# %%
# Packages laden
import numpy as np
import pandas as pd
import math
from keras.models import Sequential
from keras.layers import Input, Dense
from matplotlib import pyplot as plt
from pandas import DataFrame
from keras.datasets import mnist
from keras.utils import np_utils
from keras.layers import Dropout, Activation, Flatten,TimeDistributed, BatchNormalization, LeakyReLU, Activation 
from keras.models import Model
from pandas import concat
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.preprocessing import MinMaxScaler
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Laden der Daten
DATA_FILE="Dropbox/Masterarbeit/Masterarbeit/Datensätze/Geburtenrate/Datensatz.xlsx"
df = pd.read_excel(DATA_FILE)
df=pd.read_excel(DATA_FILE, header=0, parse_dates=[0], index_col='Jahr-Monat',squeeze=True)

# %%
# Ein array mit allen Einträgen --> zur besseren Weiterverarbeitung
ZR=df.values

# %%
ZR = ZR.reshape((len(ZR), 1))
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(ZR)
ZR_N = scaler.transform(ZR)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Anteil der Datensätze am Gesamtdatensatz
ZR_100=ZR

# Unterteilung der Teildatensätze in Trainings-und Testdaten
ZR_100_TR, ZR_100_TE= ZR_100[0:605], ZR_100[605:len(ZR_100)]

# Anteil der Datensätze am Gesamtdatensatz: normalisierte Daten
ZR_N100=ZR_N

# Unterteilung der Teildatensätze in Trainings-und Testdaten
ZR_N100_TR, ZR_N100_TE= ZR_N100[0:605], ZR_N100[605:len(ZR_N100)]

# %%
# Funktion: Datensatz erstellen mit Inputs (look_back: Anzahl der verwendten Vergangenheitswerte) + Output (look_forward: 
# Vorhersagehorizont)
def timeseries_to_supervised_R(data, look_back, look_forward):
    df = DataFrame(data)
    columns = [df.shift(look_forward-1+i) for i in range(1, look_back+1)]
    columns.append(df)
    df = concat(columns, axis=1)
    #df = df.drop(0)
    DF=df[::-1]
    df=DF[:len(df)-(look_back+look_forward-1)]
    DF=df[::-1]
    return DF

# %%
# Festlegung: look_back, look_forward + Anwendung der Funktion
# Inputneuronen: 12
# Vorhersagehorizont: t+1
look_back=12
look_forward=240

# Inputgröße 100%
# Trainingsdaten
ZR_100_TR_I=timeseries_to_supervised_R(ZR_100_TR, look_back, look_forward)
trainX_100, train_y_100 = ZR_100_TR_I.iloc[:, 0:-1], ZR_100_TR_I.iloc[:, -1]

# Testdaten 
ZR_100_TE_I=timeseries_to_supervised_R(ZR_100_TE, look_back, look_forward)
testX_100, test_y_100 = ZR_100_TE_I.iloc[:, 0:-1], ZR_100_TE_I.iloc[:, -1]

# %%
# Normalisierten Daten
# Inputgröße 100%
# Trainingsdaten
ZR_N100_TR_I=timeseries_to_supervised_R(ZR_N100_TR, look_back, look_forward)
trainX_100N, train_y_100N = ZR_N100_TR_I.iloc[:, 0:-1], ZR_N100_TR_I.iloc[:, -1]

# Testdaten 
ZR_N100_TE_I=timeseries_to_supervised_R(ZR_N100_TE, look_back, look_forward)
testX_100N, test_y_100N = ZR_N100_TE_I.iloc[:, 0:-1], ZR_N100_TE_I.iloc[:, -1]

# %%
# Replizierbarkeit gewährleisten
np.random.seed(2)

# %%
# Modell zusammenbauen
# Dateninput: 100 %
model = Sequential()
model.add(Dense(10, input_dim=look_back, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(10, activation='sigmoid'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history_reg=model.fit(trainX_100N, train_y_100N, epochs=200,batch_size=25, verbose=2,validation_data=(testX_100N, test_y_100N))
# Out:
# Train on 354 samples, validate on 7 samples
# Epoch 1/200
#  - 1s - loss: 0.0226 - val_loss: 0.0085
# Epoch 2/200
#  - 0s - loss: 0.0225 - val_loss: 0.0107
# Epoch 3/200
#  - 0s - loss: 0.0225 - val_loss: 0.0100
# Epoch 4/200
#  - 0s - loss: 0.0223 - val_loss: 0.0094
# Epoch 5/200
#  - 0s - loss: 0.0225 - val_loss: 0.0114
# Epoch 6/200
#  - 0s - loss: 0.0225 - val_loss: 0.0101
# Epoch 7/200
#  - 0s - loss: 0.0223 - val_loss: 0.0100
# Epoch 8/200
#  - 0s - loss: 0.0223 - val_loss: 0.0104
# Epoch 9/200
#  - 0s - loss: 0.0226 - val_loss: 0.0097
# Epoch 10/200
#  - 0s - loss: 0.0223 - val_loss: 0.0092
# Epoch 11/200
#  - 0s - loss: 0.0224 - val_loss: 0.0085
# Epoch 12/200
#  - 0s - loss: 0.0224 - val_loss: 0.0116
# Epoch 13/200
#  - 0s - loss: 0.0223 - val_loss: 0.0092
# Epoch 14/200
#  - 0s - loss: 0.0225 - val_loss: 0.0104
# Epoch 15/200
#  - 0s - loss: 0.0237 - val_loss: 0.0106
# Epoch 16/200
#  - 0s - loss: 0.0227 - val_loss: 0.0088
# Epoch 17/200
#  - 0s - loss: 0.0225 - val_loss: 0.0107
# Epoch 18/200
#  - 0s - loss: 0.0222 - val_loss: 0.0081
# Epoch 19/200
#  - 0s - loss: 0.0224 - val_loss: 0.0104
# Epoch 20/200
#  - 0s - loss: 0.0223 - val_loss: 0.0097
# Epoch 21/200
#  - 0s - loss: 0.0223 - val_loss: 0.0100
# Epoch 22/200
#  - 0s - loss: 0.0224 - val_loss: 0.0081
# Epoch 23/200
#  - 0s - loss: 0.0224 - val_loss: 0.0111
# Epoch 24/200
#  - 0s - loss: 0.0225 - val_loss: 0.0090
# Epoch 25/200
#  - 0s - loss: 0.0223 - val_loss: 0.0102
# Epoch 26/200
#  - 0s - loss: 0.0224 - val_loss: 0.0089
# Epoch 27/200
#  - 0s - loss: 0.0225 - val_loss: 0.0102
# Epoch 28/200
#  - 0s - loss: 0.0225 - val_loss: 0.0092
# Epoch 29/200
#  - 0s - loss: 0.0224 - val_loss: 0.0088
# Epoch 30/200
#  - 0s - loss: 0.0222 - val_loss: 0.0105
# Epoch 31/200
#  - 0s - loss: 0.0223 - val_loss: 0.0096
# Epoch 32/200
#  - 0s - loss: 0.0223 - val_loss: 0.0083
# Epoch 33/200
#  - 0s - loss: 0.0223 - val_loss: 0.0111
# Epoch 34/200
#  - 0s - loss: 0.0226 - val_loss: 0.0096
# Epoch 35/200
#  - 0s - loss: 0.0223 - val_loss: 0.0098
# Epoch 36/200
#  - 0s - loss: 0.0223 - val_loss: 0.0098
# Epoch 37/200
#  - 0s - loss: 0.0225 - val_loss: 0.0096
# Epoch 38/200
#  - 0s - loss: 0.0223 - val_loss: 0.0098
# Epoch 39/200
#  - 0s - loss: 0.0222 - val_loss: 0.0120
# Epoch 40/200
#  - 0s - loss: 0.0224 - val_loss: 0.0091
# Epoch 41/200
#  - 0s - loss: 0.0223 - val_loss: 0.0103
# Epoch 42/200
#  - 0s - loss: 0.0224 - val_loss: 0.0098
# Epoch 43/200
#  - 0s - loss: 0.0223 - val_loss: 0.0093
# Epoch 44/200
#  - 0s - loss: 0.0224 - val_loss: 0.0092
# Epoch 45/200
#  - 0s - loss: 0.0223 - val_loss: 0.0094
# Epoch 46/200
#  - 0s - loss: 0.0224 - val_loss: 0.0099
# Epoch 47/200
#  - 0s - loss: 0.0223 - val_loss: 0.0098
# Epoch 48/200
#  - 0s - loss: 0.0222 - val_loss: 0.0110
# Epoch 49/200
#  - 0s - loss: 0.0228 - val_loss: 0.0087
# Epoch 50/200
#  - 0s - loss: 0.0224 - val_loss: 0.0085
# Epoch 51/200
#  - 0s - loss: 0.0223 - val_loss: 0.0103
# Epoch 52/200
#  - 0s - loss: 0.0223 - val_loss: 0.0101
# Epoch 53/200
#  - 0s - loss: 0.0224 - val_loss: 0.0088
# Epoch 54/200
#  - 0s - loss: 0.0224 - val_loss: 0.0099
# Epoch 55/200
#  - 0s - loss: 0.0225 - val_loss: 0.0096
# Epoch 56/200
#  - 0s - loss: 0.0226 - val_loss: 0.0084
# Epoch 57/200
#  - 0s - loss: 0.0224 - val_loss: 0.0105
# Epoch 58/200
#  - 0s - loss: 0.0224 - val_loss: 0.0105
# Epoch 59/200
#  - 0s - loss: 0.0224 - val_loss: 0.0106
# Epoch 60/200
#  - 0s - loss: 0.0224 - val_loss: 0.0101
# Epoch 61/200
#  - 0s - loss: 0.0223 - val_loss: 0.0103
# Epoch 62/200
#  - 0s - loss: 0.0223 - val_loss: 0.0093
# Epoch 63/200
#  - 0s - loss: 0.0225 - val_loss: 0.0093
# Epoch 64/200
#  - 0s - loss: 0.0223 - val_loss: 0.0118
# Epoch 65/200
#  - 0s - loss: 0.0224 - val_loss: 0.0101
# Epoch 66/200
#  - 0s - loss: 0.0224 - val_loss: 0.0102
# Epoch 67/200
#  - 0s - loss: 0.0224 - val_loss: 0.0090
# Epoch 68/200
#  - 0s - loss: 0.0224 - val_loss: 0.0107
# Epoch 69/200
#  - 0s - loss: 0.0224 - val_loss: 0.0091
# Epoch 70/200
#  - 0s - loss: 0.0223 - val_loss: 0.0113
# Epoch 71/200
#  - 0s - loss: 0.0225 - val_loss: 0.0079
# Epoch 72/200
#  - 0s - loss: 0.0228 - val_loss: 0.0108
# Epoch 73/200
#  - 0s - loss: 0.0223 - val_loss: 0.0099
# Epoch 74/200
#  - 0s - loss: 0.0225 - val_loss: 0.0108
# Epoch 75/200
#  - 0s - loss: 0.0223 - val_loss: 0.0088
# Epoch 76/200
#  - 0s - loss: 0.0223 - val_loss: 0.0094
# Epoch 77/200
#  - 0s - loss: 0.0223 - val_loss: 0.0110
# Epoch 78/200
#  - 0s - loss: 0.0224 - val_loss: 0.0102
# Epoch 79/200
#  - 0s - loss: 0.0223 - val_loss: 0.0092
# Epoch 80/200
#  - 0s - loss: 0.0222 - val_loss: 0.0115
# Epoch 81/200
#  - 0s - loss: 0.0224 - val_loss: 0.0097
# Epoch 82/200
#  - 0s - loss: 0.0225 - val_loss: 0.0109
# Epoch 83/200
#  - 0s - loss: 0.0227 - val_loss: 0.0095
# Epoch 84/200
#  - 0s - loss: 0.0228 - val_loss: 0.0095
# Epoch 85/200
#  - 0s - loss: 0.0225 - val_loss: 0.0092
# Epoch 86/200
#  - 0s - loss: 0.0224 - val_loss: 0.0093
# Epoch 87/200
#  - 0s - loss: 0.0222 - val_loss: 0.0116
# Epoch 88/200
#  - 0s - loss: 0.0224 - val_loss: 0.0111
# Epoch 89/200
#  - 0s - loss: 0.0224 - val_loss: 0.0103
# Epoch 90/200
#  - 0s - loss: 0.0224 - val_loss: 0.0094
# Epoch 91/200
#  - 0s - loss: 0.0223 - val_loss: 0.0109
# Epoch 92/200
#  - 0s - loss: 0.0223 - val_loss: 0.0100
# Epoch 93/200
#  - 0s - loss: 0.0223 - val_loss: 0.0093
# Epoch 94/200
#  - 0s - loss: 0.0224 - val_loss: 0.0095
# Epoch 95/200
#  - 0s - loss: 0.0224 - val_loss: 0.0112
# Epoch 96/200
#  - 0s - loss: 0.0223 - val_loss: 0.0098
# Epoch 97/200
#  - 0s - loss: 0.0223 - val_loss: 0.0099
# Epoch 98/200
#  - 0s - loss: 0.0224 - val_loss: 0.0099
# Epoch 99/200
#  - 0s - loss: 0.0222 - val_loss: 0.0098
# Epoch 100/200
#  - 0s - loss: 0.0223 - val_loss: 0.0091
# Epoch 101/200
#  - 0s - loss: 0.0223 - val_loss: 0.0105
# Epoch 102/200
#  - 0s - loss: 0.0224 - val_loss: 0.0098
# Epoch 103/200
#  - 0s - loss: 0.0223 - val_loss: 0.0088
# Epoch 104/200
#  - 0s - loss: 0.0224 - val_loss: 0.0101
# Epoch 105/200
#  - 0s - loss: 0.0223 - val_loss: 0.0092
# Epoch 106/200
#  - 0s - loss: 0.0224 - val_loss: 0.0111
# Epoch 107/200
#  - 0s - loss: 0.0222 - val_loss: 0.0092
# Epoch 108/200
#  - 0s - loss: 0.0223 - val_loss: 0.0108
# Epoch 109/200
#  - 0s - loss: 0.0223 - val_loss: 0.0106
# Epoch 110/200
#  - 0s - loss: 0.0222 - val_loss: 0.0085
# Epoch 111/200
#  - 0s - loss: 0.0224 - val_loss: 0.0102
# Epoch 112/200
#  - 0s - loss: 0.0224 - val_loss: 0.0113
# Epoch 113/200
#  - 0s - loss: 0.0222 - val_loss: 0.0085
# Epoch 114/200
#  - 0s - loss: 0.0222 - val_loss: 0.0109
# Epoch 115/200
#  - 0s - loss: 0.0222 - val_loss: 0.0099
# Epoch 116/200
#  - 0s - loss: 0.0225 - val_loss: 0.0099
# Epoch 117/200
#  - 0s - loss: 0.0225 - val_loss: 0.0093
# Epoch 118/200
#  - 0s - loss: 0.0223 - val_loss: 0.0102
# Epoch 119/200
#  - 0s - loss: 0.0222 - val_loss: 0.0087
# Epoch 120/200
#  - 0s - loss: 0.0223 - val_loss: 0.0112
# Epoch 121/200
#  - 0s - loss: 0.0226 - val_loss: 0.0103
# Epoch 122/200
#  - 0s - loss: 0.0229 - val_loss: 0.0090
# Epoch 123/200
#  - 0s - loss: 0.0224 - val_loss: 0.0121
# Epoch 124/200
#  - 0s - loss: 0.0223 - val_loss: 0.0088
# Epoch 125/200
#  - 0s - loss: 0.0223 - val_loss: 0.0097
# Epoch 126/200
#  - 0s - loss: 0.0222 - val_loss: 0.0102
# Epoch 127/200
#  - 0s - loss: 0.0224 - val_loss: 0.0096
# Epoch 128/200
#  - 0s - loss: 0.0223 - val_loss: 0.0097
# Epoch 129/200
#  - 0s - loss: 0.0223 - val_loss: 0.0103
# Epoch 130/200
#  - 0s - loss: 0.0223 - val_loss: 0.0110
# Epoch 131/200
#  - 0s - loss: 0.0223 - val_loss: 0.0096
# Epoch 132/200
#  - 0s - loss: 0.0224 - val_loss: 0.0104
# Epoch 133/200
#  - 0s - loss: 0.0223 - val_loss: 0.0098
# Epoch 134/200
#  - 0s - loss: 0.0222 - val_loss: 0.0101
# Epoch 135/200
#  - 0s - loss: 0.0223 - val_loss: 0.0087
# Epoch 136/200
#  - 0s - loss: 0.0223 - val_loss: 0.0114
# Epoch 137/200
#  - 0s - loss: 0.0223 - val_loss: 0.0103
# Epoch 138/200
#  - 0s - loss: 0.0223 - val_loss: 0.0099
# Epoch 139/200
#  - 0s - loss: 0.0224 - val_loss: 0.0104
# Epoch 140/200
#  - 0s - loss: 0.0222 - val_loss: 0.0108
# Epoch 141/200
#  - 0s - loss: 0.0223 - val_loss: 0.0094
# Epoch 142/200
#  - 0s - loss: 0.0223 - val_loss: 0.0087
# Epoch 143/200
#  - 0s - loss: 0.0223 - val_loss: 0.0097
# Epoch 144/200
#  - 0s - loss: 0.0223 - val_loss: 0.0110
# Epoch 145/200
#  - 0s - loss: 0.0224 - val_loss: 0.0095
# Epoch 146/200
#  - 0s - loss: 0.0224 - val_loss: 0.0116
# Epoch 147/200
#  - 0s - loss: 0.0223 - val_loss: 0.0095
# Epoch 148/200
#  - 0s - loss: 0.0222 - val_loss: 0.0107
# Epoch 149/200
#  - 0s - loss: 0.0228 - val_loss: 0.0100
# Epoch 150/200
#  - 0s - loss: 0.0228 - val_loss: 0.0093
# Epoch 151/200
#  - 0s - loss: 0.0225 - val_loss: 0.0123
# Epoch 152/200
#  - 0s - loss: 0.0222 - val_loss: 0.0081
# Epoch 153/200
#  - 0s - loss: 0.0224 - val_loss: 0.0102
# Epoch 154/200
#  - 0s - loss: 0.0223 - val_loss: 0.0099
# Epoch 155/200
#  - 0s - loss: 0.0222 - val_loss: 0.0099
# Epoch 156/200
#  - 0s - loss: 0.0224 - val_loss: 0.0091
# Epoch 157/200
#  - 0s - loss: 0.0226 - val_loss: 0.0105
# Epoch 158/200
#  - 0s - loss: 0.0225 - val_loss: 0.0092
# Epoch 159/200
#  - 0s - loss: 0.0225 - val_loss: 0.0101
# Epoch 160/200
#  - 0s - loss: 0.0223 - val_loss: 0.0095
# Epoch 161/200
#  - 0s - loss: 0.0223 - val_loss: 0.0104
# Epoch 162/200
#  - 0s - loss: 0.0223 - val_loss: 0.0094
# Epoch 163/200
#  - 0s - loss: 0.0224 - val_loss: 0.0105
# Epoch 164/200
#  - 0s - loss: 0.0223 - val_loss: 0.0098
# Epoch 165/200
#  - 0s - loss: 0.0223 - val_loss: 0.0105
# Epoch 166/200
#  - 0s - loss: 0.0223 - val_loss: 0.0102
# Epoch 167/200
#  - 0s - loss: 0.0223 - val_loss: 0.0099
# Epoch 168/200
#  - 0s - loss: 0.0222 - val_loss: 0.0091
# Epoch 169/200
#  - 0s - loss: 0.0222 - val_loss: 0.0099
# Epoch 170/200
#  - 0s - loss: 0.0223 - val_loss: 0.0105
# Epoch 171/200
#  - 0s - loss: 0.0223 - val_loss: 0.0090
# Epoch 172/200
#  - 0s - loss: 0.0223 - val_loss: 0.0093
# Epoch 173/200
#  - 0s - loss: 0.0222 - val_loss: 0.0121
# Epoch 174/200
#  - 0s - loss: 0.0223 - val_loss: 0.0093
# Epoch 175/200
#  - 0s - loss: 0.0222 - val_loss: 0.0109
# Epoch 176/200
#  - 0s - loss: 0.0226 - val_loss: 0.0096
# Epoch 177/200
#  - 0s - loss: 0.0224 - val_loss: 0.0091
# Epoch 178/200
#  - 0s - loss: 0.0222 - val_loss: 0.0114
# Epoch 179/200
#  - 0s - loss: 0.0226 - val_loss: 0.0097
# Epoch 180/200
#  - 0s - loss: 0.0222 - val_loss: 0.0121
# Epoch 181/200
#  - 0s - loss: 0.0224 - val_loss: 0.0091
# Epoch 182/200
#  - 0s - loss: 0.0227 - val_loss: 0.0132
# Epoch 183/200
#  - 0s - loss: 0.0223 - val_loss: 0.0090
# Epoch 184/200
#  - 0s - loss: 0.0223 - val_loss: 0.0093
# Epoch 185/200
#  - 0s - loss: 0.0222 - val_loss: 0.0106
# Epoch 186/200
#  - 0s - loss: 0.0222 - val_loss: 0.0091
# Epoch 187/200
#  - 0s - loss: 0.0223 - val_loss: 0.0108
# Epoch 188/200
#  - 0s - loss: 0.0225 - val_loss: 0.0101
# Epoch 189/200
#  - 0s - loss: 0.0223 - val_loss: 0.0109
# Epoch 190/200
#  - 0s - loss: 0.0222 - val_loss: 0.0099
# Epoch 191/200
#  - 0s - loss: 0.0222 - val_loss: 0.0116
# Epoch 192/200
#  - 0s - loss: 0.0228 - val_loss: 0.0118
# Epoch 193/200
#  - 0s - loss: 0.0224 - val_loss: 0.0091
# Epoch 194/200
#  - 0s - loss: 0.0223 - val_loss: 0.0127
# Epoch 195/200
#  - 0s - loss: 0.0225 - val_loss: 0.0092
# Epoch 196/200
#  - 0s - loss: 0.0221 - val_loss: 0.0122
# Epoch 197/200
#  - 0s - loss: 0.0226 - val_loss: 0.0103
# Epoch 198/200
#  - 0s - loss: 0.0224 - val_loss: 0.0088
# Epoch 199/200
#  - 0s - loss: 0.0223 - val_loss: 0.0117
# Epoch 200/200
#  - 0s - loss: 0.0223 - val_loss: 0.0092

# %%
#Ploten der Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history_reg.history['loss'],'r',linewidth=3.0)
plt.plot(history_reg.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
# Out:
# Text(0.5,1,'Loss Curves')

# %%
# Modellperformance bewerten: normalisierte Daten
trainScore = model.evaluate(trainX_100N, train_y_100N, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))
testScore = model.evaluate(testX_100N, test_y_100N, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.02 MSE (0.15 RMSE)
# Test Score: 0.01 MSE (0.10 RMSE)

# %%
# Vorhersagen generieren
trainPredict_100N = model.predict(trainX_100N)
testPredict_100N = model.predict(testX_100N)

# %%
# Prediction Denormalizing
testPredict_100=scaler.inverse_transform(testPredict_100N)
trainPredict_100=scaler.inverse_transform(trainPredict_100N)

# Evaluation
test_MSE=mean_squared_error(test_y_100,testPredict_100)
train_MSE=mean_squared_error(train_y_100,trainPredict_100)

print(test_MSE,train_MSE)
# Out:
# 54086584.900905065 130521242.65906866

# %%
# Verschiebund der Trainingsvorhersage zum Plotten
trainPredictPlot = np.empty_like(ZR_100)
trainPredictPlot=trainPredictPlot.reshape(len(ZR_100))
trainPredictPlot[:]=[0]*len(ZR_100)
trainPredictPlot = trainPredictPlot.reshape(len(ZR_100),1)
trainPredictPlot[(look_back+look_forward-1):len(trainPredict_100)+(look_back+look_forward-1)] = trainPredict_100

# Verschiebung der Testvorhersage zum Plotten
testPredictPlot = np.empty_like(ZR_100)
testPredictPlot=testPredictPlot.reshape(len(ZR_100))
testPredictPlot[:]=[0]*len(ZR_100)
testPredictPlot = testPredictPlot.reshape(len(ZR_100),1)
testPredictPlot[len(trainPredict_100)+(2*look_back+2*look_forward-2):len(ZR_100)-(look_back+look_forward-1)+look_back+look_forward] = testPredict_100
 
# Plotten der baseline und  der Vorhersagen
plt.plot(ZR_100, color='blue')
plt.plot(trainPredictPlot, color='orange') 
plt.plot(testPredictPlot, color='green')
plt.show()
