# %%
# Packages laden
import numpy as np
import pandas as pd
import math
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from pandas import DataFrame
from pandas import concat
from math import sqrt
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Laden der Daten
DATA_FILE="Dropbox/Masterarbeit/Masterarbeit/Datensätze/Geburtenrate/Datensatz.xlsx"
df = pd.read_excel(DATA_FILE)
df=pd.read_excel(DATA_FILE, header=0, parse_dates=[0], index_col='Jahr-Monat',squeeze=True,)

# %%
# Ein array mit allen Einträgen --> zur besseren Weiterverarbeitung
ZR=df.values

# %%
# Daten normalisieren
ZR = ZR.reshape((len(ZR), 1))
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(ZR)
ZR_N = scaler.transform(ZR)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Anteil der Datensätze am Gesamtdatensatz
ZR_100=ZR
ZR_46=ZR[-400:]
ZR_12=ZR[-100:]

# Unterteilung der Teildatensätze in Trainings-und Testdaten
ZR_100_TR, ZR_100_TE= ZR_100[0:605], ZR_100[605:len(ZR_100)]
ZR_46_TR, ZR_46_TE= ZR_46[0:250], ZR_46[250:len(ZR_46)]
ZR_12_TR, ZR_12_TE= ZR_12[0:50], ZR_12[50:len(ZR_12)]

# Anteil der Datensätze am Gesamtdatensatz: normalisierte Daten
ZR_N100=ZR_N
ZR_N46=ZR_N[-400:]
ZR_N12=ZR_N[-100:]

# Unterteilung der Teildatensätze in Trainings-und Testdaten
ZR_N100_TR, ZR_N100_TE= ZR_N100[0:605], ZR_N100[605:len(ZR_N100)]
ZR_N46_TR, ZR_N46_TE= ZR_N46[0:250], ZR_N46[250:len(ZR_N46)]
ZR_N12_TR, ZR_N12_TE= ZR_N12[0:50], ZR_N12[50:len(ZR_N12)]

# %%
# Funktion: Datensatz erstellen mit Inputs (look_back: Anzahl der verwendten Vergangenheitswerte) + Output (look_forward: 
# Vorhersagehorizont)
def timeseries_to_supervised_R(data, look_back=1, look_forward=1):
    df = DataFrame(data)
    columns = [df.shift(look_forward-1+i) for i in range(1, look_back+1)]
    columns.append(df)
    df = concat(columns, axis=1)
    df = df.drop(0)
    DF=df[::-1]
    df=DF[:len(df)-(look_back+look_forward-1)]
    DF=df[::-1]
    return DF

# %%
# Festlegung: look_back, look_forward + Anwendung der Funktion
# Inputneuronen: 12
# Vorhersagehorizont: 1
look_back=12
look_forward=1

# Inputgröße 100%
# Trainingsdaten
ZR_100_TR_I=timeseries_to_supervised_R(ZR_100_TR, look_back, look_forward)

# Testdaten 
ZR_100_TE_I=timeseries_to_supervised_R(ZR_100_TE, look_back, look_forward)


# Inputgröße 46%
# Trainingsdaten
ZR_46_TR_I=timeseries_to_supervised_R(ZR_46_TR, look_back, look_forward)

# Testdaten 
ZR_46_TE_I=timeseries_to_supervised_R(ZR_46_TE, look_back, look_forward)

# Inputgröße 12%
# Trainingsdaten
ZR_12_TR_I=timeseries_to_supervised_R(ZR_12_TR, look_back, look_forward)

# Testdaten 
ZR_12_TE_I=timeseries_to_supervised_R(ZR_12_TE, look_back, look_forward)

# %%
# Normalisierten Daten
# Inputgröße 100%
# Trainingsdaten
ZR_N100_TR_I=timeseries_to_supervised_R(ZR_N100_TR, look_back, look_forward)

# Testdaten 
ZR_N100_TE_I=timeseries_to_supervised_R(ZR_N100_TE, look_back, look_forward)


# Inputgröße 46%
# Trainingsdaten
ZR_N46_TR_I=timeseries_to_supervised_R(ZR_N46_TR, look_back, look_forward)

# Testdaten 
ZR_N46_TE_I=timeseries_to_supervised_R(ZR_N46_TE, look_back, look_forward)


# Inputgröße 12%
# Trainingsdaten
ZR_N12_TR_I=timeseries_to_supervised_R(ZR_N12_TR, look_back, look_forward)

# Testdaten 
ZR_N12_TE_I=timeseries_to_supervised_R(ZR_N12_TE, look_back, look_forward)

# %%
# Funktion: X,y trennen, Form von X anpassen, Modell zusammenbauen, Modell anpassen
def fit_lstm(train, batch_size, nb_epochs, blocks):
    X, y = train.iloc[:, 0:-1], train.iloc[:, -1]
    X=array(X)
    X = X.reshape(X.shape[0], 1, X.shape[1]) 
    model = Sequential()
    model.add(LSTM(blocks, return_sequences=True, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(LSTM(blocks))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epochs):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
        model.reset_states()
    return model

# %%
# Replizierbarkeit gewährleisten
np.random.seed(0)

# %%
# Modell anpassen: 100% der originalen Datensatzstärke
lstm_model_100 = fit_lstm(ZR_N100_TR_I, 1, 30, 4)

# %%
# Funktion zur Vorhersage definieren
def forecast_lstm(model, batch_size, X):
    X=array(X)
    X = X.reshape(1, 1, len(X)) # 1,1 hat nichts mit look_forward oder look_backward zu tun!
    yhat = model.predict(X, batch_size=batch_size)
    return yhat[0,0]

# %%
# Validierung des Modells anhand der Testdaten
predictions_100 = list()
for i in range(len(ZR_N100_TE_I)):
    # Vorhersage erzeugen 
    X, y = ZR_N100_TE_I.iloc[i, 0:-1], ZR_N100_TE_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_100, 1, X)
    predictions_100.append(yhat)
    expected = ZR_N100[len(ZR_N100_TR_I) + i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.262996, Expected=0.223510
# Month=2, Predicted=0.294989, Expected=0.280323
# Month=3, Predicted=0.283545, Expected=0.269972
# Month=4, Predicted=0.261754, Expected=0.253233
# Month=5, Predicted=0.241877, Expected=0.232648
# Month=6, Predicted=0.222144, Expected=0.170517
# Month=7, Predicted=0.212276, Expected=0.170399
# Month=8, Predicted=0.205907, Expected=0.208309
# Month=9, Predicted=0.207550, Expected=0.183214
# Month=10, Predicted=0.201741, Expected=0.224774
# Month=11, Predicted=0.211989, Expected=0.178704
# Month=12, Predicted=0.223442, Expected=0.210825
# Month=13, Predicted=0.229751, Expected=0.232896
# Month=14, Predicted=0.232568, Expected=0.311024
# Month=15, Predicted=0.249828, Expected=0.304401
# Month=16, Predicted=0.237968, Expected=0.303071
# Month=17, Predicted=0.220538, Expected=0.260064
# Month=18, Predicted=0.207488, Expected=0.215792
# Month=19, Predicted=0.203171, Expected=0.247627
# Month=20, Predicted=0.193518, Expected=0.292355
# Month=21, Predicted=0.199606, Expected=0.218530
# Month=22, Predicted=0.188017, Expected=0.234773
# Month=23, Predicted=0.193715, Expected=0.254054
# Month=24, Predicted=0.201822, Expected=0.275108
# Month=25, Predicted=0.228296, Expected=0.281731
# Month=26, Predicted=0.232002, Expected=0.335089
# Month=27, Predicted=0.245751, Expected=0.299082
# Month=28, Predicted=0.229182, Expected=0.293776
# Month=29, Predicted=0.214375, Expected=0.238645
# Month=30, Predicted=0.192485, Expected=0.159944
# Month=31, Predicted=0.189359, Expected=0.208283
# Month=32, Predicted=0.186418, Expected=0.247275
# Month=33, Predicted=0.197688, Expected=0.174102
# Month=34, Predicted=0.189354, Expected=0.227734
# Month=35, Predicted=0.198180, Expected=0.213798
# Month=36, Predicted=0.207621, Expected=0.218621
# Month=37, Predicted=0.224670, Expected=0.202495
# Month=38, Predicted=0.221317, Expected=0.310567
# Month=39, Predicted=0.229122, Expected=0.283178
# Month=40, Predicted=0.215336, Expected=0.293346
# Month=41, Predicted=0.203093, Expected=0.217435
# Month=42, Predicted=0.191639, Expected=0.167153
# Month=43, Predicted=0.191207, Expected=0.181872
# Month=44, Predicted=0.188377, Expected=0.232283
# Month=45, Predicted=0.184736, Expected=0.158367
# Month=46, Predicted=0.168997, Expected=0.209000
# Month=47, Predicted=0.179709, Expected=0.180581
# Month=48, Predicted=0.190069, Expected=0.226143
# Month=49, Predicted=0.205644, Expected=0.226078
# Month=50, Predicted=0.209933, Expected=0.293085
# Month=51, Predicted=0.223167, Expected=0.268290
# Month=52, Predicted=0.209847, Expected=0.268225
# Month=53, Predicted=0.196602, Expected=0.184088
# Month=54, Predicted=0.182475, Expected=0.128422
# Month=55, Predicted=0.177338, Expected=0.176722
# Month=56, Predicted=0.161557, Expected=0.231984
# Month=57, Predicted=0.168168, Expected=0.190189
# Month=58, Predicted=0.162516, Expected=0.215688
# Month=59, Predicted=0.174931, Expected=0.173320
# Month=60, Predicted=0.176850, Expected=0.222715
# Month=61, Predicted=0.189531, Expected=0.202678
# Month=62, Predicted=0.197488, Expected=0.256088
# Month=63, Predicted=0.209260, Expected=0.265109
# Month=64, Predicted=0.199209, Expected=0.241761
# Month=65, Predicted=0.190170, Expected=0.196303
# Month=66, Predicted=0.174954, Expected=0.140220
# Month=67, Predicted=0.169188, Expected=0.166410
# Month=68, Predicted=0.159244, Expected=0.208401
# Month=69, Predicted=0.162302, Expected=0.099051
# Month=70, Predicted=0.148585, Expected=0.169109
# Month=71, Predicted=0.154865, Expected=0.142123
# Month=72, Predicted=0.167676, Expected=0.199640
# Month=73, Predicted=0.185570, Expected=0.175275
# Month=74, Predicted=0.196457, Expected=0.240562
# Month=75, Predicted=0.212505, Expected=0.230185
# Month=76, Predicted=0.203245, Expected=0.198623
# Month=77, Predicted=0.186811, Expected=0.172577
# Month=78, Predicted=0.168750, Expected=0.120639
# Month=79, Predicted=0.158673, Expected=0.122282
# Month=80, Predicted=0.149856, Expected=0.167949
# Month=81, Predicted=0.157438, Expected=0.101971
# Month=82, Predicted=0.147374, Expected=0.168913
# Month=83, Predicted=0.153445, Expected=0.130182
# Month=84, Predicted=0.161731, Expected=0.142958
# Month=85, Predicted=0.184771, Expected=0.144900
# Month=86, Predicted=0.195377, Expected=0.223797
# Month=87, Predicted=0.211087, Expected=0.204372
# Month=88, Predicted=0.198394, Expected=0.202521
# Month=89, Predicted=0.181164, Expected=0.173424
# Month=90, Predicted=0.167616, Expected=0.096730
# Month=91, Predicted=0.162612, Expected=0.122269
# Month=92, Predicted=0.152711, Expected=0.145474
# Month=93, Predicted=0.148252, Expected=0.072991
# Month=94, Predicted=0.140354, Expected=0.123234
# Month=95, Predicted=0.148886, Expected=0.118058
# Month=96, Predicted=0.163126, Expected=0.147781
# Month=97, Predicted=0.178286, Expected=0.146569
# Month=98, Predicted=0.186798, Expected=0.235256
# Month=99, Predicted=0.196189, Expected=0.194804
# Month=100, Predicted=0.186072, Expected=0.205116
# Month=101, Predicted=0.172098, Expected=0.145422
# Month=102, Predicted=0.157764, Expected=0.077567
# Month=103, Predicted=0.148684, Expected=0.104383
# Month=104, Predicted=0.141164, Expected=0.152696
# Month=105, Predicted=0.140656, Expected=0.091229
# Month=106, Predicted=0.133770, Expected=0.114682
# Month=107, Predicted=0.140130, Expected=0.101046
# Month=108, Predicted=0.152734, Expected=0.112909
# Month=109, Predicted=0.171148, Expected=0.159162
# Month=110, Predicted=0.179164, Expected=0.225074
# Month=111, Predicted=0.190014, Expected=0.211464
# Month=112, Predicted=0.180314, Expected=0.192770
# Month=113, Predicted=0.171994, Expected=0.136283
# Month=114, Predicted=0.154651, Expected=0.086679
# Month=115, Predicted=0.141955, Expected=0.118332
# Month=116, Predicted=0.133321, Expected=0.122777
# Month=117, Predicted=0.140242, Expected=0.068376
# Month=118, Predicted=0.130213, Expected=0.119297
# Month=119, Predicted=0.140112, Expected=0.101215
# Month=120, Predicted=0.143911, Expected=0.116624
# Month=121, Predicted=0.168757, Expected=0.133311
# Month=122, Predicted=0.179379, Expected=0.176657
# Month=123, Predicted=0.195756, Expected=0.176722
# Month=124, Predicted=0.188432, Expected=0.166215
# Month=125, Predicted=0.180818, Expected=0.110797
# Month=126, Predicted=0.161215, Expected=0.063162
# Month=127, Predicted=0.156576, Expected=0.088700
# Month=128, Predicted=0.144929, Expected=0.096196
# Month=129, Predicted=0.149163, Expected=0.044585
# Month=130, Predicted=0.130100, Expected=0.100733
# Month=131, Predicted=0.136054, Expected=0.055144
# Month=132, Predicted=0.152692, Expected=0.134575
# Month=133, Predicted=0.172844, Expected=0.111605
# Month=134, Predicted=0.185471, Expected=0.170673
# Month=135, Predicted=0.196870, Expected=0.164337
# Month=136, Predicted=0.191825, Expected=0.159436
# Month=137, Predicted=0.175929, Expected=0.125111
# Month=138, Predicted=0.156617, Expected=0.059759
# Month=139, Predicted=0.146072, Expected=0.051298
# Month=140, Predicted=0.134425, Expected=0.121995
# Month=141, Predicted=0.130649, Expected=0.041977
# Month=142, Predicted=0.125532, Expected=0.108789
# Month=143, Predicted=0.135608, Expected=0.042694
# Month=144, Predicted=0.148120, Expected=0.109793
# Month=145, Predicted=0.168045, Expected=0.124863
# Month=146, Predicted=0.180579, Expected=0.180568
# Month=147, Predicted=0.196007, Expected=0.190919
# Month=148, Predicted=0.181740, Expected=0.182093
# Month=149, Predicted=0.163695, Expected=0.150701
# Month=150, Predicted=0.146551, Expected=0.084176
# Month=151, Predicted=0.139811, Expected=0.093119
# Month=152, Predicted=0.131186, Expected=0.138173
# Month=153, Predicted=0.131943, Expected=0.071049
# Month=154, Predicted=0.125389, Expected=0.064296
# Month=155, Predicted=0.134944, Expected=0.092924
# Month=156, Predicted=0.147335, Expected=0.123559
# Month=157, Predicted=0.169878, Expected=0.135488
# Month=158, Predicted=0.179265, Expected=0.200696
# Month=159, Predicted=0.190148, Expected=0.169526
# Month=160, Predicted=0.177336, Expected=0.173945
# Month=161, Predicted=0.173319, Expected=0.116507
# Month=162, Predicted=0.161816, Expected=0.049317
# Month=163, Predicted=0.151782, Expected=0.065599
# Month=164, Predicted=0.136871, Expected=0.094319
# Month=165, Predicted=0.136742, Expected=0.028250
# Month=166, Predicted=0.123206, Expected=0.075246
# Month=167, Predicted=0.128136, Expected=0.068533
# Month=168, Predicted=0.135840, Expected=0.086236
# Month=169, Predicted=0.158787, Expected=0.115190
# Month=170, Predicted=0.173737, Expected=0.187360
# Month=171, Predicted=0.192595, Expected=0.155812
# Month=172, Predicted=0.188589, Expected=0.152422
# Month=173, Predicted=0.177259, Expected=0.089169
# Month=174, Predicted=0.155330, Expected=0.044311
# Month=175, Predicted=0.140474, Expected=0.077554
# Month=176, Predicted=0.128918, Expected=0.095857
# Month=177, Predicted=0.129730, Expected=0.031209
# Month=178, Predicted=0.121276, Expected=0.098634
# Month=179, Predicted=0.134887, Expected=0.053449
# Month=180, Predicted=0.149010, Expected=0.106038
# Month=181, Predicted=0.167635, Expected=0.125293
# Month=182, Predicted=0.177185, Expected=0.182484
# Month=183, Predicted=0.193111, Expected=0.155460
# Month=184, Predicted=0.181871, Expected=0.172146
# Month=185, Predicted=0.168212, Expected=0.142045
# Month=186, Predicted=0.153055, Expected=0.086771
# Month=187, Predicted=0.145896, Expected=0.092155
# Month=188, Predicted=0.135505, Expected=0.089717
# Month=189, Predicted=0.135082, Expected=0.033895
# Month=190, Predicted=0.125245, Expected=0.071870
# Month=191, Predicted=0.135217, Expected=0.024391
# Month=192, Predicted=0.146249, Expected=0.093067
# Month=193, Predicted=0.168132, Expected=0.117680
# Month=194, Predicted=0.184518, Expected=0.172720
# Month=195, Predicted=0.203032, Expected=0.167988
# Month=196, Predicted=0.196941, Expected=0.161496
# Month=197, Predicted=0.182622, Expected=0.104513
# Month=198, Predicted=0.159219, Expected=0.049160
# Month=199, Predicted=0.148804, Expected=0.056083
# Month=200, Predicted=0.136444, Expected=0.086145
# Month=201, Predicted=0.142753, Expected=0.043802
# Month=202, Predicted=0.135147, Expected=0.092637
# Month=203, Predicted=0.145929, Expected=0.068298
# Month=204, Predicted=0.161425, Expected=0.114238
# Month=205, Predicted=0.189938, Expected=0.099142
# Month=206, Predicted=0.203140, Expected=0.175027
# Month=207, Predicted=0.218407, Expected=0.179303
# Month=208, Predicted=0.205109, Expected=0.152461
# Month=209, Predicted=0.191419, Expected=0.129530
# Month=210, Predicted=0.174268, Expected=0.073917
# Month=211, Predicted=0.165355, Expected=0.069641
# Month=212, Predicted=0.154969, Expected=0.104279
# Month=213, Predicted=0.154428, Expected=0.024326
# Month=214, Predicted=0.145211, Expected=0.082156
# Month=215, Predicted=0.156429, Expected=0.074529
# Month=216, Predicted=0.172048, Expected=0.115347
# Month=217, Predicted=0.200833, Expected=0.119270
# Month=218, Predicted=0.214738, Expected=0.212338
# Month=219, Predicted=0.234124, Expected=0.189289
# Month=220, Predicted=0.225089, Expected=0.193005
# Month=221, Predicted=0.211353, Expected=0.133037
# Month=222, Predicted=0.191755, Expected=0.066030
# Month=223, Predicted=0.178319, Expected=0.081673
# Month=224, Predicted=0.166515, Expected=0.125111
# Month=225, Predicted=0.174734, Expected=0.070710
# Month=226, Predicted=0.170310, Expected=0.109506
# Month=227, Predicted=0.180363, Expected=0.106104
# Month=228, Predicted=0.194571, Expected=0.147090
# Month=229, Predicted=0.221939, Expected=0.164598
# Month=230, Predicted=0.240159, Expected=0.248214
# Month=231, Predicted=0.257261, Expected=0.215597
# Month=232, Predicted=0.247156, Expected=0.222545
# Month=233, Predicted=0.232903, Expected=0.178286
# Month=234, Predicted=0.215308, Expected=0.107107
# Month=235, Predicted=0.207861, Expected=0.128761
# Month=236, Predicted=0.195765, Expected=0.150832
# Month=237, Predicted=0.190911, Expected=0.070762
# Month=238, Predicted=0.180983, Expected=0.137600
# Month=239, Predicted=0.189267, Expected=0.113991
# Month=240, Predicted=0.206259, Expected=0.169930
# Month=241, Predicted=0.232899, Expected=0.202547
# Month=242, Predicted=0.246545, Expected=0.264757
# Month=243, Predicted=0.258868, Expected=0.257353
# Month=244, Predicted=0.248584, Expected=0.256271
# Month=245, Predicted=0.229708, Expected=0.206967

# %%
# Skalierung zurücksetzten
predictions_100=np.reshape(predictions_100,(len(predictions_100),1))
predictions_100=scaler.inverse_transform(predictions_100)

# %%
# Modellperformance bewerten
mse = mean_squared_error(ZR_100[-len(predictions_100):], predictions_100)
print('Test MSE: %.3f' % mse)
# Vorhersage und Testdaten abtragen
plt.plot(ZR_100[-len(predictions_100):], color='blue')
plt.plot(predictions_100, color='orange')
plt.show()
# Out:
# Test MSE: 15924204.127

# %%
predictions_train_100 = list()
for i in range(len(ZR_N100_TR_I)):
    # Vorhersage erzeugen
    X, y = ZR_N100_TR_I.iloc[i, 0:-1], ZR_N100_TR_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_100, 1, X)
    predictions_train_100.append(yhat)
    expected = ZR_N100[ i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.289564, Expected=0.057608
# Month=2, Predicted=0.318242, Expected=0.288836
# Month=3, Predicted=0.317157, Expected=0.342833
# Month=4, Predicted=0.332791, Expected=0.449679
# Month=5, Predicted=0.335867, Expected=0.429707
# Month=6, Predicted=0.343058, Expected=0.470811
# Month=7, Predicted=0.334100, Expected=0.456041
# Month=8, Predicted=0.343214, Expected=0.501017
# Month=9, Predicted=0.335398, Expected=0.486846
# Month=10, Predicted=0.330678, Expected=0.397051
# Month=11, Predicted=0.318134, Expected=0.450149
# Month=12, Predicted=0.323011, Expected=0.551885
# Month=13, Predicted=0.324334, Expected=0.440463
# Month=14, Predicted=0.350460, Expected=0.529397
# Month=15, Predicted=0.338586, Expected=0.457762
# Month=16, Predicted=0.350892, Expected=0.505866
# Month=17, Predicted=0.348854, Expected=0.467565
# Month=18, Predicted=0.352868, Expected=0.494955
# Month=19, Predicted=0.342743, Expected=0.458883
# Month=20, Predicted=0.352263, Expected=0.520063
# Month=21, Predicted=0.343954, Expected=0.433801
# Month=22, Predicted=0.345389, Expected=0.375932
# Month=23, Predicted=0.342929, Expected=0.428404
# Month=24, Predicted=0.351936, Expected=0.518746
# Month=25, Predicted=0.361657, Expected=0.479037
# Month=26, Predicted=0.368476, Expected=0.541117
# Month=27, Predicted=0.361882, Expected=0.480693
# Month=28, Predicted=0.363448, Expected=0.510938
# Month=29, Predicted=0.361011, Expected=0.473758
# Month=30, Predicted=0.364599, Expected=0.522318
# Month=31, Predicted=0.361479, Expected=0.504641
# Month=32, Predicted=0.366983, Expected=0.584789
# Month=33, Predicted=0.356375, Expected=0.522292
# Month=34, Predicted=0.352945, Expected=0.488450
# Month=35, Predicted=0.349458, Expected=0.556995
# Month=36, Predicted=0.349124, Expected=0.594984
# Month=37, Predicted=0.357428, Expected=0.554740
# Month=38, Predicted=0.368074, Expected=0.650780
# Month=39, Predicted=0.367962, Expected=0.565873
# Month=40, Predicted=0.379696, Expected=0.610966
# Month=41, Predicted=0.377951, Expected=0.573200
# Month=42, Predicted=0.380814, Expected=0.617263
# Month=43, Predicted=0.366358, Expected=0.599351
# Month=44, Predicted=0.361061, Expected=0.597369
# Month=45, Predicted=0.348551, Expected=0.543646
# Month=46, Predicted=0.346051, Expected=0.491474
# Month=47, Predicted=0.346495, Expected=0.532943
# Month=48, Predicted=0.348649, Expected=0.624655
# Month=49, Predicted=0.358551, Expected=0.567803
# Month=50, Predicted=0.376105, Expected=0.719390
# Month=51, Predicted=0.374812, Expected=0.622047
# Month=52, Predicted=0.381539, Expected=0.652579
# Month=53, Predicted=0.375934, Expected=0.579353
# Month=54, Predicted=0.375760, Expected=0.570749
# Month=55, Predicted=0.363602, Expected=0.541534
# Month=56, Predicted=0.364110, Expected=0.570801
# Month=57, Predicted=0.354150, Expected=0.564935
# Month=58, Predicted=0.349188, Expected=0.514470
# Month=59, Predicted=0.344270, Expected=0.533021
# Month=60, Predicted=0.343414, Expected=0.599625
# Month=61, Predicted=0.354671, Expected=0.536685
# Month=62, Predicted=0.374830, Expected=0.672850
# Month=63, Predicted=0.379785, Expected=0.604487
# Month=64, Predicted=0.387315, Expected=0.667062
# Month=65, Predicted=0.379972, Expected=0.582638
# Month=66, Predicted=0.374933, Expected=0.594553
# Month=67, Predicted=0.360973, Expected=0.559133
# Month=68, Predicted=0.357226, Expected=0.557399
# Month=69, Predicted=0.347359, Expected=0.541052
# Month=70, Predicted=0.343175, Expected=0.472858
# Month=71, Predicted=0.341595, Expected=0.538444
# Month=72, Predicted=0.347648, Expected=0.616781
# Month=73, Predicted=0.360996, Expected=0.593862
# Month=74, Predicted=0.377846, Expected=0.696172
# Month=75, Predicted=0.374872, Expected=0.619375
# Month=76, Predicted=0.384927, Expected=0.634536
# Month=77, Predicted=0.376905, Expected=0.546240
# Month=78, Predicted=0.376799, Expected=0.576993
# Month=79, Predicted=0.362052, Expected=0.533243
# Month=80, Predicted=0.360425, Expected=0.575950
# Month=81, Predicted=0.348585, Expected=0.509986
# Month=82, Predicted=0.345024, Expected=0.494016
# Month=83, Predicted=0.333826, Expected=0.512737
# Month=84, Predicted=0.336259, Expected=0.609063
# Month=85, Predicted=0.356671, Expected=0.534586
# Month=86, Predicted=0.379395, Expected=0.687986
# Month=87, Predicted=0.375659, Expected=0.612348
# Month=88, Predicted=0.384040, Expected=0.645409
# Month=89, Predicted=0.387960, Expected=0.564061
# Month=90, Predicted=0.387035, Expected=0.577802
# Month=91, Predicted=0.367236, Expected=0.529736
# Month=92, Predicted=0.361743, Expected=0.572626
# Month=93, Predicted=0.347643, Expected=0.496402
# Month=94, Predicted=0.342092, Expected=0.423280
# Month=95, Predicted=0.340333, Expected=0.525512
# Month=96, Predicted=0.343693, Expected=0.617615
# Month=97, Predicted=0.354052, Expected=0.557465
# Month=98, Predicted=0.371148, Expected=0.657572
# Month=99, Predicted=0.376681, Expected=0.619088
# Month=100, Predicted=0.392792, Expected=0.686030
# Month=101, Predicted=0.383069, Expected=0.586197
# Month=102, Predicted=0.380765, Expected=0.596378
# Month=103, Predicted=0.365701, Expected=0.559577
# Month=104, Predicted=0.360965, Expected=0.570045
# Month=105, Predicted=0.348777, Expected=0.499205
# Month=106, Predicted=0.346043, Expected=0.489467
# Month=107, Predicted=0.343924, Expected=0.531991
# Month=108, Predicted=0.345567, Expected=0.611136
# Month=109, Predicted=0.357733, Expected=0.556487
# Month=110, Predicted=0.380531, Expected=0.703642
# Month=111, Predicted=0.386416, Expected=0.618345
# Month=112, Predicted=0.391652, Expected=0.649020
# Month=113, Predicted=0.383168, Expected=0.589495
# Month=114, Predicted=0.378058, Expected=0.583042
# Month=115, Predicted=0.365157, Expected=0.560776
# Month=116, Predicted=0.362747, Expected=0.573630
# Month=117, Predicted=0.350993, Expected=0.539031
# Month=118, Predicted=0.346033, Expected=0.494277
# Month=119, Predicted=0.342753, Expected=0.539527
# Month=120, Predicted=0.351434, Expected=0.612844
# Month=121, Predicted=0.367447, Expected=0.626806
# Month=122, Predicted=0.383862, Expected=0.741800
# Month=123, Predicted=0.382255, Expected=0.638538
# Month=124, Predicted=0.394074, Expected=0.683436
# Month=125, Predicted=0.385397, Expected=0.568676
# Month=126, Predicted=0.384324, Expected=0.617954
# Month=127, Predicted=0.369992, Expected=0.580878
# Month=128, Predicted=0.364769, Expected=0.598269
# Month=129, Predicted=0.355632, Expected=0.549030
# Month=130, Predicted=0.354871, Expected=0.536463
# Month=131, Predicted=0.351766, Expected=0.573473
# Month=132, Predicted=0.351756, Expected=0.644131
# Month=133, Predicted=0.366580, Expected=0.608763
# Month=134, Predicted=0.385337, Expected=0.737263
# Month=135, Predicted=0.386839, Expected=0.690215
# Month=136, Predicted=0.392662, Expected=0.705624
# Month=137, Predicted=0.383164, Expected=0.645435
# Month=138, Predicted=0.376301, Expected=0.629165
# Month=139, Predicted=0.358611, Expected=0.600707
# Month=140, Predicted=0.359500, Expected=0.651014
# Month=141, Predicted=0.356455, Expected=0.615307
# Month=142, Predicted=0.361602, Expected=0.551690
# Month=143, Predicted=0.358756, Expected=0.618905
# Month=144, Predicted=0.365871, Expected=0.695990
# Month=145, Predicted=0.387987, Expected=0.618384
# Month=146, Predicted=0.411046, Expected=0.797283
# Month=147, Predicted=0.395404, Expected=0.663699
# Month=148, Predicted=0.399585, Expected=0.716953
# Month=149, Predicted=0.386289, Expected=0.570931
# Month=150, Predicted=0.380291, Expected=0.561897
# Month=151, Predicted=0.373360, Expected=0.591764
# Month=152, Predicted=0.375283, Expected=0.708049
# Month=153, Predicted=0.363448, Expected=0.631681
# Month=154, Predicted=0.361177, Expected=0.600993
# Month=155, Predicted=0.358967, Expected=0.675066
# Month=156, Predicted=0.360604, Expected=0.747393
# Month=157, Predicted=0.374663, Expected=0.701635
# Month=158, Predicted=0.398954, Expected=0.845961
# Month=159, Predicted=0.403393, Expected=0.790165
# Month=160, Predicted=0.405601, Expected=0.798665
# Month=161, Predicted=0.398687, Expected=0.712533
# Month=162, Predicted=0.396479, Expected=0.731162
# Month=163, Predicted=0.385186, Expected=0.686330
# Month=164, Predicted=0.383560, Expected=0.724383
# Month=165, Predicted=0.372233, Expected=0.677583
# Month=166, Predicted=0.365193, Expected=0.620326
# Month=167, Predicted=0.357721, Expected=0.683710
# Month=168, Predicted=0.361233, Expected=0.745972
# Month=169, Predicted=0.381968, Expected=0.758539
# Month=170, Predicted=0.400690, Expected=0.854070
# Month=171, Predicted=0.400233, Expected=0.774717
# Month=172, Predicted=0.416398, Expected=0.809889
# Month=173, Predicted=0.412332, Expected=0.740953
# Month=174, Predicted=0.410141, Expected=0.770467
# Month=175, Predicted=0.390316, Expected=0.755514
# Month=176, Predicted=0.385463, Expected=0.767977
# Month=177, Predicted=0.370731, Expected=0.657180
# Month=178, Predicted=0.367703, Expected=0.622986
# Month=179, Predicted=0.368820, Expected=0.692222
# Month=180, Predicted=0.375496, Expected=0.830409
# Month=181, Predicted=0.389741, Expected=0.759973
# Month=182, Predicted=0.404145, Expected=0.935065
# Month=183, Predicted=0.401819, Expected=0.840382
# Month=184, Predicted=0.409691, Expected=0.867654
# Month=185, Predicted=0.402413, Expected=0.768290
# Month=186, Predicted=0.400627, Expected=0.784299
# Month=187, Predicted=0.388569, Expected=0.780857
# Month=188, Predicted=0.390391, Expected=0.788914
# Month=189, Predicted=0.381850, Expected=0.767599
# Month=190, Predicted=0.378764, Expected=0.725244
# Month=191, Predicted=0.374290, Expected=0.778276
# Month=192, Predicted=0.374521, Expected=0.832312
# Month=193, Predicted=0.390099, Expected=0.752425
# Month=194, Predicted=0.408358, Expected=0.917375
# Month=195, Predicted=0.407762, Expected=0.832064
# Month=196, Predicted=0.423397, Expected=0.879960
# Month=197, Predicted=0.415341, Expected=0.789122
# Month=198, Predicted=0.411556, Expected=0.803410
# Month=199, Predicted=0.394901, Expected=0.805627
# Month=200, Predicted=0.394539, Expected=0.805783
# Month=201, Predicted=0.381030, Expected=0.758708
# Month=202, Predicted=0.377720, Expected=0.718517
# Month=203, Predicted=0.374053, Expected=0.771145
# Month=204, Predicted=0.374907, Expected=0.898772
# Month=205, Predicted=0.388263, Expected=0.785746
# Month=206, Predicted=0.419622, Expected=1.000000
# Month=207, Predicted=0.417126, Expected=0.902083
# Month=208, Predicted=0.424906, Expected=0.941623
# Month=209, Predicted=0.416334, Expected=0.815586
# Month=210, Predicted=0.414590, Expected=0.872947
# Month=211, Predicted=0.398727, Expected=0.816668
# Month=212, Predicted=0.393998, Expected=0.853288
# Month=213, Predicted=0.379653, Expected=0.788718
# Month=214, Predicted=0.373052, Expected=0.729872
# Month=215, Predicted=0.369321, Expected=0.770363
# Month=216, Predicted=0.376081, Expected=0.908171
# Month=217, Predicted=0.391723, Expected=0.870691
# Month=218, Predicted=0.409628, Expected=0.977968
# Month=219, Predicted=0.412128, Expected=0.928808
# Month=220, Predicted=0.421868, Expected=0.916788
# Month=221, Predicted=0.416878, Expected=0.836601
# Month=222, Predicted=0.410861, Expected=0.872256
# Month=223, Predicted=0.394430, Expected=0.794611
# Month=224, Predicted=0.392853, Expected=0.844058
# Month=225, Predicted=0.377709, Expected=0.753950
# Month=226, Predicted=0.372027, Expected=0.698402
# Month=227, Predicted=0.368209, Expected=0.795641
# Month=228, Predicted=0.371586, Expected=0.845479
# Month=229, Predicted=0.386080, Expected=0.805757
# Month=230, Predicted=0.405209, Expected=0.957671
# Month=231, Predicted=0.405132, Expected=0.876310
# Month=232, Predicted=0.423126, Expected=0.892019
# Month=233, Predicted=0.414859, Expected=0.806044
# Month=234, Predicted=0.414358, Expected=0.828440
# Month=235, Predicted=0.396634, Expected=0.800399
# Month=236, Predicted=0.392488, Expected=0.806800
# Month=237, Predicted=0.377042, Expected=0.709665
# Month=238, Predicted=0.371787, Expected=0.719482
# Month=239, Predicted=0.366668, Expected=0.733783
# Month=240, Predicted=0.365558, Expected=0.845961
# Month=241, Predicted=0.375468, Expected=0.760990
# Month=242, Predicted=0.396522, Expected=0.948819
# Month=243, Predicted=0.401291, Expected=0.868384
# Month=244, Predicted=0.412884, Expected=0.901588
# Month=245, Predicted=0.409019, Expected=0.822704
# Month=246, Predicted=0.408322, Expected=0.827463
# Month=247, Predicted=0.391681, Expected=0.799356
# Month=248, Predicted=0.386107, Expected=0.786150
# Month=249, Predicted=0.372204, Expected=0.734500
# Month=250, Predicted=0.366696, Expected=0.685457
# Month=251, Predicted=0.361300, Expected=0.708140
# Month=252, Predicted=0.361357, Expected=0.791221
# Month=253, Predicted=0.375621, Expected=0.752242
# Month=254, Predicted=0.397691, Expected=0.885514
# Month=255, Predicted=0.397271, Expected=0.806930
# Month=256, Predicted=0.404606, Expected=0.857472
# Month=257, Predicted=0.397727, Expected=0.757535
# Month=258, Predicted=0.395489, Expected=0.769855
# Month=259, Predicted=0.377980, Expected=0.731332
# Month=260, Predicted=0.374247, Expected=0.735999
# Month=261, Predicted=0.363150, Expected=0.697828
# Month=262, Predicted=0.354203, Expected=0.632268
# Month=263, Predicted=0.349503, Expected=0.671286
# Month=264, Predicted=0.355673, Expected=0.790426
# Month=265, Predicted=0.373456, Expected=0.721776
# Month=266, Predicted=0.388413, Expected=0.829131
# Month=267, Predicted=0.385195, Expected=0.757913
# Month=268, Predicted=0.399406, Expected=0.780010
# Month=269, Predicted=0.391970, Expected=0.688781
# Month=270, Predicted=0.386301, Expected=0.695364
# Month=271, Predicted=0.370215, Expected=0.678821
# Month=272, Predicted=0.366139, Expected=0.661939
# Month=273, Predicted=0.350373, Expected=0.572404
# Month=274, Predicted=0.346459, Expected=0.547153
# Month=275, Predicted=0.344331, Expected=0.618671
# Month=276, Predicted=0.346091, Expected=0.722480
# Month=277, Predicted=0.351075, Expected=0.608867
# Month=278, Predicted=0.366371, Expected=0.768421
# Month=279, Predicted=0.366555, Expected=0.679212
# Month=280, Predicted=0.378888, Expected=0.693683
# Month=281, Predicted=0.375516, Expected=0.598360
# Month=282, Predicted=0.378281, Expected=0.655577
# Month=283, Predicted=0.366450, Expected=0.571335
# Month=284, Predicted=0.364303, Expected=0.595309
# Month=285, Predicted=0.338864, Expected=0.530323
# Month=286, Predicted=0.324665, Expected=0.468256
# Month=287, Predicted=0.320203, Expected=0.504093
# Month=288, Predicted=0.331562, Expected=0.544089
# Month=289, Predicted=0.345585, Expected=0.484291
# Month=290, Predicted=0.357359, Expected=0.624185
# Month=291, Predicted=0.360477, Expected=0.564856
# Month=292, Predicted=0.378200, Expected=0.571466
# Month=293, Predicted=0.373269, Expected=0.536293
# Month=294, Predicted=0.360005, Expected=0.554088
# Month=295, Predicted=0.343336, Expected=0.484630
# Month=296, Predicted=0.333544, Expected=0.445051
# Month=297, Predicted=0.319432, Expected=0.411170
# Month=298, Predicted=0.321420, Expected=0.421899
# Month=299, Predicted=0.320080, Expected=0.520272
# Month=300, Predicted=0.317113, Expected=0.529397
# Month=301, Predicted=0.313472, Expected=0.457671
# Month=302, Predicted=0.338573, Expected=0.591724
# Month=303, Predicted=0.329274, Expected=0.521249
# Month=304, Predicted=0.337152, Expected=0.537675
# Month=305, Predicted=0.325944, Expected=0.475400
# Month=306, Predicted=0.328354, Expected=0.498996
# Month=307, Predicted=0.309726, Expected=0.443044
# Month=308, Predicted=0.299824, Expected=0.462533
# Month=309, Predicted=0.269525, Expected=0.413334
# Month=310, Predicted=0.255813, Expected=0.389699
# Month=311, Predicted=0.242650, Expected=0.393883
# Month=312, Predicted=0.243048, Expected=0.449210
# Month=313, Predicted=0.246299, Expected=0.407076
# Month=314, Predicted=0.266487, Expected=0.478373
# Month=315, Predicted=0.262053, Expected=0.412395
# Month=316, Predicted=0.281317, Expected=0.445573
# Month=317, Predicted=0.274873, Expected=0.403882
# Month=318, Predicted=0.270319, Expected=0.391185
# Month=319, Predicted=0.249103, Expected=0.307399
# Month=320, Predicted=0.245466, Expected=0.272292
# Month=321, Predicted=0.224018, Expected=0.244225
# Month=322, Predicted=0.214743, Expected=0.216275
# Month=323, Predicted=0.205217, Expected=0.230041
# Month=324, Predicted=0.210430, Expected=0.320592
# Month=325, Predicted=0.209241, Expected=0.232805
# Month=326, Predicted=0.230782, Expected=0.337331
# Month=327, Predicted=0.226279, Expected=0.278602
# Month=328, Predicted=0.246284, Expected=0.303097
# Month=329, Predicted=0.251568, Expected=0.278159
# Month=330, Predicted=0.254476, Expected=0.304349
# Month=331, Predicted=0.235234, Expected=0.264001
# Month=332, Predicted=0.238624, Expected=0.237733
# Month=333, Predicted=0.223444, Expected=0.215010
# Month=334, Predicted=0.214308, Expected=0.178925
# Month=335, Predicted=0.197013, Expected=0.190254
# Month=336, Predicted=0.201017, Expected=0.291117
# Month=337, Predicted=0.196390, Expected=0.192666
# Month=338, Predicted=0.222656, Expected=0.319263
# Month=339, Predicted=0.215019, Expected=0.265735
# Month=340, Predicted=0.235363, Expected=0.320201
# Month=341, Predicted=0.234708, Expected=0.243534
# Month=342, Predicted=0.241888, Expected=0.293346
# Month=343, Predicted=0.229031, Expected=0.270037
# Month=344, Predicted=0.231628, Expected=0.266309
# Month=345, Predicted=0.210449, Expected=0.213224
# Month=346, Predicted=0.196092, Expected=0.162082
# Month=347, Predicted=0.182400, Expected=0.166867
# Month=348, Predicted=0.192620, Expected=0.267977
# Month=349, Predicted=0.197623, Expected=0.190280
# Month=350, Predicted=0.221987, Expected=0.277624
# Month=351, Predicted=0.222059, Expected=0.254915
# Month=352, Predicted=0.235739, Expected=0.270324
# Month=353, Predicted=0.232881, Expected=0.224396
# Month=354, Predicted=0.239706, Expected=0.269268
# Month=355, Predicted=0.227071, Expected=0.228346
# Month=356, Predicted=0.227909, Expected=0.222011
# Month=357, Predicted=0.213484, Expected=0.172042
# Month=358, Predicted=0.207880, Expected=0.138460
# Month=359, Predicted=0.197488, Expected=0.186421
# Month=360, Predicted=0.201899, Expected=0.273061
# Month=361, Predicted=0.198825, Expected=0.212377
# Month=362, Predicted=0.213112, Expected=0.301416
# Month=363, Predicted=0.209991, Expected=0.234552
# Month=364, Predicted=0.233594, Expected=0.272071
# Month=365, Predicted=0.239412, Expected=0.247080
# Month=366, Predicted=0.253348, Expected=0.276712
# Month=367, Predicted=0.242997, Expected=0.259921
# Month=368, Predicted=0.242671, Expected=0.273635
# Month=369, Predicted=0.222653, Expected=0.205885
# Month=370, Predicted=0.217181, Expected=0.173267
# Month=371, Predicted=0.201484, Expected=0.180985
# Month=372, Predicted=0.200788, Expected=0.232283
# Month=373, Predicted=0.201166, Expected=0.182015
# Month=374, Predicted=0.222531, Expected=0.309107
# Month=375, Predicted=0.221440, Expected=0.251017
# Month=376, Predicted=0.246317, Expected=0.317190
# Month=377, Predicted=0.249567, Expected=0.279658
# Month=378, Predicted=0.251585, Expected=0.275108
# Month=379, Predicted=0.241775, Expected=0.262815
# Month=380, Predicted=0.242101, Expected=0.271771
# Month=381, Predicted=0.223135, Expected=0.230015
# Month=382, Predicted=0.214541, Expected=0.191193
# Month=383, Predicted=0.200134, Expected=0.202156
# Month=384, Predicted=0.201348, Expected=0.255749
# Month=385, Predicted=0.204435, Expected=0.207410
# Month=386, Predicted=0.223867, Expected=0.315456
# Month=387, Predicted=0.219784, Expected=0.276112
# Month=388, Predicted=0.242398, Expected=0.320762
# Month=389, Predicted=0.246508, Expected=0.268095
# Month=390, Predicted=0.248237, Expected=0.291391
# Month=391, Predicted=0.236190, Expected=0.252607
# Month=392, Predicted=0.246168, Expected=0.258148
# Month=393, Predicted=0.233000, Expected=0.220981
# Month=394, Predicted=0.224302, Expected=0.170882
# Month=395, Predicted=0.215237, Expected=0.207449
# Month=396, Predicted=0.216904, Expected=0.263584
# Month=397, Predicted=0.215303, Expected=0.187999
# Month=398, Predicted=0.239874, Expected=0.295341
# Month=399, Predicted=0.237193, Expected=0.266856
# Month=400, Predicted=0.252034, Expected=0.307269
# Month=401, Predicted=0.256019, Expected=0.247588
# Month=402, Predicted=0.269633, Expected=0.304179
# Month=403, Predicted=0.264924, Expected=0.291156
# Month=404, Predicted=0.270093, Expected=0.288158
# Month=405, Predicted=0.254410, Expected=0.262958
# Month=406, Predicted=0.245770, Expected=0.215336
# Month=407, Predicted=0.235385, Expected=0.226704
# Month=408, Predicted=0.241788, Expected=0.316251
# Month=409, Predicted=0.237535, Expected=0.260116
# Month=410, Predicted=0.248683, Expected=0.330943
# Month=411, Predicted=0.246834, Expected=0.311350
# Month=412, Predicted=0.262478, Expected=0.354070
# Month=413, Predicted=0.262610, Expected=0.316838
# Month=414, Predicted=0.269105, Expected=0.382750
# Month=415, Predicted=0.267766, Expected=0.328871
# Month=416, Predicted=0.277384, Expected=0.332677
# Month=417, Predicted=0.266854, Expected=0.308208
# Month=418, Predicted=0.253546, Expected=0.251134
# Month=419, Predicted=0.242217, Expected=0.297127
# Month=420, Predicted=0.237702, Expected=0.309016
# Month=421, Predicted=0.238002, Expected=0.271041
# Month=422, Predicted=0.247155, Expected=0.343497
# Month=423, Predicted=0.241860, Expected=0.311336
# Month=424, Predicted=0.256081, Expected=0.318337
# Month=425, Predicted=0.257336, Expected=0.312797
# Month=426, Predicted=0.267459, Expected=0.372165
# Month=427, Predicted=0.270487, Expected=0.349859
# Month=428, Predicted=0.279983, Expected=0.352949
# Month=429, Predicted=0.261057, Expected=0.284859
# Month=430, Predicted=0.254311, Expected=0.240796
# Month=431, Predicted=0.244642, Expected=0.275591
# Month=432, Predicted=0.240848, Expected=0.314087
# Month=433, Predicted=0.233235, Expected=0.251082
# Month=434, Predicted=0.241494, Expected=0.354396
# Month=435, Predicted=0.231911, Expected=0.294832
# Month=436, Predicted=0.240867, Expected=0.303228
# Month=437, Predicted=0.247727, Expected=0.316395
# Month=438, Predicted=0.260136, Expected=0.366767
# Month=439, Predicted=0.258220, Expected=0.343993
# Month=440, Predicted=0.266035, Expected=0.352727
# Month=441, Predicted=0.252925, Expected=0.305900
# Month=442, Predicted=0.240340, Expected=0.251903
# Month=443, Predicted=0.224173, Expected=0.276177
# Month=444, Predicted=0.218307, Expected=0.282135
# Month=445, Predicted=0.212904, Expected=0.235399
# Month=446, Predicted=0.222889, Expected=0.317659
# Month=447, Predicted=0.221299, Expected=0.258161
# Month=448, Predicted=0.234699, Expected=0.311923
# Month=449, Predicted=0.235042, Expected=0.286385
# Month=450, Predicted=0.244570, Expected=0.312158
# Month=451, Predicted=0.249226, Expected=0.317685
# Month=452, Predicted=0.252828, Expected=0.299630
# Month=453, Predicted=0.237113, Expected=0.246976
# Month=454, Predicted=0.228201, Expected=0.206106
# Month=455, Predicted=0.217702, Expected=0.222610
# Month=456, Predicted=0.213131, Expected=0.235908
# Month=457, Predicted=0.213059, Expected=0.231658
# Month=458, Predicted=0.221557, Expected=0.292864
# Month=459, Predicted=0.214852, Expected=0.231306
# Month=460, Predicted=0.232886, Expected=0.280753
# Month=461, Predicted=0.237049, Expected=0.253963
# Month=462, Predicted=0.243139, Expected=0.309368
# Month=463, Predicted=0.239375, Expected=0.298509
# Month=464, Predicted=0.250473, Expected=0.276451
# Month=465, Predicted=0.238805, Expected=0.258943
# Month=466, Predicted=0.231491, Expected=0.212051
# Month=467, Predicted=0.216285, Expected=0.211151
# Month=468, Predicted=0.213756, Expected=0.271315
# Month=469, Predicted=0.207838, Expected=0.198128
# Month=470, Predicted=0.230668, Expected=0.299982
# Month=471, Predicted=0.222342, Expected=0.264158
# Month=472, Predicted=0.237878, Expected=0.289592
# Month=473, Predicted=0.244504, Expected=0.229481
# Month=474, Predicted=0.260851, Expected=0.318363
# Month=475, Predicted=0.253305, Expected=0.282995
# Month=476, Predicted=0.265091, Expected=0.298717
# Month=477, Predicted=0.257178, Expected=0.266283
# Month=478, Predicted=0.246183, Expected=0.197176
# Month=479, Predicted=0.230147, Expected=0.196433
# Month=480, Predicted=0.232705, Expected=0.291573
# Month=481, Predicted=0.232118, Expected=0.220811
# Month=482, Predicted=0.239798, Expected=0.293151
# Month=483, Predicted=0.235396, Expected=0.306383
# Month=484, Predicted=0.247166, Expected=0.310098
# Month=485, Predicted=0.257056, Expected=0.291273
# Month=486, Predicted=0.272665, Expected=0.338830
# Month=487, Predicted=0.279307, Expected=0.328675
# Month=488, Predicted=0.290576, Expected=0.356782
# Month=489, Predicted=0.273028, Expected=0.306865
# Month=490, Predicted=0.258250, Expected=0.227916
# Month=491, Predicted=0.246113, Expected=0.289096
# Month=492, Predicted=0.238543, Expected=0.309798
# Month=493, Predicted=0.237035, Expected=0.234917
# Month=494, Predicted=0.257133, Expected=0.330265
# Month=495, Predicted=0.255726, Expected=0.295067
# Month=496, Predicted=0.269809, Expected=0.344592
# Month=497, Predicted=0.275240, Expected=0.354904
# Month=498, Predicted=0.288678, Expected=0.395448
# Month=499, Predicted=0.279206, Expected=0.362830
# Month=500, Predicted=0.288932, Expected=0.363886
# Month=501, Predicted=0.277097, Expected=0.299890
# Month=502, Predicted=0.269823, Expected=0.248827
# Month=503, Predicted=0.252746, Expected=0.278328
# Month=504, Predicted=0.259173, Expected=0.354513
# Month=505, Predicted=0.254714, Expected=0.305431
# Month=506, Predicted=0.261019, Expected=0.392919
# Month=507, Predicted=0.247060, Expected=0.295328
# Month=508, Predicted=0.265199, Expected=0.374850
# Month=509, Predicted=0.264397, Expected=0.324868
# Month=510, Predicted=0.277688, Expected=0.383376
# Month=511, Predicted=0.285376, Expected=0.398029
# Month=512, Predicted=0.299901, Expected=0.400688
# Month=513, Predicted=0.278954, Expected=0.322404
# Month=514, Predicted=0.265197, Expected=0.284494
# Month=515, Predicted=0.252833, Expected=0.308077
# Month=516, Predicted=0.253522, Expected=0.324790
# Month=517, Predicted=0.253158, Expected=0.278002
# Month=518, Predicted=0.262941, Expected=0.354891
# Month=519, Predicted=0.255650, Expected=0.304949
# Month=520, Predicted=0.269688, Expected=0.348986
# Month=521, Predicted=0.274588, Expected=0.323134
# Month=522, Predicted=0.286958, Expected=0.402370
# Month=523, Predicted=0.286783, Expected=0.391107
# Month=524, Predicted=0.301966, Expected=0.350459
# Month=525, Predicted=0.293758, Expected=0.312210
# Month=526, Predicted=0.285818, Expected=0.274978
# Month=527, Predicted=0.271392, Expected=0.315704
# Month=528, Predicted=0.265252, Expected=0.363456
# Month=529, Predicted=0.252695, Expected=0.294246
# Month=530, Predicted=0.257163, Expected=0.374276
# Month=531, Predicted=0.240070, Expected=0.321922
# Month=532, Predicted=0.246447, Expected=0.373442
# Month=533, Predicted=0.247715, Expected=0.327893
# Month=534, Predicted=0.266642, Expected=0.432523
# Month=535, Predicted=0.270304, Expected=0.438585
# Month=536, Predicted=0.282555, Expected=0.422759
# Month=537, Predicted=0.267567, Expected=0.375919
# Month=538, Predicted=0.248760, Expected=0.294141
# Month=539, Predicted=0.227395, Expected=0.291143
# Month=540, Predicted=0.224711, Expected=0.340043
# Month=541, Predicted=0.215428, Expected=0.239949
# Month=542, Predicted=0.229998, Expected=0.303749
# Month=543, Predicted=0.221863, Expected=0.265396
# Month=544, Predicted=0.228766, Expected=0.293633
# Month=545, Predicted=0.229547, Expected=0.271732
# Month=546, Predicted=0.247012, Expected=0.340238
# Month=547, Predicted=0.246918, Expected=0.315156
# Month=548, Predicted=0.255065, Expected=0.314309
# Month=549, Predicted=0.238167, Expected=0.234474
# Month=550, Predicted=0.226271, Expected=0.196329
# Month=551, Predicted=0.208734, Expected=0.209013
# Month=552, Predicted=0.210671, Expected=0.280649
# Month=553, Predicted=0.212315, Expected=0.239988
# Month=554, Predicted=0.220017, Expected=0.275512
# Month=555, Predicted=0.207765, Expected=0.224462
# Month=556, Predicted=0.220102, Expected=0.257118
# Month=557, Predicted=0.223341, Expected=0.254185
# Month=558, Predicted=0.237792, Expected=0.320879
# Month=559, Predicted=0.240766, Expected=0.302498
# Month=560, Predicted=0.251994, Expected=0.298574
# Month=561, Predicted=0.232321, Expected=0.217839
# Month=562, Predicted=0.221142, Expected=0.175549
# Month=563, Predicted=0.206801, Expected=0.204242
# Month=564, Predicted=0.204355, Expected=0.282761
# Month=565, Predicted=0.194671, Expected=0.199640
# Month=566, Predicted=0.201122, Expected=0.271966
# Month=567, Predicted=0.190921, Expected=0.221972
# Month=568, Predicted=0.202920, Expected=0.229728
# Month=569, Predicted=0.216876, Expected=0.251564
# Month=570, Predicted=0.232619, Expected=0.313696
# Month=571, Predicted=0.232278, Expected=0.295015
# Month=572, Predicted=0.237668, Expected=0.286737
# Month=573, Predicted=0.219364, Expected=0.220603
# Month=574, Predicted=0.203464, Expected=0.159736
# Month=575, Predicted=0.190439, Expected=0.179017
# Month=576, Predicted=0.190493, Expected=0.216900
# Month=577, Predicted=0.187157, Expected=0.156203
# Month=578, Predicted=0.192879, Expected=0.230119
# Month=579, Predicted=0.187158, Expected=0.207892
# Month=580, Predicted=0.193680, Expected=0.231958
# Month=581, Predicted=0.192691, Expected=0.226847
# Month=582, Predicted=0.207593, Expected=0.259738
# Month=583, Predicted=0.221652, Expected=0.248357
# Month=584, Predicted=0.233050, Expected=0.232075
# Month=585, Predicted=0.219953, Expected=0.184896
# Month=586, Predicted=0.216954, Expected=0.153726
# Month=587, Predicted=0.207797, Expected=0.187699
# Month=588, Predicted=0.196658, Expected=0.206915
# Month=589, Predicted=0.185012, Expected=0.145461
# Month=590, Predicted=0.192847, Expected=0.213081
# Month=591, Predicted=0.183871, Expected=0.133624
# Month=592, Predicted=0.191282, Expected=0.179603

# %%
# Skalierung zurücksetzten
predictions_train_100=np.reshape(predictions_train_100,(len(predictions_train_100),1))
predictions_train_100=scaler.inverse_transform(predictions_train_100)

# %%
# Verschiebung der Trainingsvorhersage zum Plotten
trainPredictPlot = np.empty_like(ZR_100)
trainPredictPlot=trainPredictPlot.reshape(len(ZR_100))
trainPredictPlot[:]=[0]*len(ZR_100)
predictions_train_100=predictions_train_100.reshape(len(predictions_train_100))
trainPredictPlot[(look_back+look_forward-1):len(predictions_train_100)+(look_back+look_forward-1)] = predictions_train_100

# Verschiebung der Testvorhersage zum Plotten
testPredictPlot = np.empty_like(ZR_100)
testPredictPlot=testPredictPlot.reshape(len(ZR_100))
testPredictPlot[:]=[0]*len(ZR_100)
predictions_100=predictions_100.reshape(len(predictions_100))
testPredictPlot[-len(predictions_100):] = predictions_100

# Plotten der baseline und  der Vorhersagen
plt.plot(ZR_100, color='blue')
plt.plot(trainPredictPlot, color='orange') 
plt.plot(testPredictPlot, color='green')
plt.show()

# %%
# Replizierbarkeit gewährleisten
np.random.seed(0)

# %%
# Modell anpassen: 46% der originalen Datensatzstärke
lstm_model_46 = fit_lstm(ZR_N46_TR_I, 1, 30, 4)

# %%
# Validierung des Modells anhand der Testdaten
predictions_46 = list()
for i in range(len(ZR_N46_TE_I)):
    # Vorhersage erzeugen 
    X, y = ZR_N46_TE_I.iloc[i, 0:-1], ZR_N46_TE_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_46, 1, X)
    predictions_46.append(yhat)
    expected = ZR_N46[len(ZR_N46_TR_I) + i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.091628, Expected=0.159162
# Month=2, Predicted=0.125609, Expected=0.225074
# Month=3, Predicted=0.136033, Expected=0.211464
# Month=4, Predicted=0.132424, Expected=0.192770
# Month=5, Predicted=0.126082, Expected=0.136283
# Month=6, Predicted=0.118498, Expected=0.086679
# Month=7, Predicted=0.111294, Expected=0.118332
# Month=8, Predicted=0.108300, Expected=0.122777
# Month=9, Predicted=0.107570, Expected=0.068376
# Month=10, Predicted=0.104008, Expected=0.119297
# Month=11, Predicted=0.106802, Expected=0.101215
# Month=12, Predicted=0.113302, Expected=0.116624
# Month=13, Predicted=0.125166, Expected=0.133311
# Month=14, Predicted=0.131694, Expected=0.176657
# Month=15, Predicted=0.134402, Expected=0.176722
# Month=16, Predicted=0.130696, Expected=0.166215
# Month=17, Predicted=0.126132, Expected=0.110797
# Month=18, Predicted=0.120788, Expected=0.063162
# Month=19, Predicted=0.119055, Expected=0.088700
# Month=20, Predicted=0.114972, Expected=0.096196
# Month=21, Predicted=0.113185, Expected=0.044585
# Month=22, Predicted=0.104604, Expected=0.100733
# Month=23, Predicted=0.108515, Expected=0.055144
# Month=24, Predicted=0.120795, Expected=0.134575
# Month=25, Predicted=0.132978, Expected=0.111605
# Month=26, Predicted=0.139695, Expected=0.170673
# Month=27, Predicted=0.141746, Expected=0.164337
# Month=28, Predicted=0.139835, Expected=0.159436
# Month=29, Predicted=0.132527, Expected=0.125111
# Month=30, Predicted=0.124298, Expected=0.059759
# Month=31, Predicted=0.118097, Expected=0.051298
# Month=32, Predicted=0.111295, Expected=0.121995
# Month=33, Predicted=0.105834, Expected=0.041977
# Month=34, Predicted=0.103147, Expected=0.108789
# Month=35, Predicted=0.107383, Expected=0.042694
# Month=36, Predicted=0.116681, Expected=0.109793
# Month=37, Predicted=0.126347, Expected=0.124863
# Month=38, Predicted=0.132014, Expected=0.180568
# Month=39, Predicted=0.133996, Expected=0.190919
# Month=40, Predicted=0.126797, Expected=0.182093
# Month=41, Predicted=0.117373, Expected=0.150701
# Month=42, Predicted=0.111417, Expected=0.084176
# Month=43, Predicted=0.107988, Expected=0.093119
# Month=44, Predicted=0.103655, Expected=0.138173
# Month=45, Predicted=0.100459, Expected=0.071049
# Month=46, Predicted=0.097639, Expected=0.064296
# Month=47, Predicted=0.102031, Expected=0.092924
# Month=48, Predicted=0.112589, Expected=0.123559
# Month=49, Predicted=0.123226, Expected=0.135488
# Month=50, Predicted=0.128092, Expected=0.200696
# Month=51, Predicted=0.128736, Expected=0.169526
# Month=52, Predicted=0.123542, Expected=0.173945
# Month=53, Predicted=0.120982, Expected=0.116507
# Month=54, Predicted=0.118395, Expected=0.049317
# Month=55, Predicted=0.113898, Expected=0.065599
# Month=56, Predicted=0.108058, Expected=0.094319
# Month=57, Predicted=0.105673, Expected=0.028250
# Month=58, Predicted=0.100955, Expected=0.075246
# Month=59, Predicted=0.103112, Expected=0.068533
# Month=60, Predicted=0.109993, Expected=0.086236
# Month=61, Predicted=0.120318, Expected=0.115190
# Month=62, Predicted=0.127625, Expected=0.187360
# Month=63, Predicted=0.132707, Expected=0.155812
# Month=64, Predicted=0.131068, Expected=0.152422
# Month=65, Predicted=0.125438, Expected=0.089169
# Month=66, Predicted=0.117532, Expected=0.044311
# Month=67, Predicted=0.109633, Expected=0.077554
# Month=68, Predicted=0.103349, Expected=0.095857
# Month=69, Predicted=0.099400, Expected=0.031209
# Month=70, Predicted=0.095377, Expected=0.098634
# Month=71, Predicted=0.100844, Expected=0.053449
# Month=72, Predicted=0.111500, Expected=0.106038
# Month=73, Predicted=0.121782, Expected=0.125293
# Month=74, Predicted=0.128264, Expected=0.182484
# Month=75, Predicted=0.131699, Expected=0.155460
# Month=76, Predicted=0.125860, Expected=0.172146
# Month=77, Predicted=0.118422, Expected=0.142045
# Month=78, Predicted=0.113351, Expected=0.086771
# Month=79, Predicted=0.110741, Expected=0.092155
# Month=80, Predicted=0.107651, Expected=0.089717
# Month=81, Predicted=0.104692, Expected=0.033895
# Month=82, Predicted=0.100779, Expected=0.071870
# Month=83, Predicted=0.104748, Expected=0.024391
# Month=84, Predicted=0.113361, Expected=0.093067
# Month=85, Predicted=0.123997, Expected=0.117680
# Month=86, Predicted=0.132868, Expected=0.172720
# Month=87, Predicted=0.138013, Expected=0.167988
# Month=88, Predicted=0.136462, Expected=0.161496
# Month=89, Predicted=0.128904, Expected=0.104513
# Month=90, Predicted=0.120412, Expected=0.049160
# Month=91, Predicted=0.115426, Expected=0.056083
# Month=92, Predicted=0.110570, Expected=0.086145
# Month=93, Predicted=0.109582, Expected=0.043802
# Month=94, Predicted=0.106410, Expected=0.092637
# Month=95, Predicted=0.112267, Expected=0.068298
# Month=96, Predicted=0.126075, Expected=0.114238
# Month=97, Predicted=0.142120, Expected=0.099142
# Month=98, Predicted=0.150814, Expected=0.175027
# Month=99, Predicted=0.153731, Expected=0.179303
# Month=100, Predicted=0.148434, Expected=0.152461
# Month=101, Predicted=0.141706, Expected=0.129530
# Month=102, Predicted=0.135619, Expected=0.073917
# Month=103, Predicted=0.132361, Expected=0.069641
# Month=104, Predicted=0.127970, Expected=0.104279
# Month=105, Predicted=0.124227, Expected=0.024326
# Month=106, Predicted=0.121922, Expected=0.082156
# Month=107, Predicted=0.129632, Expected=0.074529
# Month=108, Predicted=0.144039, Expected=0.115347
# Month=109, Predicted=0.159090, Expected=0.119270
# Month=110, Predicted=0.167548, Expected=0.212338
# Month=111, Predicted=0.172554, Expected=0.189289
# Month=112, Predicted=0.170379, Expected=0.193005
# Month=113, Predicted=0.163720, Expected=0.133037
# Month=114, Predicted=0.155154, Expected=0.066030
# Month=115, Predicted=0.148598, Expected=0.081673
# Month=116, Predicted=0.142636, Expected=0.125111
# Month=117, Predicted=0.143429, Expected=0.070710
# Month=118, Predicted=0.143307, Expected=0.109506
# Month=119, Predicted=0.151754, Expected=0.106104
# Month=120, Predicted=0.167463, Expected=0.147090
# Month=121, Predicted=0.182836, Expected=0.164598
# Month=122, Predicted=0.193646, Expected=0.248214
# Month=123, Predicted=0.197083, Expected=0.215597
# Month=124, Predicted=0.194922, Expected=0.222545
# Month=125, Predicted=0.189546, Expected=0.178286
# Month=126, Predicted=0.184376, Expected=0.107107
# Month=127, Predicted=0.183215, Expected=0.128761
# Month=128, Predicted=0.175938, Expected=0.150832
# Month=129, Predicted=0.170659, Expected=0.070762
# Month=130, Predicted=0.167126, Expected=0.137600
# Month=131, Predicted=0.174862, Expected=0.113991
# Month=132, Predicted=0.189201, Expected=0.169930
# Month=133, Predicted=0.199481, Expected=0.202547
# Month=134, Predicted=0.207220, Expected=0.264757
# Month=135, Predicted=0.208587, Expected=0.257353
# Month=136, Predicted=0.207315, Expected=0.256271
# Month=137, Predicted=0.198236, Expected=0.206967

# %%
# Skalierung zurücksetzten
predictions_46=np.reshape(predictions_46,(len(predictions_46),1))
predictions_46=scaler.inverse_transform(predictions_46)

# %%
# Modellperformance bewerten
mse = mean_squared_error(ZR_46[-len(predictions_46):], predictions_46)
print('Test MSE: %.3f' % mse)
# Vorhersage und Testdaten abtragen
plt.plot(ZR_46[-len(predictions_46):], color='blue')
plt.plot(predictions_46, color='orange')
plt.show()
# Out:
# Test MSE: 14930790.434

# %%
predictions_train_46 = list()
for i in range(len(ZR_N46_TR_I)):
    # Vorhersage erzeugen 
    X, y = ZR_N46_TR_I.iloc[i, 0:-1], ZR_N46_TR_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_46, 1, X)
    predictions_train_46.append(yhat)
    expected = ZR_N46[ i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.206524, Expected=0.276451
# Month=2, Predicted=0.206245, Expected=0.258943
# Month=3, Predicted=0.201433, Expected=0.212051
# Month=4, Predicted=0.196179, Expected=0.211151
# Month=5, Predicted=0.196376, Expected=0.271315
# Month=6, Predicted=0.198644, Expected=0.198128
# Month=7, Predicted=0.202311, Expected=0.299982
# Month=8, Predicted=0.201216, Expected=0.264158
# Month=9, Predicted=0.206716, Expected=0.289592
# Month=10, Predicted=0.211716, Expected=0.229481
# Month=11, Predicted=0.214987, Expected=0.318363
# Month=12, Predicted=0.217076, Expected=0.282995
# Month=13, Predicted=0.217608, Expected=0.298717
# Month=14, Predicted=0.217397, Expected=0.266283
# Month=15, Predicted=0.212959, Expected=0.197176
# Month=16, Predicted=0.206467, Expected=0.196433
# Month=17, Predicted=0.210204, Expected=0.291573
# Month=18, Predicted=0.211831, Expected=0.220811
# Month=19, Predicted=0.211485, Expected=0.293151
# Month=20, Predicted=0.212605, Expected=0.306383
# Month=21, Predicted=0.216102, Expected=0.310098
# Month=22, Predicted=0.221470, Expected=0.291273
# Month=23, Predicted=0.224082, Expected=0.338830
# Month=24, Predicted=0.228928, Expected=0.328675
# Month=25, Predicted=0.227744, Expected=0.356782
# Month=26, Predicted=0.227758, Expected=0.306865
# Month=27, Predicted=0.222171, Expected=0.227916
# Month=28, Predicted=0.218535, Expected=0.289096
# Month=29, Predicted=0.217502, Expected=0.309798
# Month=30, Predicted=0.218425, Expected=0.234917
# Month=31, Predicted=0.220833, Expected=0.330265
# Month=32, Predicted=0.223613, Expected=0.295067
# Month=33, Predicted=0.224421, Expected=0.344592
# Month=34, Predicted=0.230138, Expected=0.354904
# Month=35, Predicted=0.228731, Expected=0.395448
# Month=36, Predicted=0.231785, Expected=0.362830
# Month=37, Predicted=0.229470, Expected=0.363886
# Month=38, Predicted=0.231030, Expected=0.299890
# Month=39, Predicted=0.226077, Expected=0.248827
# Month=40, Predicted=0.223440, Expected=0.278328
# Month=41, Predicted=0.225623, Expected=0.354513
# Month=42, Predicted=0.224099, Expected=0.305431
# Month=43, Predicted=0.223956, Expected=0.392919
# Month=44, Predicted=0.222369, Expected=0.295328
# Month=45, Predicted=0.225260, Expected=0.374850
# Month=46, Predicted=0.227868, Expected=0.324868
# Month=47, Predicted=0.227918, Expected=0.383376
# Month=48, Predicted=0.232930, Expected=0.398029
# Month=49, Predicted=0.232243, Expected=0.400688
# Month=50, Predicted=0.230651, Expected=0.322404
# Month=51, Predicted=0.225741, Expected=0.284494
# Month=52, Predicted=0.223593, Expected=0.308077
# Month=53, Predicted=0.224747, Expected=0.324790
# Month=54, Predicted=0.224291, Expected=0.278002
# Month=55, Predicted=0.224297, Expected=0.354891
# Month=56, Predicted=0.224525, Expected=0.304949
# Month=57, Predicted=0.226896, Expected=0.348986
# Month=58, Predicted=0.230755, Expected=0.323134
# Month=59, Predicted=0.229055, Expected=0.402370
# Month=60, Predicted=0.234355, Expected=0.391107
# Month=61, Predicted=0.233493, Expected=0.350459
# Month=62, Predicted=0.235316, Expected=0.312210
# Month=63, Predicted=0.231120, Expected=0.274978
# Month=64, Predicted=0.228120, Expected=0.315704
# Month=65, Predicted=0.227234, Expected=0.363456
# Month=66, Predicted=0.225001, Expected=0.294246
# Month=67, Predicted=0.222839, Expected=0.374276
# Month=68, Predicted=0.219865, Expected=0.321922
# Month=69, Predicted=0.221167, Expected=0.373442
# Month=70, Predicted=0.224362, Expected=0.327893
# Month=71, Predicted=0.224479, Expected=0.432523
# Month=72, Predicted=0.229136, Expected=0.438585
# Month=73, Predicted=0.227273, Expected=0.422759
# Month=74, Predicted=0.227180, Expected=0.375919
# Month=75, Predicted=0.220506, Expected=0.294141
# Month=76, Predicted=0.215491, Expected=0.291143
# Month=77, Predicted=0.213692, Expected=0.340043
# Month=78, Predicted=0.211810, Expected=0.239949
# Month=79, Predicted=0.210701, Expected=0.303749
# Month=80, Predicted=0.208262, Expected=0.265396
# Month=81, Predicted=0.208426, Expected=0.293633
# Month=82, Predicted=0.211514, Expected=0.271732
# Month=83, Predicted=0.213851, Expected=0.340238
# Month=84, Predicted=0.215825, Expected=0.315156
# Month=85, Predicted=0.213539, Expected=0.314309
# Month=86, Predicted=0.209493, Expected=0.234474
# Month=87, Predicted=0.202803, Expected=0.196329
# Month=88, Predicted=0.197425, Expected=0.209013
# Month=89, Predicted=0.198054, Expected=0.280649
# Month=90, Predicted=0.199305, Expected=0.239988
# Month=91, Predicted=0.195760, Expected=0.275512
# Month=92, Predicted=0.192987, Expected=0.224462
# Month=93, Predicted=0.196951, Expected=0.257118
# Month=94, Predicted=0.202535, Expected=0.254185
# Month=95, Predicted=0.206073, Expected=0.320879
# Month=96, Predicted=0.209408, Expected=0.302498
# Month=97, Predicted=0.208035, Expected=0.298574
# Month=98, Predicted=0.202544, Expected=0.217839
# Month=99, Predicted=0.196779, Expected=0.175549
# Month=100, Predicted=0.191257, Expected=0.204242
# Month=101, Predicted=0.191348, Expected=0.282761
# Month=102, Predicted=0.187000, Expected=0.199640
# Month=103, Predicted=0.183303, Expected=0.271966
# Month=104, Predicted=0.179793, Expected=0.221972
# Month=105, Predicted=0.184785, Expected=0.229728
# Month=106, Predicted=0.193736, Expected=0.251564
# Month=107, Predicted=0.198459, Expected=0.313696
# Month=108, Predicted=0.200295, Expected=0.295015
# Month=109, Predicted=0.198055, Expected=0.286737
# Month=110, Predicted=0.190778, Expected=0.220603
# Month=111, Predicted=0.180494, Expected=0.159736
# Month=112, Predicted=0.172810, Expected=0.179017
# Month=113, Predicted=0.172834, Expected=0.216900
# Month=114, Predicted=0.171006, Expected=0.156203
# Month=115, Predicted=0.169773, Expected=0.230119
# Month=116, Predicted=0.169315, Expected=0.207892
# Month=117, Predicted=0.171350, Expected=0.231958
# Month=118, Predicted=0.175025, Expected=0.226847
# Month=119, Predicted=0.180359, Expected=0.259738
# Month=120, Predicted=0.186052, Expected=0.248357
# Month=121, Predicted=0.185622, Expected=0.232075
# Month=122, Predicted=0.181131, Expected=0.184896
# Month=123, Predicted=0.179981, Expected=0.153726
# Month=124, Predicted=0.177506, Expected=0.187699
# Month=125, Predicted=0.173259, Expected=0.206915
# Month=126, Predicted=0.166387, Expected=0.145461
# Month=127, Predicted=0.165629, Expected=0.213081
# Month=128, Predicted=0.162404, Expected=0.133624
# Month=129, Predicted=0.167422, Expected=0.179603
# Month=130, Predicted=0.177952, Expected=0.223510
# Month=131, Predicted=0.188171, Expected=0.280323
# Month=132, Predicted=0.197085, Expected=0.269972
# Month=133, Predicted=0.198575, Expected=0.253233
# Month=134, Predicted=0.197079, Expected=0.232648
# Month=135, Predicted=0.192376, Expected=0.170517
# Month=136, Predicted=0.189055, Expected=0.170399
# Month=137, Predicted=0.190535, Expected=0.208309
# Month=138, Predicted=0.191073, Expected=0.183214
# Month=139, Predicted=0.188080, Expected=0.224774
# Month=140, Predicted=0.182458, Expected=0.178704
# Month=141, Predicted=0.190007, Expected=0.210825
# Month=142, Predicted=0.201057, Expected=0.232896
# Month=143, Predicted=0.207696, Expected=0.311024
# Month=144, Predicted=0.211669, Expected=0.304401
# Month=145, Predicted=0.212380, Expected=0.303071
# Month=146, Predicted=0.211443, Expected=0.260064
# Month=147, Predicted=0.206753, Expected=0.215792
# Month=148, Predicted=0.200009, Expected=0.247627
# Month=149, Predicted=0.197432, Expected=0.292355
# Month=150, Predicted=0.195177, Expected=0.218530
# Month=151, Predicted=0.191048, Expected=0.234773
# Month=152, Predicted=0.189853, Expected=0.254054
# Month=153, Predicted=0.195078, Expected=0.275108
# Month=154, Predicted=0.201049, Expected=0.281731
# Month=155, Predicted=0.201697, Expected=0.335089
# Month=156, Predicted=0.205335, Expected=0.299082
# Month=157, Predicted=0.205160, Expected=0.293776
# Month=158, Predicted=0.202328, Expected=0.238645
# Month=159, Predicted=0.192558, Expected=0.159944
# Month=160, Predicted=0.187483, Expected=0.208283
# Month=161, Predicted=0.185733, Expected=0.247275
# Month=162, Predicted=0.182666, Expected=0.174102
# Month=163, Predicted=0.177735, Expected=0.227734
# Month=164, Predicted=0.172398, Expected=0.213798
# Month=165, Predicted=0.175584, Expected=0.218621
# Month=166, Predicted=0.184866, Expected=0.202495
# Month=167, Predicted=0.194219, Expected=0.310567
# Month=168, Predicted=0.198415, Expected=0.283178
# Month=169, Predicted=0.198628, Expected=0.293346
# Month=170, Predicted=0.194221, Expected=0.217435
# Month=171, Predicted=0.185368, Expected=0.167153
# Month=172, Predicted=0.175661, Expected=0.181872
# Month=173, Predicted=0.174009, Expected=0.232283
# Month=174, Predicted=0.172154, Expected=0.158367
# Month=175, Predicted=0.171489, Expected=0.209000
# Month=176, Predicted=0.168006, Expected=0.180581
# Month=177, Predicted=0.174032, Expected=0.226143
# Month=178, Predicted=0.184844, Expected=0.226078
# Month=179, Predicted=0.191169, Expected=0.293085
# Month=180, Predicted=0.190985, Expected=0.268290
# Month=181, Predicted=0.188756, Expected=0.268225
# Month=182, Predicted=0.182324, Expected=0.184088
# Month=183, Predicted=0.175461, Expected=0.128422
# Month=184, Predicted=0.171200, Expected=0.176722
# Month=185, Predicted=0.172311, Expected=0.231984
# Month=186, Predicted=0.171199, Expected=0.190189
# Month=187, Predicted=0.163279, Expected=0.215688
# Month=188, Predicted=0.155969, Expected=0.173320
# Month=189, Predicted=0.160913, Expected=0.222715
# Month=190, Predicted=0.170502, Expected=0.202678
# Month=191, Predicted=0.174865, Expected=0.256088
# Month=192, Predicted=0.178126, Expected=0.265109
# Month=193, Predicted=0.178534, Expected=0.241761
# Month=194, Predicted=0.173470, Expected=0.196303
# Month=195, Predicted=0.165436, Expected=0.140220
# Month=196, Predicted=0.157559, Expected=0.166410
# Month=197, Predicted=0.152831, Expected=0.208401
# Month=198, Predicted=0.144772, Expected=0.099051
# Month=199, Predicted=0.142737, Expected=0.169109
# Month=200, Predicted=0.141037, Expected=0.142123
# Month=201, Predicted=0.147185, Expected=0.199640
# Month=202, Predicted=0.152493, Expected=0.175275
# Month=203, Predicted=0.158379, Expected=0.240562
# Month=204, Predicted=0.163376, Expected=0.230185
# Month=205, Predicted=0.163166, Expected=0.198623
# Month=206, Predicted=0.157307, Expected=0.172577
# Month=207, Predicted=0.150397, Expected=0.120639
# Month=208, Predicted=0.143759, Expected=0.122282
# Month=209, Predicted=0.142164, Expected=0.167949
# Month=210, Predicted=0.137802, Expected=0.101971
# Month=211, Predicted=0.134032, Expected=0.168913
# Month=212, Predicted=0.126768, Expected=0.130182
# Month=213, Predicted=0.129731, Expected=0.142958
# Month=214, Predicted=0.139642, Expected=0.144900
# Month=215, Predicted=0.148816, Expected=0.223797
# Month=216, Predicted=0.155560, Expected=0.204372
# Month=217, Predicted=0.158441, Expected=0.202521
# Month=218, Predicted=0.154866, Expected=0.173424
# Month=219, Predicted=0.145251, Expected=0.096730
# Month=220, Predicted=0.136892, Expected=0.122269
# Month=221, Predicted=0.131539, Expected=0.145474
# Month=222, Predicted=0.127438, Expected=0.072991
# Month=223, Predicted=0.126082, Expected=0.123234
# Month=224, Predicted=0.121380, Expected=0.118058
# Month=225, Predicted=0.125400, Expected=0.147781
# Month=226, Predicted=0.135141, Expected=0.146569
# Month=227, Predicted=0.147927, Expected=0.235256
# Month=228, Predicted=0.152872, Expected=0.194804
# Month=229, Predicted=0.154441, Expected=0.205116
# Month=230, Predicted=0.147230, Expected=0.145422
# Month=231, Predicted=0.139006, Expected=0.077567
# Month=232, Predicted=0.134878, Expected=0.104383
# Month=233, Predicted=0.133446, Expected=0.152696
# Month=234, Predicted=0.126812, Expected=0.091229
# Month=235, Predicted=0.119697, Expected=0.114682
# Month=236, Predicted=0.115549, Expected=0.101046
# Month=237, Predicted=0.121557, Expected=0.112909

# %%
# Skalierung zurücksetzten
predictions_train_46=np.reshape(predictions_train_46,(len(predictions_train_46),1))
predictions_train_46=scaler.inverse_transform(predictions_train_46)

# %%
# Verschiebung der Trainingsvorhersage zum Plotten
trainPredictPlot = np.empty_like(ZR_46)
trainPredictPlot=trainPredictPlot.reshape(len(ZR_46))
trainPredictPlot[:]=[0]*len(ZR_46)
predictions_train_46=predictions_train_46.reshape(len(predictions_train_46))
trainPredictPlot[(look_back+look_forward-1):len(predictions_train_46)+(look_back+look_forward-1)] = predictions_train_46

# Verschiebung der Testvorhersage zum Plotten
testPredictPlot = np.empty_like(ZR_46)
testPredictPlot=testPredictPlot.reshape(len(ZR_46))
testPredictPlot[:]=[0]*len(ZR_46)
predictions_46=predictions_46.reshape(len(predictions_46))
testPredictPlot[-len(predictions_46):] = predictions_46

# Plotten der baseline und  der Vorhersagen
plt.plot(ZR_46, color='blue')
plt.plot(trainPredictPlot, color='orange') 
plt.plot(testPredictPlot, color='green')
plt.show()

# %%
# Replizierbarkeit gewährleisten
np.random.seed(0)

# %%
# Modell anpassen: 12% der originalen Datensatzstärke
lstm_model_12 = fit_lstm(ZR_N12_TR_I, 1, 30, 4)

# %%
# Validierung des Modells anhand der Testdaten
predictions_12 = list()
for i in range(len(ZR_N12_TE_I)):
    # Vorhersage erzeugen
    X, y = ZR_N12_TE_I.iloc[i, 0:-1], ZR_N12_TE_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_12, 1, X)
    predictions_12.append(yhat)
    expected = ZR_N12[len(ZR_N12_TR_I) + i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.062382, Expected=0.129530
# Month=2, Predicted=0.053771, Expected=0.073917
# Month=3, Predicted=0.052173, Expected=0.069641
# Month=4, Predicted=0.045394, Expected=0.104279
# Month=5, Predicted=0.045505, Expected=0.024326
# Month=6, Predicted=0.054866, Expected=0.082156
# Month=7, Predicted=0.070097, Expected=0.074529
# Month=8, Predicted=0.091208, Expected=0.115347
# Month=9, Predicted=0.120290, Expected=0.119270
# Month=10, Predicted=0.141035, Expected=0.212338
# Month=11, Predicted=0.150148, Expected=0.189289
# Month=12, Predicted=0.150508, Expected=0.193005
# Month=13, Predicted=0.131379, Expected=0.133037
# Month=14, Predicted=0.106753, Expected=0.066030
# Month=15, Predicted=0.089639, Expected=0.081673
# Month=16, Predicted=0.069718, Expected=0.125111
# Month=17, Predicted=0.065213, Expected=0.070710
# Month=18, Predicted=0.069157, Expected=0.109506
# Month=19, Predicted=0.081750, Expected=0.106104
# Month=20, Predicted=0.101722, Expected=0.147090
# Month=21, Predicted=0.125644, Expected=0.164598
# Month=22, Predicted=0.145252, Expected=0.248214
# Month=23, Predicted=0.151926, Expected=0.215597
# Month=24, Predicted=0.148375, Expected=0.222545
# Month=25, Predicted=0.128969, Expected=0.178286
# Month=26, Predicted=0.104670, Expected=0.107107
# Month=27, Predicted=0.086543, Expected=0.128761
# Month=28, Predicted=0.064479, Expected=0.150832
# Month=29, Predicted=0.056533, Expected=0.070762
# Month=30, Predicted=0.054685, Expected=0.137600
# Month=31, Predicted=0.066354, Expected=0.113991
# Month=32, Predicted=0.088334, Expected=0.169930
# Month=33, Predicted=0.117078, Expected=0.202547
# Month=34, Predicted=0.144902, Expected=0.264757
# Month=35, Predicted=0.159309, Expected=0.257353
# Month=36, Predicted=0.160952, Expected=0.256271
# Month=37, Predicted=0.142746, Expected=0.206967

# %%
# Skalierung zurücksetzten
predictions_12=np.reshape(predictions_12,(len(predictions_12),1))
predictions_12=scaler.inverse_transform(predictions_12)

# %%
# Modellperformance bewerten
mse = mean_squared_error(ZR_12[-len(predictions_12):], predictions_12)
print('Test MSE: %.3f' % mse)
# Vorhersage und Testdaten abtragen
plt.plot(ZR_12[-len(predictions_12):], color='blue')
plt.plot(predictions_12, color='orange')
plt.show()
# Out:
# Test MSE: 81608918.135

# %%
predictions_train_12 = list()
for i in range(len(ZR_N12_TR_I)):
    # Vorhersage erzeugen 
    X, y = ZR_N12_TR_I.iloc[i, 0:-1], ZR_N12_TR_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_12, 1, X)
    predictions_train_12.append(yhat)
    expected = ZR_N12[i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.152359, Expected=0.152422
# Month=2, Predicted=0.152874, Expected=0.089169
# Month=3, Predicted=0.137870, Expected=0.044311
# Month=4, Predicted=0.119925, Expected=0.077554
# Month=5, Predicted=0.106651, Expected=0.095857
# Month=6, Predicted=0.088342, Expected=0.031209
# Month=7, Predicted=0.081783, Expected=0.098634
# Month=8, Predicted=0.081154, Expected=0.053449
# Month=9, Predicted=0.087010, Expected=0.106038
# Month=10, Predicted=0.101593, Expected=0.125293
# Month=11, Predicted=0.122417, Expected=0.182484
# Month=12, Predicted=0.139713, Expected=0.155460
# Month=13, Predicted=0.149994, Expected=0.172146
# Month=14, Predicted=0.151911, Expected=0.142045
# Month=15, Predicted=0.136624, Expected=0.086771
# Month=16, Predicted=0.117097, Expected=0.092155
# Month=17, Predicted=0.099789, Expected=0.089717
# Month=18, Predicted=0.083007, Expected=0.033895
# Month=19, Predicted=0.077500, Expected=0.071870
# Month=20, Predicted=0.079863, Expected=0.024391
# Month=21, Predicted=0.091502, Expected=0.093067
# Month=22, Predicted=0.109036, Expected=0.117680
# Month=23, Predicted=0.125661, Expected=0.172720
# Month=24, Predicted=0.138518, Expected=0.167988
# Month=25, Predicted=0.140618, Expected=0.161496
# Month=26, Predicted=0.134069, Expected=0.104513
# Month=27, Predicted=0.119537, Expected=0.049160
# Month=28, Predicted=0.101579, Expected=0.056083
# Month=29, Predicted=0.089991, Expected=0.086145
# Month=30, Predicted=0.079432, Expected=0.043802
# Month=31, Predicted=0.073835, Expected=0.092637
# Month=32, Predicted=0.077415, Expected=0.068298
# Month=33, Predicted=0.089278, Expected=0.114238
# Month=34, Predicted=0.103558, Expected=0.099142
# Month=35, Predicted=0.122763, Expected=0.175027
# Month=36, Predicted=0.141642, Expected=0.179303
# Month=37, Predicted=0.144509, Expected=0.152461

# %%
# Skalierung zurücksetzten
predictions_train_12=np.reshape(predictions_train_12,(len(predictions_train_12),1))
predictions_train_12=scaler.inverse_transform(predictions_train_12)

# %%
# Verschiebung der Trainingsvorhersage zum Plotten
trainPredictPlot = np.empty_like(ZR_12)
trainPredictPlot=trainPredictPlot.reshape(len(ZR_12))
trainPredictPlot[:]=[0]*len(ZR_12)
predictions_train_12=predictions_train_12.reshape(len(predictions_train_12))
trainPredictPlot[(look_back+look_forward-1):len(predictions_train_12)+(look_back+look_forward-1)] = predictions_train_12

# Verschiebung der Testvorhersage zum Plotten
testPredictPlot = np.empty_like(ZR_12)
testPredictPlot=testPredictPlot.reshape(len(ZR_12))
testPredictPlot[:]=[0]*len(ZR_12)
predictions_12=predictions_12.reshape(len(predictions_12))
testPredictPlot[-len(predictions_12):] = predictions_12

# Plotten der baseline und  der Vorhersagen
plt.plot(ZR_12, color='blue')
plt.plot(trainPredictPlot, color='orange') 
plt.plot(testPredictPlot, color='green')
plt.show()
