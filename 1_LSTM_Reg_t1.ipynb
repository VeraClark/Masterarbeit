# %%
# Packages laden
import numpy as np
import pandas as pd
import math
from numpy import array
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from pandas import DataFrame
from pandas import concat
from math import sqrt
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Laden der Daten
DATA_FILE="Dropbox/Masterarbeit/Masterarbeit/Datensätze/Geburtenrate/Datensatz.xlsx"
df = pd.read_excel(DATA_FILE)
df=pd.read_excel(DATA_FILE, header=0, parse_dates=[0], index_col='Jahr-Monat',squeeze=True,)

# %%
# Ein array mit allen Einträgen --> zur besseren Weiterverarbeitung
ZR=df.values

# %%
# Daten normalisieren
ZR = ZR.reshape((len(ZR), 1))
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(ZR)
ZR_N = scaler.transform(ZR)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# (863, 1)

# %%
# Anteil der Datensätze am Gesamtdatensatz
ZR_100=ZR
ZR_46=ZR[-400:]
ZR_12=ZR[-100:]

# Unterteilung der Teildatensätze in Trainings-und Testdaten
ZR_100_TR, ZR_100_TE= ZR_100[0:605], ZR_100[605:len(ZR_100)]
ZR_46_TR, ZR_46_TE= ZR_46[0:250], ZR_46[250:len(ZR_46)]
ZR_12_TR, ZR_12_TE= ZR_12[0:50], ZR_12[50:len(ZR_12)]

# Anteil der Datensätze am Gesamtdatensatz: normalisierte Daten
ZR_N100=ZR_N
ZR_N46=ZR_N[-400:]
ZR_N12=ZR_N[-100:]

# Unterteilung der Teildatensätze in Trainings-und Testdaten
ZR_N100_TR, ZR_N100_TE= ZR_N100[0:605], ZR_N100[605:len(ZR_N100)]
ZR_N46_TR, ZR_N46_TE= ZR_N46[0:250], ZR_N46[250:len(ZR_N46)]
ZR_N12_TR, ZR_N12_TE= ZR_N12[0:50], ZR_N12[50:len(ZR_N12)]

# %%
# Funktion: Datensatz erstellen mit Inputs (look_back: Anzahl der verwendten Vergangenheitswerte) + Output (look_forward: 
# Vorhersagehorizont)
def timeseries_to_supervised_R(data, look_back=1, look_forward=1):
    df = DataFrame(data)
    columns = [df.shift(look_forward-1+i) for i in range(1, look_back+1)]
    columns.append(df)
    df = concat(columns, axis=1)
    df = df.drop(0)
    DF=df[::-1]
    df=DF[:len(df)-(look_back+look_forward-1)]
    DF=df[::-1]
    return DF

# %%
# Festlegung: look_back, look_forward + Anwendung der Funktion
# Inputneuronen: 12
# Vorhersagehorizont: 1
look_back=12
look_forward=1

# Inputgröße 100%
# Trainingsdaten
ZR_100_TR_I=timeseries_to_supervised_R(ZR_100_TR, look_back, look_forward)

# Testdaten 
ZR_100_TE_I=timeseries_to_supervised_R(ZR_100_TE, look_back, look_forward)


# Inputgröße 46%
# Trainingsdaten
ZR_46_TR_I=timeseries_to_supervised_R(ZR_46_TR, look_back, look_forward)

# Testdaten 
ZR_46_TE_I=timeseries_to_supervised_R(ZR_46_TE, look_back, look_forward)

# Inputgröße 12%
# Trainingsdaten
ZR_12_TR_I=timeseries_to_supervised_R(ZR_12_TR, look_back, look_forward)

# Testdaten 
ZR_12_TE_I=timeseries_to_supervised_R(ZR_12_TE, look_back, look_forward)

# %%
# Normalisierten Daten
# Inputgröße 100%
# Trainingsdaten
ZR_N100_TR_I=timeseries_to_supervised_R(ZR_N100_TR, look_back, look_forward)

# Testdaten 
ZR_N100_TE_I=timeseries_to_supervised_R(ZR_N100_TE, look_back, look_forward)


# Inputgröße 46%
# Trainingsdaten
ZR_N46_TR_I=timeseries_to_supervised_R(ZR_N46_TR, look_back, look_forward)

# Testdaten 
ZR_N46_TE_I=timeseries_to_supervised_R(ZR_N46_TE, look_back, look_forward)


# Inputgröße 12%
# Trainingsdaten
ZR_N12_TR_I=timeseries_to_supervised_R(ZR_N12_TR, look_back, look_forward)

# Testdaten 
ZR_N12_TE_I=timeseries_to_supervised_R(ZR_N12_TE, look_back, look_forward)

# %%
# Funktion: X,y trennen, Form von X anpassen, Modell zusammenbauen, Modell anpassen
def fit_lstm(train, batch_size, nb_epochs, blocks):
    X, y = train.iloc[:, 0:-1], train.iloc[:, -1]
    X=array(X)
    X = X.reshape(X.shape[0], 1, X.shape[1]) 
    model = Sequential()
    model.add(LSTM(blocks, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    for i in range(nb_epochs):
        model.fit(X, y, epochs=1, batch_size=batch_size, verbose=0, shuffle=False)
        model.reset_states()
    return model

# %%
# Replizierbarkeit gewährleisten
np.random.seed(0)

# %%
# Modell anpassen: 100% der originalen Datensatzstärke
lstm_model_100 = fit_lstm(ZR_N100_TR_I, 1, 200, 4)

# %%
# Vorhersage
def forecast_lstm(model, batch_size, X):
    X=array(X)
    X = X.reshape(1, 1, len(X)) # 1,1 hat nichts mit look_forward oder look_backward zu tun!
    yhat = model.predict(X, batch_size=batch_size)
    return yhat[0,0]

# %%
# Validierung des Modells anhand der Testdaten
predictions_100 = list()
for i in range(len(ZR_N100_TE_I)):
    # make forecast 
    X, y = ZR_N100_TE_I.iloc[i, 0:-1], ZR_N100_TE_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_100, 1, X)
    predictions_100.append(yhat)
    expected = ZR_N100[len(ZR_N100_TR_I) + i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.252743, Expected=0.223510
# Month=2, Predicted=0.236337, Expected=0.280323
# Month=3, Predicted=0.272390, Expected=0.269972
# Month=4, Predicted=0.235313, Expected=0.253233
# Month=5, Predicted=0.199359, Expected=0.232648
# Month=6, Predicted=0.173578, Expected=0.170517
# Month=7, Predicted=0.201325, Expected=0.170399
# Month=8, Predicted=0.201689, Expected=0.208309
# Month=9, Predicted=0.198262, Expected=0.183214
# Month=10, Predicted=0.195503, Expected=0.224774
# Month=11, Predicted=0.222605, Expected=0.178704
# Month=12, Predicted=0.224487, Expected=0.210825
# Month=13, Predicted=0.247174, Expected=0.232896
# Month=14, Predicted=0.257125, Expected=0.311024
# Month=15, Predicted=0.281387, Expected=0.304401
# Month=16, Predicted=0.247369, Expected=0.303071
# Month=17, Predicted=0.177450, Expected=0.260064
# Month=18, Predicted=0.165519, Expected=0.215792
# Month=19, Predicted=0.199444, Expected=0.247627
# Month=20, Predicted=0.180853, Expected=0.292355
# Month=21, Predicted=0.203594, Expected=0.218530
# Month=22, Predicted=0.173743, Expected=0.234773
# Month=23, Predicted=0.204022, Expected=0.254054
# Month=24, Predicted=0.197797, Expected=0.275108
# Month=25, Predicted=0.272488, Expected=0.281731
# Month=26, Predicted=0.247347, Expected=0.335089
# Month=27, Predicted=0.277452, Expected=0.299082
# Month=28, Predicted=0.220617, Expected=0.293776
# Month=29, Predicted=0.179540, Expected=0.238645
# Month=30, Predicted=0.139153, Expected=0.159944
# Month=31, Predicted=0.194594, Expected=0.208283
# Month=32, Predicted=0.184746, Expected=0.247275
# Month=33, Predicted=0.223197, Expected=0.174102
# Month=34, Predicted=0.172425, Expected=0.227734
# Month=35, Predicted=0.204092, Expected=0.213798
# Month=36, Predicted=0.207917, Expected=0.218621
# Month=37, Predicted=0.253449, Expected=0.202495
# Month=38, Predicted=0.230631, Expected=0.310567
# Month=39, Predicted=0.262108, Expected=0.283178
# Month=40, Predicted=0.208742, Expected=0.293346
# Month=41, Predicted=0.170761, Expected=0.217435
# Month=42, Predicted=0.148856, Expected=0.167153
# Month=43, Predicted=0.193068, Expected=0.181872
# Month=44, Predicted=0.188138, Expected=0.232283
# Month=45, Predicted=0.180158, Expected=0.158367
# Month=46, Predicted=0.145014, Expected=0.209000
# Month=47, Predicted=0.200572, Expected=0.180581
# Month=48, Predicted=0.206238, Expected=0.226143
# Month=49, Predicted=0.232124, Expected=0.226078
# Month=50, Predicted=0.235649, Expected=0.293085
# Month=51, Predicted=0.246465, Expected=0.268290
# Month=52, Predicted=0.207012, Expected=0.268225
# Month=53, Predicted=0.172123, Expected=0.184088
# Month=54, Predicted=0.143359, Expected=0.128422
# Month=55, Predicted=0.187853, Expected=0.176722
# Month=56, Predicted=0.136541, Expected=0.231984
# Month=57, Predicted=0.183642, Expected=0.190189
# Month=58, Predicted=0.153786, Expected=0.215688
# Month=59, Predicted=0.202340, Expected=0.173320
# Month=60, Predicted=0.172839, Expected=0.222715
# Month=61, Predicted=0.216473, Expected=0.202678
# Month=62, Predicted=0.232135, Expected=0.256088
# Month=63, Predicted=0.233784, Expected=0.265109
# Month=64, Predicted=0.206361, Expected=0.241761
# Month=65, Predicted=0.175247, Expected=0.196303
# Month=66, Predicted=0.131436, Expected=0.140220
# Month=67, Predicted=0.174955, Expected=0.166410
# Month=68, Predicted=0.140704, Expected=0.208401
# Month=69, Predicted=0.171397, Expected=0.099051
# Month=70, Predicted=0.136992, Expected=0.169109
# Month=71, Predicted=0.175591, Expected=0.142123
# Month=72, Predicted=0.181776, Expected=0.199640
# Month=73, Predicted=0.224949, Expected=0.175275
# Month=74, Predicted=0.229928, Expected=0.240562
# Month=75, Predicted=0.236619, Expected=0.230185
# Month=76, Predicted=0.214299, Expected=0.198623
# Month=77, Predicted=0.155172, Expected=0.172577
# Month=78, Predicted=0.126512, Expected=0.120639
# Month=79, Predicted=0.158083, Expected=0.122282
# Month=80, Predicted=0.141890, Expected=0.167949
# Month=81, Predicted=0.170474, Expected=0.101971
# Month=82, Predicted=0.135566, Expected=0.168913
# Month=83, Predicted=0.170236, Expected=0.130182
# Month=84, Predicted=0.163596, Expected=0.142958
# Month=85, Predicted=0.241086, Expected=0.144900
# Month=86, Predicted=0.226622, Expected=0.223797
# Month=87, Predicted=0.249362, Expected=0.204372
# Month=88, Predicted=0.198147, Expected=0.202521
# Month=89, Predicted=0.147648, Expected=0.173424
# Month=90, Predicted=0.127752, Expected=0.096730
# Month=91, Predicted=0.170507, Expected=0.122269
# Month=92, Predicted=0.141274, Expected=0.145474
# Month=93, Predicted=0.143351, Expected=0.072991
# Month=94, Predicted=0.138953, Expected=0.123234
# Month=95, Predicted=0.161761, Expected=0.118058
# Month=96, Predicted=0.181887, Expected=0.147781
# Month=97, Predicted=0.214703, Expected=0.146569
# Month=98, Predicted=0.215932, Expected=0.235256
# Month=99, Predicted=0.226877, Expected=0.194804
# Month=100, Predicted=0.192478, Expected=0.205116
# Month=101, Predicted=0.145492, Expected=0.145422
# Month=102, Predicted=0.129923, Expected=0.077567
# Month=103, Predicted=0.151993, Expected=0.104383
# Month=104, Predicted=0.131807, Expected=0.152696
# Month=105, Predicted=0.148566, Expected=0.091229
# Month=106, Predicted=0.138144, Expected=0.114682
# Month=107, Predicted=0.154945, Expected=0.101046
# Month=108, Predicted=0.185135, Expected=0.112909
# Month=109, Predicted=0.207650, Expected=0.159162
# Month=110, Predicted=0.209809, Expected=0.225074
# Month=111, Predicted=0.220237, Expected=0.211464
# Month=112, Predicted=0.186018, Expected=0.192770
# Month=113, Predicted=0.156004, Expected=0.136283
# Month=114, Predicted=0.123564, Expected=0.086679
# Month=115, Predicted=0.132128, Expected=0.118332
# Month=116, Predicted=0.126201, Expected=0.122777
# Month=117, Predicted=0.163472, Expected=0.068376
# Month=118, Predicted=0.118499, Expected=0.119297
# Month=119, Predicted=0.165549, Expected=0.101215
# Month=120, Predicted=0.155585, Expected=0.116624
# Month=121, Predicted=0.219505, Expected=0.133311
# Month=122, Predicted=0.214986, Expected=0.176657
# Month=123, Predicted=0.231833, Expected=0.176722
# Month=124, Predicted=0.198446, Expected=0.166215
# Month=125, Predicted=0.169878, Expected=0.110797
# Month=126, Predicted=0.112958, Expected=0.063162
# Month=127, Predicted=0.164647, Expected=0.088700
# Month=128, Predicted=0.123457, Expected=0.096196
# Month=129, Predicted=0.169988, Expected=0.044585
# Month=130, Predicted=0.090655, Expected=0.100733
# Month=131, Predicted=0.155952, Expected=0.055144
# Month=132, Predicted=0.178880, Expected=0.134575
# Month=133, Predicted=0.214763, Expected=0.111605
# Month=134, Predicted=0.224794, Expected=0.170673
# Month=135, Predicted=0.217871, Expected=0.164337
# Month=136, Predicted=0.203274, Expected=0.159436
# Month=137, Predicted=0.151813, Expected=0.125111
# Month=138, Predicted=0.113237, Expected=0.059759
# Month=139, Predicted=0.144418, Expected=0.051298
# Month=140, Predicted=0.131583, Expected=0.121995
# Month=141, Predicted=0.123101, Expected=0.041977
# Month=142, Predicted=0.130293, Expected=0.108789
# Month=143, Predicted=0.162907, Expected=0.042694
# Month=144, Predicted=0.169227, Expected=0.109793
# Month=145, Predicted=0.220357, Expected=0.124863
# Month=146, Predicted=0.216658, Expected=0.180568
# Month=147, Predicted=0.230389, Expected=0.190919
# Month=148, Predicted=0.184946, Expected=0.182093
# Month=149, Predicted=0.134155, Expected=0.150701
# Month=150, Predicted=0.110800, Expected=0.084176
# Month=151, Predicted=0.150647, Expected=0.093119
# Month=152, Predicted=0.123329, Expected=0.138173
# Month=153, Predicted=0.136958, Expected=0.071049
# Month=154, Predicted=0.131271, Expected=0.064296
# Month=155, Predicted=0.152724, Expected=0.092924
# Month=156, Predicted=0.169737, Expected=0.123559
# Month=157, Predicted=0.222545, Expected=0.135488
# Month=158, Predicted=0.209942, Expected=0.200696
# Month=159, Predicted=0.221079, Expected=0.169526
# Month=160, Predicted=0.180162, Expected=0.173945
# Month=161, Predicted=0.160355, Expected=0.116507
# Month=162, Predicted=0.136172, Expected=0.049317
# Month=163, Predicted=0.151657, Expected=0.065599
# Month=164, Predicted=0.105025, Expected=0.094319
# Month=165, Predicted=0.144038, Expected=0.028250
# Month=166, Predicted=0.105351, Expected=0.075246
# Month=167, Predicted=0.141073, Expected=0.068533
# Month=168, Predicted=0.158056, Expected=0.086236
# Month=169, Predicted=0.218349, Expected=0.115190
# Month=170, Predicted=0.211538, Expected=0.187360
# Month=171, Predicted=0.230575, Expected=0.155812
# Month=172, Predicted=0.199505, Expected=0.152422
# Month=173, Predicted=0.156959, Expected=0.089169
# Month=174, Predicted=0.122627, Expected=0.044311
# Month=175, Predicted=0.133671, Expected=0.077554
# Month=176, Predicted=0.115799, Expected=0.095857
# Month=177, Predicted=0.147571, Expected=0.031209
# Month=178, Predicted=0.113021, Expected=0.098634
# Month=179, Predicted=0.162698, Expected=0.053449
# Month=180, Predicted=0.174503, Expected=0.106038
# Month=181, Predicted=0.204226, Expected=0.125293
# Month=182, Predicted=0.210679, Expected=0.182484
# Month=183, Predicted=0.232186, Expected=0.155460
# Month=184, Predicted=0.184856, Expected=0.172146
# Month=185, Predicted=0.150639, Expected=0.142045
# Month=186, Predicted=0.119154, Expected=0.086771
# Month=187, Predicted=0.142536, Expected=0.092155
# Month=188, Predicted=0.122686, Expected=0.089717
# Month=189, Predicted=0.138732, Expected=0.033895
# Month=190, Predicted=0.115505, Expected=0.071870
# Month=191, Predicted=0.169147, Expected=0.024391
# Month=192, Predicted=0.166405, Expected=0.093067
# Month=193, Predicted=0.212324, Expected=0.117680
# Month=194, Predicted=0.231857, Expected=0.172720
# Month=195, Predicted=0.231322, Expected=0.167988
# Month=196, Predicted=0.207967, Expected=0.161496
# Month=197, Predicted=0.159083, Expected=0.104513
# Month=198, Predicted=0.108769, Expected=0.049160
# Month=199, Predicted=0.147986, Expected=0.056083
# Month=200, Predicted=0.119132, Expected=0.086145
# Month=201, Predicted=0.155839, Expected=0.043802
# Month=202, Predicted=0.126748, Expected=0.092637
# Month=203, Predicted=0.172750, Expected=0.068298
# Month=204, Predicted=0.177866, Expected=0.114238
# Month=205, Predicted=0.243535, Expected=0.099142
# Month=206, Predicted=0.236518, Expected=0.175027
# Month=207, Predicted=0.249269, Expected=0.179303
# Month=208, Predicted=0.205740, Expected=0.152461
# Month=209, Predicted=0.165251, Expected=0.129530
# Month=210, Predicted=0.126919, Expected=0.073917
# Month=211, Predicted=0.158831, Expected=0.069641
# Month=212, Predicted=0.136174, Expected=0.104279
# Month=213, Predicted=0.145310, Expected=0.024326
# Month=214, Predicted=0.134342, Expected=0.082156
# Month=215, Predicted=0.176391, Expected=0.074529
# Month=216, Predicted=0.191396, Expected=0.115347
# Month=217, Predicted=0.259614, Expected=0.119270
# Month=218, Predicted=0.245050, Expected=0.212338
# Month=219, Predicted=0.267049, Expected=0.189289
# Month=220, Predicted=0.230076, Expected=0.193005
# Month=221, Predicted=0.181459, Expected=0.133037
# Month=222, Predicted=0.144031, Expected=0.066030
# Month=223, Predicted=0.168025, Expected=0.081673
# Month=224, Predicted=0.138278, Expected=0.125111
# Month=225, Predicted=0.190360, Expected=0.070710
# Month=226, Predicted=0.158348, Expected=0.109506
# Month=227, Predicted=0.186399, Expected=0.106104
# Month=228, Predicted=0.206948, Expected=0.147090
# Month=229, Predicted=0.265126, Expected=0.164598
# Month=230, Predicted=0.279932, Expected=0.248214
# Month=231, Predicted=0.293638, Expected=0.215597
# Month=232, Predicted=0.249224, Expected=0.222545
# Month=233, Predicted=0.199365, Expected=0.178286
# Month=234, Predicted=0.167685, Expected=0.107107
# Month=235, Predicted=0.190315, Expected=0.128761
# Month=236, Predicted=0.162204, Expected=0.150832
# Month=237, Predicted=0.177943, Expected=0.070762
# Month=238, Predicted=0.151385, Expected=0.137600
# Month=239, Predicted=0.193726, Expected=0.113991
# Month=240, Predicted=0.226182, Expected=0.169930
# Month=241, Predicted=0.269050, Expected=0.202547
# Month=242, Predicted=0.276308, Expected=0.264757
# Month=243, Predicted=0.284212, Expected=0.257353
# Month=244, Predicted=0.248088, Expected=0.256271
# Month=245, Predicted=0.191296, Expected=0.206967

# %%
# Skalierung zurücksetzten
predictions_100=np.reshape(predictions_100,(len(predictions_100),1))

# %%
predictions_100=scaler.inverse_transform(predictions_100)

# %%
# Modellperformance bewerten
mse = mean_squared_error(ZR_100[-len(predictions_100):], predictions_100)
print('Test MSE: %.3f' % mse)
# line plot of observed vs predicted
plt.plot(ZR_100[-len(predictions_100):], color='blue')
plt.plot(predictions_100, color='orange')
plt.show()
# Out:
# Test MSE: 13386072.468

# %%
predictions_train_100 = list()
for i in range(len(ZR_N100_TR_I)):
    # make forecast 
    X, y = ZR_N100_TR_I.iloc[i, 0:-1], ZR_N100_TR_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_100, 1, X)
    predictions_train_100.append(yhat)
    expected = ZR_N100[ i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.264677, Expected=0.057608
# Month=2, Predicted=0.335525, Expected=0.288836
# Month=3, Predicted=0.321021, Expected=0.342833
# Month=4, Predicted=0.355037, Expected=0.449679
# Month=5, Predicted=0.333664, Expected=0.429707
# Month=6, Predicted=0.363281, Expected=0.470811
# Month=7, Predicted=0.341470, Expected=0.456041
# Month=8, Predicted=0.356118, Expected=0.501017
# Month=9, Predicted=0.360333, Expected=0.486846
# Month=10, Predicted=0.327395, Expected=0.397051
# Month=11, Predicted=0.283817, Expected=0.450149
# Month=12, Predicted=0.356188, Expected=0.551885
# Month=13, Predicted=0.338702, Expected=0.440463
# Month=14, Predicted=0.411158, Expected=0.529397
# Month=15, Predicted=0.362792, Expected=0.457762
# Month=16, Predicted=0.384373, Expected=0.505866
# Month=17, Predicted=0.346989, Expected=0.467565
# Month=18, Predicted=0.374541, Expected=0.494955
# Month=19, Predicted=0.348026, Expected=0.458883
# Month=20, Predicted=0.387419, Expected=0.520063
# Month=21, Predicted=0.369429, Expected=0.433801
# Month=22, Predicted=0.357613, Expected=0.375932
# Month=23, Predicted=0.324008, Expected=0.428404
# Month=24, Predicted=0.388359, Expected=0.518746
# Month=25, Predicted=0.377334, Expected=0.479037
# Month=26, Predicted=0.412840, Expected=0.541117
# Month=27, Predicted=0.387601, Expected=0.480693
# Month=28, Predicted=0.397707, Expected=0.510938
# Month=29, Predicted=0.361004, Expected=0.473758
# Month=30, Predicted=0.392177, Expected=0.522318
# Month=31, Predicted=0.366191, Expected=0.504641
# Month=32, Predicted=0.410796, Expected=0.584789
# Month=33, Predicted=0.367906, Expected=0.522292
# Month=34, Predicted=0.348691, Expected=0.488450
# Month=35, Predicted=0.334929, Expected=0.556995
# Month=36, Predicted=0.363743, Expected=0.594984
# Month=37, Predicted=0.381874, Expected=0.554740
# Month=38, Predicted=0.436023, Expected=0.650780
# Month=39, Predicted=0.420153, Expected=0.565873
# Month=40, Predicted=0.444260, Expected=0.610966
# Month=41, Predicted=0.397361, Expected=0.573200
# Month=42, Predicted=0.402897, Expected=0.617263
# Month=43, Predicted=0.366976, Expected=0.599351
# Month=44, Predicted=0.369753, Expected=0.597369
# Month=45, Predicted=0.352225, Expected=0.543646
# Month=46, Predicted=0.357609, Expected=0.491474
# Month=47, Predicted=0.338422, Expected=0.532943
# Month=48, Predicted=0.383763, Expected=0.624655
# Month=49, Predicted=0.365761, Expected=0.567803
# Month=50, Predicted=0.441506, Expected=0.719390
# Month=51, Predicted=0.414052, Expected=0.622047
# Month=52, Predicted=0.447426, Expected=0.652579
# Month=53, Predicted=0.408659, Expected=0.579353
# Month=54, Predicted=0.402748, Expected=0.570749
# Month=55, Predicted=0.363855, Expected=0.541534
# Month=56, Predicted=0.374778, Expected=0.570801
# Month=57, Predicted=0.359457, Expected=0.564935
# Month=58, Predicted=0.350241, Expected=0.514470
# Month=59, Predicted=0.320813, Expected=0.533021
# Month=60, Predicted=0.373087, Expected=0.599625
# Month=61, Predicted=0.374495, Expected=0.536685
# Month=62, Predicted=0.457920, Expected=0.672850
# Month=63, Predicted=0.428509, Expected=0.604487
# Month=64, Predicted=0.455507, Expected=0.667062
# Month=65, Predicted=0.393299, Expected=0.582638
# Month=66, Predicted=0.382621, Expected=0.594553
# Month=67, Predicted=0.358166, Expected=0.559133
# Month=68, Predicted=0.359220, Expected=0.557399
# Month=69, Predicted=0.360068, Expected=0.541052
# Month=70, Predicted=0.332428, Expected=0.472858
# Month=71, Predicted=0.328888, Expected=0.538444
# Month=72, Predicted=0.374115, Expected=0.616781
# Month=73, Predicted=0.387912, Expected=0.593862
# Month=74, Predicted=0.442449, Expected=0.696172
# Month=75, Predicted=0.423227, Expected=0.619375
# Month=76, Predicted=0.455287, Expected=0.634536
# Month=77, Predicted=0.390426, Expected=0.546240
# Month=78, Predicted=0.403023, Expected=0.576993
# Month=79, Predicted=0.348931, Expected=0.533243
# Month=80, Predicted=0.372893, Expected=0.575950
# Month=81, Predicted=0.342477, Expected=0.509986
# Month=82, Predicted=0.344387, Expected=0.494016
# Month=83, Predicted=0.291453, Expected=0.512737
# Month=84, Predicted=0.372986, Expected=0.609063
# Month=85, Predicted=0.380838, Expected=0.534586
# Month=86, Predicted=0.462684, Expected=0.687986
# Month=87, Predicted=0.416615, Expected=0.612348
# Month=88, Predicted=0.451534, Expected=0.645409
# Month=89, Predicted=0.417570, Expected=0.564061
# Month=90, Predicted=0.419462, Expected=0.577802
# Month=91, Predicted=0.357809, Expected=0.529736
# Month=92, Predicted=0.376103, Expected=0.572626
# Month=93, Predicted=0.346100, Expected=0.496402
# Month=94, Predicted=0.313924, Expected=0.423280
# Month=95, Predicted=0.319075, Expected=0.525512
# Month=96, Predicted=0.377449, Expected=0.617615
# Month=97, Predicted=0.379106, Expected=0.557465
# Month=98, Predicted=0.438250, Expected=0.657572
# Month=99, Predicted=0.428636, Expected=0.619088
# Month=100, Predicted=0.468815, Expected=0.686030
# Month=101, Predicted=0.398976, Expected=0.586197
# Month=102, Predicted=0.409532, Expected=0.596378
# Month=103, Predicted=0.362472, Expected=0.559577
# Month=104, Predicted=0.375968, Expected=0.570045
# Month=105, Predicted=0.343433, Expected=0.499205
# Month=106, Predicted=0.348458, Expected=0.489467
# Month=107, Predicted=0.326040, Expected=0.531991
# Month=108, Predicted=0.378419, Expected=0.611136
# Month=109, Predicted=0.374803, Expected=0.556487
# Month=110, Predicted=0.474050, Expected=0.703642
# Month=111, Predicted=0.454253, Expected=0.618345
# Month=112, Predicted=0.457942, Expected=0.649020
# Month=113, Predicted=0.409962, Expected=0.589495
# Month=114, Predicted=0.388047, Expected=0.583042
# Month=115, Predicted=0.368604, Expected=0.560776
# Month=116, Predicted=0.379914, Expected=0.573630
# Month=117, Predicted=0.363458, Expected=0.539031
# Month=118, Predicted=0.346245, Expected=0.494277
# Month=119, Predicted=0.337765, Expected=0.539527
# Month=120, Predicted=0.385834, Expected=0.612844
# Month=121, Predicted=0.402545, Expected=0.626806
# Month=122, Predicted=0.469714, Expected=0.741800
# Month=123, Predicted=0.433788, Expected=0.638538
# Month=124, Predicted=0.485880, Expected=0.683436
# Month=125, Predicted=0.411816, Expected=0.568676
# Month=126, Predicted=0.424468, Expected=0.617954
# Month=127, Predicted=0.378676, Expected=0.580878
# Month=128, Predicted=0.386766, Expected=0.598269
# Month=129, Predicted=0.374596, Expected=0.549030
# Month=130, Predicted=0.382166, Expected=0.536463
# Month=131, Predicted=0.353430, Expected=0.573473
# Month=132, Predicted=0.395055, Expected=0.644131
# Month=133, Predicted=0.409479, Expected=0.608763
# Month=134, Predicted=0.458511, Expected=0.737263
# Month=135, Predicted=0.463203, Expected=0.690215
# Month=136, Predicted=0.464346, Expected=0.705624
# Month=137, Predicted=0.427423, Expected=0.645435
# Month=138, Predicted=0.392050, Expected=0.629165
# Month=139, Predicted=0.344118, Expected=0.600707
# Month=140, Predicted=0.384882, Expected=0.651014
# Month=141, Predicted=0.413892, Expected=0.615307
# Month=142, Predicted=0.406695, Expected=0.551690
# Month=143, Predicted=0.378551, Expected=0.618905
# Month=144, Predicted=0.436834, Expected=0.695990
# Month=145, Predicted=0.427767, Expected=0.618384
# Month=146, Predicted=0.517546, Expected=0.797283
# Month=147, Predicted=0.460045, Expected=0.663699
# Month=148, Predicted=0.512870, Expected=0.716953
# Month=149, Predicted=0.437940, Expected=0.570931
# Month=150, Predicted=0.418709, Expected=0.561897
# Month=151, Predicted=0.397918, Expected=0.591764
# Month=152, Predicted=0.437675, Expected=0.708049
# Month=153, Predicted=0.404640, Expected=0.631681
# Month=154, Predicted=0.401208, Expected=0.600993
# Month=155, Predicted=0.385420, Expected=0.675066
# Month=156, Predicted=0.430526, Expected=0.747393
# Month=157, Predicted=0.434301, Expected=0.701635
# Month=158, Predicted=0.516902, Expected=0.845961
# Month=159, Predicted=0.502529, Expected=0.790165
# Month=160, Predicted=0.510648, Expected=0.798665
# Month=161, Predicted=0.464132, Expected=0.712533
# Month=162, Predicted=0.464910, Expected=0.731162
# Month=163, Predicted=0.436465, Expected=0.686330
# Month=164, Predicted=0.458212, Expected=0.724383
# Month=165, Predicted=0.439168, Expected=0.677583
# Month=166, Predicted=0.394631, Expected=0.620326
# Month=167, Predicted=0.375834, Expected=0.683710
# Month=168, Predicted=0.422999, Expected=0.745972
# Month=169, Predicted=0.477924, Expected=0.758539
# Month=170, Predicted=0.527755, Expected=0.854070
# Month=171, Predicted=0.511597, Expected=0.774717
# Month=172, Predicted=0.541331, Expected=0.809889
# Month=173, Predicted=0.491816, Expected=0.740953
# Month=174, Predicted=0.481238, Expected=0.770467
# Month=175, Predicted=0.444720, Expected=0.755514
# Month=176, Predicted=0.470794, Expected=0.767977
# Month=177, Predicted=0.428250, Expected=0.657180
# Month=178, Predicted=0.430390, Expected=0.622986
# Month=179, Predicted=0.412928, Expected=0.692222
# Month=180, Predicted=0.484885, Expected=0.830409
# Month=181, Predicted=0.464030, Expected=0.759973
# Month=182, Predicted=0.530337, Expected=0.935065
# Month=183, Predicted=0.503989, Expected=0.840382
# Month=184, Predicted=0.539752, Expected=0.867654
# Month=185, Predicted=0.493699, Expected=0.768290
# Month=186, Predicted=0.483743, Expected=0.784299
# Month=187, Predicted=0.459787, Expected=0.780857
# Month=188, Predicted=0.476399, Expected=0.788914
# Month=189, Predicted=0.466424, Expected=0.767599
# Month=190, Predicted=0.446625, Expected=0.725244
# Month=191, Predicted=0.427860, Expected=0.778276
# Month=192, Predicted=0.474078, Expected=0.832312
# Month=193, Predicted=0.482229, Expected=0.752425
# Month=194, Predicted=0.547965, Expected=0.917375
# Month=195, Predicted=0.528415, Expected=0.832064
# Month=196, Predicted=0.572630, Expected=0.879960
# Month=197, Predicted=0.520442, Expected=0.789122
# Month=198, Predicted=0.495888, Expected=0.803410
# Month=199, Predicted=0.475539, Expected=0.805627
# Month=200, Predicted=0.486757, Expected=0.805783
# Month=201, Predicted=0.462841, Expected=0.758708
# Month=202, Predicted=0.453474, Expected=0.718517
# Month=203, Predicted=0.416553, Expected=0.771145
# Month=204, Predicted=0.488079, Expected=0.898772
# Month=205, Predicted=0.474457, Expected=0.785746
# Month=206, Predicted=0.595391, Expected=1.000000
# Month=207, Predicted=0.544282, Expected=0.902083
# Month=208, Predicted=0.584232, Expected=0.941623
# Month=209, Predicted=0.508789, Expected=0.815586
# Month=210, Predicted=0.516465, Expected=0.872947
# Month=211, Predicted=0.474814, Expected=0.816668
# Month=212, Predicted=0.488442, Expected=0.853288
# Month=213, Predicted=0.460469, Expected=0.788718
# Month=214, Predicted=0.439290, Expected=0.729872
# Month=215, Predicted=0.406365, Expected=0.770363
# Month=216, Predicted=0.487336, Expected=0.908171
# Month=217, Predicted=0.496521, Expected=0.870691
# Month=218, Predicted=0.548167, Expected=0.977968
# Month=219, Predicted=0.544693, Expected=0.928808
# Month=220, Predicted=0.562650, Expected=0.916788
# Month=221, Predicted=0.511866, Expected=0.836601
# Month=222, Predicted=0.508258, Expected=0.872256
# Month=223, Predicted=0.459361, Expected=0.794611
# Month=224, Predicted=0.491247, Expected=0.844058
# Month=225, Predicted=0.452590, Expected=0.753950
# Month=226, Predicted=0.416417, Expected=0.698402
# Month=227, Predicted=0.423766, Expected=0.795641
# Month=228, Predicted=0.463082, Expected=0.845479
# Month=229, Predicted=0.475917, Expected=0.805757
# Month=230, Predicted=0.539880, Expected=0.957671
# Month=231, Predicted=0.525361, Expected=0.876310
# Month=232, Predicted=0.563388, Expected=0.892019
# Month=233, Predicted=0.512235, Expected=0.806044
# Month=234, Predicted=0.509377, Expected=0.828440
# Month=235, Predicted=0.468157, Expected=0.800399
# Month=236, Predicted=0.484865, Expected=0.806800
# Month=237, Predicted=0.429728, Expected=0.709665
# Month=238, Predicted=0.437183, Expected=0.719482
# Month=239, Predicted=0.394676, Expected=0.733783
# Month=240, Predicted=0.456915, Expected=0.845961
# Month=241, Predicted=0.438345, Expected=0.760990
# Month=242, Predicted=0.531661, Expected=0.948819
# Month=243, Predicted=0.509467, Expected=0.868384
# Month=244, Predicted=0.539011, Expected=0.901588
# Month=245, Predicted=0.500976, Expected=0.822704
# Month=246, Predicted=0.488754, Expected=0.827463
# Month=247, Predicted=0.455514, Expected=0.799356
# Month=248, Predicted=0.454333, Expected=0.786150
# Month=249, Predicted=0.429700, Expected=0.734500
# Month=250, Predicted=0.418424, Expected=0.685457
# Month=251, Predicted=0.386525, Expected=0.708140
# Month=252, Predicted=0.432022, Expected=0.791221
# Month=253, Predicted=0.449121, Expected=0.752242
# Month=254, Predicted=0.519079, Expected=0.885514
# Month=255, Predicted=0.482595, Expected=0.806930
# Month=256, Predicted=0.513547, Expected=0.857472
# Month=257, Predicted=0.462382, Expected=0.757535
# Month=258, Predicted=0.454832, Expected=0.769855
# Month=259, Predicted=0.416318, Expected=0.731332
# Month=260, Predicted=0.428487, Expected=0.735999
# Month=261, Predicted=0.407049, Expected=0.697828
# Month=262, Predicted=0.368740, Expected=0.632268
# Month=263, Predicted=0.345307, Expected=0.671286
# Month=264, Predicted=0.424674, Expected=0.790426
# Month=265, Predicted=0.436915, Expected=0.721776
# Month=266, Predicted=0.476890, Expected=0.829131
# Month=267, Predicted=0.452432, Expected=0.757913
# Month=268, Predicted=0.482531, Expected=0.780010
# Month=269, Predicted=0.431856, Expected=0.688781
# Month=270, Predicted=0.413963, Expected=0.695364
# Month=271, Predicted=0.397490, Expected=0.678821
# Month=272, Predicted=0.398091, Expected=0.661939
# Month=273, Predicted=0.353799, Expected=0.572404
# Month=274, Predicted=0.348425, Expected=0.547153
# Month=275, Predicted=0.323904, Expected=0.618671
# Month=276, Predicted=0.382413, Expected=0.722480
# Month=277, Predicted=0.345509, Expected=0.608867
# Month=278, Predicted=0.428599, Expected=0.768421
# Month=279, Predicted=0.403639, Expected=0.679212
# Month=280, Predicted=0.451160, Expected=0.693683
# Month=281, Predicted=0.379673, Expected=0.598360
# Month=282, Predicted=0.416832, Expected=0.655577
# Month=283, Predicted=0.361170, Expected=0.571335
# Month=284, Predicted=0.373277, Expected=0.595309
# Month=285, Predicted=0.315101, Expected=0.530323
# Month=286, Predicted=0.295640, Expected=0.468256
# Month=287, Predicted=0.300219, Expected=0.504093
# Month=288, Predicted=0.387613, Expected=0.544089
# Month=289, Predicted=0.366218, Expected=0.484291
# Month=290, Predicted=0.404447, Expected=0.624185
# Month=291, Predicted=0.391724, Expected=0.564856
# Month=292, Predicted=0.414761, Expected=0.571466
# Month=293, Predicted=0.379841, Expected=0.536293
# Month=294, Predicted=0.374274, Expected=0.554088
# Month=295, Predicted=0.332928, Expected=0.484630
# Month=296, Predicted=0.325406, Expected=0.445051
# Month=297, Predicted=0.311077, Expected=0.411170
# Month=298, Predicted=0.309145, Expected=0.421899
# Month=299, Predicted=0.309215, Expected=0.520272
# Month=300, Predicted=0.337668, Expected=0.529397
# Month=301, Predicted=0.317621, Expected=0.457671
# Month=302, Predicted=0.391661, Expected=0.591724
# Month=303, Predicted=0.355786, Expected=0.521249
# Month=304, Predicted=0.377388, Expected=0.537675
# Month=305, Predicted=0.335188, Expected=0.475400
# Month=306, Predicted=0.360236, Expected=0.498996
# Month=307, Predicted=0.309939, Expected=0.443044
# Month=308, Predicted=0.305124, Expected=0.462533
# Month=309, Predicted=0.251479, Expected=0.413334
# Month=310, Predicted=0.257810, Expected=0.389699
# Month=311, Predicted=0.239870, Expected=0.393883
# Month=312, Predicted=0.278602, Expected=0.449210
# Month=313, Predicted=0.262945, Expected=0.407076
# Month=314, Predicted=0.293549, Expected=0.478373
# Month=315, Predicted=0.265614, Expected=0.412395
# Month=316, Predicted=0.304739, Expected=0.445573
# Month=317, Predicted=0.268377, Expected=0.403882
# Month=318, Predicted=0.282117, Expected=0.391185
# Month=319, Predicted=0.237480, Expected=0.307399
# Month=320, Predicted=0.238288, Expected=0.272292
# Month=321, Predicted=0.200324, Expected=0.244225
# Month=322, Predicted=0.185540, Expected=0.216275
# Month=323, Predicted=0.168555, Expected=0.230041
# Month=324, Predicted=0.228365, Expected=0.320592
# Month=325, Predicted=0.204602, Expected=0.232805
# Month=326, Predicted=0.265898, Expected=0.337331
# Month=327, Predicted=0.232259, Expected=0.278602
# Month=328, Predicted=0.273231, Expected=0.303097
# Month=329, Predicted=0.256027, Expected=0.278159
# Month=330, Predicted=0.255938, Expected=0.304349
# Month=331, Predicted=0.222866, Expected=0.264001
# Month=332, Predicted=0.238163, Expected=0.237733
# Month=333, Predicted=0.210306, Expected=0.215010
# Month=334, Predicted=0.187745, Expected=0.178925
# Month=335, Predicted=0.147714, Expected=0.190254
# Month=336, Predicted=0.208442, Expected=0.291117
# Month=337, Predicted=0.181300, Expected=0.192666
# Month=338, Predicted=0.270502, Expected=0.319263
# Month=339, Predicted=0.204787, Expected=0.265735
# Month=340, Predicted=0.278791, Expected=0.320201
# Month=341, Predicted=0.220672, Expected=0.243534
# Month=342, Predicted=0.251296, Expected=0.293346
# Month=343, Predicted=0.219871, Expected=0.270037
# Month=344, Predicted=0.236615, Expected=0.266309
# Month=345, Predicted=0.191571, Expected=0.213224
# Month=346, Predicted=0.167352, Expected=0.162082
# Month=347, Predicted=0.134682, Expected=0.166867
# Month=348, Predicted=0.222197, Expected=0.267977
# Month=349, Predicted=0.207800, Expected=0.190280
# Month=350, Predicted=0.262219, Expected=0.277624
# Month=351, Predicted=0.231520, Expected=0.254915
# Month=352, Predicted=0.252448, Expected=0.270324
# Month=353, Predicted=0.219271, Expected=0.224396
# Month=354, Predicted=0.254891, Expected=0.269268
# Month=355, Predicted=0.217268, Expected=0.228346
# Month=356, Predicted=0.235087, Expected=0.222011
# Month=357, Predicted=0.202188, Expected=0.172042
# Month=358, Predicted=0.175846, Expected=0.138460
# Month=359, Predicted=0.156310, Expected=0.186421
# Month=360, Predicted=0.208841, Expected=0.273061
# Month=361, Predicted=0.183203, Expected=0.212377
# Month=362, Predicted=0.247319, Expected=0.301416
# Month=363, Predicted=0.219822, Expected=0.234552
# Month=364, Predicted=0.266991, Expected=0.272071
# Month=365, Predicted=0.246971, Expected=0.247080
# Month=366, Predicted=0.269086, Expected=0.276712
# Month=367, Predicted=0.223578, Expected=0.259921
# Month=368, Predicted=0.248580, Expected=0.273635
# Month=369, Predicted=0.203823, Expected=0.205885
# Month=370, Predicted=0.198695, Expected=0.173267
# Month=371, Predicted=0.163441, Expected=0.180985
# Month=372, Predicted=0.198358, Expected=0.232283
# Month=373, Predicted=0.179475, Expected=0.182015
# Month=374, Predicted=0.262856, Expected=0.309107
# Month=375, Predicted=0.222124, Expected=0.251017
# Month=376, Predicted=0.284984, Expected=0.317190
# Month=377, Predicted=0.255667, Expected=0.279658
# Month=378, Predicted=0.251262, Expected=0.275108
# Month=379, Predicted=0.227932, Expected=0.262815
# Month=380, Predicted=0.238297, Expected=0.271771
# Month=381, Predicted=0.204742, Expected=0.230015
# Month=382, Predicted=0.190495, Expected=0.191193
# Month=383, Predicted=0.161655, Expected=0.202156
# Month=384, Predicted=0.205528, Expected=0.255749
# Month=385, Predicted=0.196790, Expected=0.207410
# Month=386, Predicted=0.253256, Expected=0.315456
# Month=387, Predicted=0.220015, Expected=0.276112
# Month=388, Predicted=0.281566, Expected=0.320762
# Month=389, Predicted=0.248685, Expected=0.268095
# Month=390, Predicted=0.255062, Expected=0.291391
# Month=391, Predicted=0.225960, Expected=0.252607
# Month=392, Predicted=0.259971, Expected=0.258148
# Month=393, Predicted=0.228088, Expected=0.220981
# Month=394, Predicted=0.200387, Expected=0.170882
# Month=395, Predicted=0.183397, Expected=0.207449
# Month=396, Predicted=0.218852, Expected=0.263584
# Month=397, Predicted=0.205082, Expected=0.187999
# Month=398, Predicted=0.278135, Expected=0.295341
# Month=399, Predicted=0.231375, Expected=0.266856
# Month=400, Predicted=0.283139, Expected=0.307269
# Month=401, Predicted=0.248303, Expected=0.247588
# Month=402, Predicted=0.285334, Expected=0.304179
# Month=403, Predicted=0.269881, Expected=0.291156
# Month=404, Predicted=0.274775, Expected=0.288158
# Month=405, Predicted=0.247336, Expected=0.262958
# Month=406, Predicted=0.228455, Expected=0.215336
# Month=407, Predicted=0.200291, Expected=0.226704
# Month=408, Predicted=0.246079, Expected=0.316251
# Month=409, Predicted=0.227147, Expected=0.260116
# Month=410, Predicted=0.257419, Expected=0.330943
# Month=411, Predicted=0.246878, Expected=0.311350
# Month=412, Predicted=0.285248, Expected=0.354070
# Month=413, Predicted=0.248498, Expected=0.316838
# Month=414, Predicted=0.286674, Expected=0.382750
# Month=415, Predicted=0.272529, Expected=0.328871
# Month=416, Predicted=0.292982, Expected=0.332677
# Month=417, Predicted=0.272934, Expected=0.308208
# Month=418, Predicted=0.226574, Expected=0.251134
# Month=419, Predicted=0.213430, Expected=0.297127
# Month=420, Predicted=0.226569, Expected=0.309016
# Month=421, Predicted=0.234751, Expected=0.271041
# Month=422, Predicted=0.257284, Expected=0.343497
# Month=423, Predicted=0.247423, Expected=0.311336
# Month=424, Predicted=0.266506, Expected=0.318337
# Month=425, Predicted=0.243141, Expected=0.312797
# Month=426, Predicted=0.284963, Expected=0.372165
# Month=427, Predicted=0.280159, Expected=0.349859
# Month=428, Predicted=0.304055, Expected=0.352949
# Month=429, Predicted=0.259019, Expected=0.284859
# Month=430, Predicted=0.235914, Expected=0.240796
# Month=431, Predicted=0.214809, Expected=0.275591
# Month=432, Predicted=0.234331, Expected=0.314087
# Month=433, Predicted=0.211560, Expected=0.251082
# Month=434, Predicted=0.250062, Expected=0.354396
# Month=435, Predicted=0.227796, Expected=0.294832
# Month=436, Predicted=0.242541, Expected=0.303228
# Month=437, Predicted=0.248817, Expected=0.316395
# Month=438, Predicted=0.277353, Expected=0.366767
# Month=439, Predicted=0.255530, Expected=0.343993
# Month=440, Predicted=0.284857, Expected=0.352727
# Month=441, Predicted=0.247909, Expected=0.305900
# Month=442, Predicted=0.213873, Expected=0.251903
# Month=443, Predicted=0.193349, Expected=0.276177
# Month=444, Predicted=0.207878, Expected=0.282135
# Month=445, Predicted=0.191570, Expected=0.235399
# Month=446, Predicted=0.251720, Expected=0.317659
# Month=447, Predicted=0.216719, Expected=0.258161
# Month=448, Predicted=0.251554, Expected=0.311923
# Month=449, Predicted=0.232315, Expected=0.286385
# Month=450, Predicted=0.252268, Expected=0.312158
# Month=451, Predicted=0.266058, Expected=0.317685
# Month=452, Predicted=0.269644, Expected=0.299630
# Month=453, Predicted=0.225501, Expected=0.246976
# Month=454, Predicted=0.204296, Expected=0.206106
# Month=455, Predicted=0.188992, Expected=0.222610
# Month=456, Predicted=0.197166, Expected=0.235908
# Month=457, Predicted=0.206935, Expected=0.231658
# Month=458, Predicted=0.236689, Expected=0.292864
# Month=459, Predicted=0.208134, Expected=0.231306
# Month=460, Predicted=0.262694, Expected=0.280753
# Month=461, Predicted=0.230336, Expected=0.253963
# Month=462, Predicted=0.243264, Expected=0.309368
# Month=463, Predicted=0.249652, Expected=0.298509
# Month=464, Predicted=0.260996, Expected=0.276451
# Month=465, Predicted=0.241112, Expected=0.258943
# Month=466, Predicted=0.216352, Expected=0.212051
# Month=467, Predicted=0.175751, Expected=0.211151
# Month=468, Predicted=0.206132, Expected=0.271315
# Month=469, Predicted=0.193151, Expected=0.198128
# Month=470, Predicted=0.264695, Expected=0.299982
# Month=471, Predicted=0.213331, Expected=0.264158
# Month=472, Predicted=0.279024, Expected=0.289592
# Month=473, Predicted=0.228678, Expected=0.229481
# Month=474, Predicted=0.286006, Expected=0.318363
# Month=475, Predicted=0.246018, Expected=0.282995
# Month=476, Predicted=0.283319, Expected=0.298717
# Month=477, Predicted=0.266278, Expected=0.266283
# Month=478, Predicted=0.232051, Expected=0.197176
# Month=479, Predicted=0.184683, Expected=0.196433
# Month=480, Predicted=0.232023, Expected=0.291573
# Month=481, Predicted=0.220009, Expected=0.220811
# Month=482, Predicted=0.239079, Expected=0.293151
# Month=483, Predicted=0.238499, Expected=0.306383
# Month=484, Predicted=0.258971, Expected=0.310098
# Month=485, Predicted=0.262401, Expected=0.291273
# Month=486, Predicted=0.302427, Expected=0.338830
# Month=487, Predicted=0.288630, Expected=0.328675
# Month=488, Predicted=0.307169, Expected=0.356782
# Month=489, Predicted=0.273068, Expected=0.306865
# Month=490, Predicted=0.227648, Expected=0.227916
# Month=491, Predicted=0.216931, Expected=0.289096
# Month=492, Predicted=0.230361, Expected=0.309798
# Month=493, Predicted=0.233102, Expected=0.234917
# Month=494, Predicted=0.284156, Expected=0.330265
# Month=495, Predicted=0.263325, Expected=0.295067
# Month=496, Predicted=0.270950, Expected=0.344592
# Month=497, Predicted=0.272261, Expected=0.354904
# Month=498, Predicted=0.301788, Expected=0.395448
# Month=499, Predicted=0.285383, Expected=0.362830
# Month=500, Predicted=0.319772, Expected=0.363886
# Month=501, Predicted=0.288462, Expected=0.299890
# Month=502, Predicted=0.252478, Expected=0.248827
# Month=503, Predicted=0.216471, Expected=0.278328
# Month=504, Predicted=0.258239, Expected=0.354513
# Month=505, Predicted=0.242392, Expected=0.305431
# Month=506, Predicted=0.281783, Expected=0.392919
# Month=507, Predicted=0.235231, Expected=0.295328
# Month=508, Predicted=0.283753, Expected=0.374850
# Month=509, Predicted=0.256592, Expected=0.324868
# Month=510, Predicted=0.288201, Expected=0.383376
# Month=511, Predicted=0.303692, Expected=0.398029
# Month=512, Predicted=0.333588, Expected=0.400688
# Month=513, Predicted=0.273221, Expected=0.322404
# Month=514, Predicted=0.244004, Expected=0.284494
# Month=515, Predicted=0.226393, Expected=0.308077
# Month=516, Predicted=0.253520, Expected=0.324790
# Month=517, Predicted=0.257266, Expected=0.278002
# Month=518, Predicted=0.280628, Expected=0.354891
# Month=519, Predicted=0.251993, Expected=0.304949
# Month=520, Predicted=0.279543, Expected=0.348986
# Month=521, Predicted=0.269502, Expected=0.323134
# Month=522, Predicted=0.299814, Expected=0.402370
# Month=523, Predicted=0.312078, Expected=0.391107
# Month=524, Predicted=0.335523, Expected=0.350459
# Month=525, Predicted=0.309546, Expected=0.312210
# Month=526, Predicted=0.275281, Expected=0.274978
# Month=527, Predicted=0.237929, Expected=0.315704
# Month=528, Predicted=0.251552, Expected=0.363456
# Month=529, Predicted=0.236047, Expected=0.294246
# Month=530, Predicted=0.262106, Expected=0.374276
# Month=531, Predicted=0.220099, Expected=0.321922
# Month=532, Predicted=0.252899, Expected=0.373442
# Month=533, Predicted=0.231642, Expected=0.327893
# Month=534, Predicted=0.283472, Expected=0.432523
# Month=535, Predicted=0.288795, Expected=0.438585
# Month=536, Predicted=0.301132, Expected=0.422759
# Month=537, Predicted=0.271050, Expected=0.375919
# Month=538, Predicted=0.219212, Expected=0.294141
# Month=539, Predicted=0.186324, Expected=0.291143
# Month=540, Predicted=0.225809, Expected=0.340043
# Month=541, Predicted=0.203890, Expected=0.239949
# Month=542, Predicted=0.261317, Expected=0.303749
# Month=543, Predicted=0.209498, Expected=0.265396
# Month=544, Predicted=0.233589, Expected=0.293633
# Month=545, Predicted=0.213885, Expected=0.271732
# Month=546, Predicted=0.273686, Expected=0.340238
# Month=547, Predicted=0.261049, Expected=0.315156
# Month=548, Predicted=0.285164, Expected=0.314309
# Month=549, Predicted=0.224254, Expected=0.234474
# Month=550, Predicted=0.192603, Expected=0.196329
# Month=551, Predicted=0.160161, Expected=0.209013
# Month=552, Predicted=0.210159, Expected=0.280649
# Month=553, Predicted=0.221524, Expected=0.239988
# Month=554, Predicted=0.236257, Expected=0.275512
# Month=555, Predicted=0.193461, Expected=0.224462
# Month=556, Predicted=0.229127, Expected=0.257118
# Month=557, Predicted=0.208847, Expected=0.254185
# Month=558, Predicted=0.264088, Expected=0.320879
# Month=559, Predicted=0.259077, Expected=0.302498
# Month=560, Predicted=0.283341, Expected=0.298574
# Month=561, Predicted=0.218012, Expected=0.217839
# Month=562, Predicted=0.187580, Expected=0.175549
# Month=563, Predicted=0.157388, Expected=0.204242
# Month=564, Predicted=0.206059, Expected=0.282761
# Month=565, Predicted=0.172211, Expected=0.199640
# Month=566, Predicted=0.216006, Expected=0.271966
# Month=567, Predicted=0.185802, Expected=0.221972
# Month=568, Predicted=0.218373, Expected=0.229728
# Month=569, Predicted=0.225166, Expected=0.251564
# Month=570, Predicted=0.257302, Expected=0.313696
# Month=571, Predicted=0.240275, Expected=0.295015
# Month=572, Predicted=0.256539, Expected=0.286737
# Month=573, Predicted=0.210914, Expected=0.220603
# Month=574, Predicted=0.171795, Expected=0.159736
# Month=575, Predicted=0.151659, Expected=0.179017
# Month=576, Predicted=0.203326, Expected=0.216900
# Month=577, Predicted=0.173924, Expected=0.156203
# Month=578, Predicted=0.202280, Expected=0.230119
# Month=579, Predicted=0.183058, Expected=0.207892
# Month=580, Predicted=0.196150, Expected=0.231958
# Month=581, Predicted=0.192576, Expected=0.226847
# Month=582, Predicted=0.243343, Expected=0.259738
# Month=583, Predicted=0.258701, Expected=0.248357
# Month=584, Predicted=0.261067, Expected=0.232075
# Month=585, Predicted=0.212376, Expected=0.184896
# Month=586, Predicted=0.196373, Expected=0.153726
# Month=587, Predicted=0.175115, Expected=0.187699
# Month=588, Predicted=0.189372, Expected=0.206915
# Month=589, Predicted=0.156956, Expected=0.145461
# Month=590, Predicted=0.218496, Expected=0.213081
# Month=591, Predicted=0.168046, Expected=0.133624
# Month=592, Predicted=0.192064, Expected=0.179603

# %%
# Skalierung zurücksetzten
predictions_train_100=np.reshape(predictions_train_100,(len(predictions_train_100),1))

# %%
predictions_train_100=scaler.inverse_transform(predictions_train_100)

# %%
# Verschiebung der Trainingsvorhersage zum Plotten
trainPredictPlot = np.empty_like(ZR_100)
trainPredictPlot=trainPredictPlot.reshape(len(ZR_100))
trainPredictPlot[:]=[0]*len(ZR_100)
predictions_train_100=predictions_train_100.reshape(len(predictions_train_100))
trainPredictPlot[(look_back+look_forward-1):len(predictions_train_100)+(look_back+look_forward-1)] = predictions_train_100

# Verschiebung der Testvorhersage zum Plotten
testPredictPlot = np.empty_like(ZR_100)
testPredictPlot=testPredictPlot.reshape(len(ZR_100))
testPredictPlot[:]=[0]*len(ZR_100)
predictions_100=predictions_100.reshape(len(predictions_100))
testPredictPlot[-len(predictions_100):] = predictions_100

# Plotten der baseline und  der Vorhersagen
plt.plot(ZR_100, color='blue')
plt.plot(trainPredictPlot, color='orange') 
plt.plot(testPredictPlot, color='green')
plt.show()

# %%
# Replizierbarkeit gewährleisten
np.random.seed(0)

# %%
# Modell anpassen: 46% der originalen Datensatzstärke
lstm_model_46 = fit_lstm(ZR_N46_TR_I, 1, 200, 4)

# %%
# Validierung des Modells anhand der Testdaten
predictions_46 = list()
for i in range(len(ZR_N46_TE_I)):
    # make forecast 
    X, y = ZR_N46_TE_I.iloc[i, 0:-1], ZR_N46_TE_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_46, 1, X)
    predictions_46.append(yhat)
    expected = ZR_N46[len(ZR_N46_TR_I) + i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.152017, Expected=0.159162
# Month=2, Predicted=0.128475, Expected=0.225074
# Month=3, Predicted=0.188980, Expected=0.211464
# Month=4, Predicted=0.119992, Expected=0.192770
# Month=5, Predicted=0.127899, Expected=0.136283
# Month=6, Predicted=0.079064, Expected=0.086679
# Month=7, Predicted=0.096446, Expected=0.118332
# Month=8, Predicted=0.084498, Expected=0.122777
# Month=9, Predicted=0.103458, Expected=0.068376
# Month=10, Predicted=0.081947, Expected=0.119297
# Month=11, Predicted=0.109632, Expected=0.101215
# Month=12, Predicted=0.115488, Expected=0.116624
# Month=13, Predicted=0.176050, Expected=0.133311
# Month=14, Predicted=0.170369, Expected=0.176657
# Month=15, Predicted=0.190288, Expected=0.176722
# Month=16, Predicted=0.142209, Expected=0.166215
# Month=17, Predicted=0.127349, Expected=0.110797
# Month=18, Predicted=0.080466, Expected=0.063162
# Month=19, Predicted=0.131073, Expected=0.088700
# Month=20, Predicted=0.079447, Expected=0.096196
# Month=21, Predicted=0.120380, Expected=0.044585
# Month=22, Predicted=0.040421, Expected=0.100733
# Month=23, Predicted=0.125328, Expected=0.055144
# Month=24, Predicted=0.119695, Expected=0.134575
# Month=25, Predicted=0.184313, Expected=0.111605
# Month=26, Predicted=0.180324, Expected=0.170673
# Month=27, Predicted=0.175947, Expected=0.164337
# Month=28, Predicted=0.155301, Expected=0.159436
# Month=29, Predicted=0.109413, Expected=0.125111
# Month=30, Predicted=0.089460, Expected=0.059759
# Month=31, Predicted=0.108312, Expected=0.051298
# Month=32, Predicted=0.078776, Expected=0.121995
# Month=33, Predicted=0.074733, Expected=0.041977
# Month=34, Predicted=0.089381, Expected=0.108789
# Month=35, Predicted=0.105721, Expected=0.042694
# Month=36, Predicted=0.129768, Expected=0.109793
# Month=37, Predicted=0.176264, Expected=0.124863
# Month=38, Predicted=0.175712, Expected=0.180568
# Month=39, Predicted=0.180836, Expected=0.190919
# Month=40, Predicted=0.133300, Expected=0.182093
# Month=41, Predicted=0.092720, Expected=0.150701
# Month=42, Predicted=0.079567, Expected=0.084176
# Month=43, Predicted=0.106607, Expected=0.093119
# Month=44, Predicted=0.073059, Expected=0.138173
# Month=45, Predicted=0.088559, Expected=0.071049
# Month=46, Predicted=0.082342, Expected=0.064296
# Month=47, Predicted=0.095016, Expected=0.092924
# Month=48, Predicted=0.135885, Expected=0.123559
# Month=49, Predicted=0.174322, Expected=0.135488
# Month=50, Predicted=0.169472, Expected=0.200696
# Month=51, Predicted=0.169413, Expected=0.169526
# Month=52, Predicted=0.129669, Expected=0.173945
# Month=53, Predicted=0.120774, Expected=0.116507
# Month=54, Predicted=0.099043, Expected=0.049317
# Month=55, Predicted=0.110563, Expected=0.065599
# Month=56, Predicted=0.063099, Expected=0.094319
# Month=57, Predicted=0.097396, Expected=0.028250
# Month=58, Predicted=0.056940, Expected=0.075246
# Month=59, Predicted=0.095405, Expected=0.068533
# Month=60, Predicted=0.116256, Expected=0.086236
# Month=61, Predicted=0.168683, Expected=0.115190
# Month=62, Predicted=0.165270, Expected=0.187360
# Month=63, Predicted=0.186892, Expected=0.155812
# Month=64, Predicted=0.146983, Expected=0.152422
# Month=65, Predicted=0.119031, Expected=0.089169
# Month=66, Predicted=0.087909, Expected=0.044311
# Month=67, Predicted=0.094156, Expected=0.077554
# Month=68, Predicted=0.071387, Expected=0.095857
# Month=69, Predicted=0.089318, Expected=0.031209
# Month=70, Predicted=0.064389, Expected=0.098634
# Month=71, Predicted=0.111806, Expected=0.053449
# Month=72, Predicted=0.128476, Expected=0.106038
# Month=73, Predicted=0.161764, Expected=0.125293
# Month=74, Predicted=0.173846, Expected=0.182484
# Month=75, Predicted=0.181485, Expected=0.155460
# Month=76, Predicted=0.130914, Expected=0.172146
# Month=77, Predicted=0.112438, Expected=0.142045
# Month=78, Predicted=0.079271, Expected=0.086771
# Month=79, Predicted=0.103682, Expected=0.092155
# Month=80, Predicted=0.079802, Expected=0.089717
# Month=81, Predicted=0.087657, Expected=0.033895
# Month=82, Predicted=0.075533, Expected=0.071870
# Month=83, Predicted=0.112413, Expected=0.024391
# Month=84, Predicted=0.121223, Expected=0.093067
# Month=85, Predicted=0.173040, Expected=0.117680
# Month=86, Predicted=0.187396, Expected=0.172720
# Month=87, Predicted=0.181626, Expected=0.167988
# Month=88, Predicted=0.163330, Expected=0.161496
# Month=89, Predicted=0.114883, Expected=0.104513
# Month=90, Predicted=0.082049, Expected=0.049160
# Month=91, Predicted=0.107932, Expected=0.056083
# Month=92, Predicted=0.073793, Expected=0.086145
# Month=93, Predicted=0.108561, Expected=0.043802
# Month=94, Predicted=0.079827, Expected=0.092637
# Month=95, Predicted=0.124099, Expected=0.068298
# Month=96, Predicted=0.136657, Expected=0.114238
# Month=97, Predicted=0.206623, Expected=0.099142
# Month=98, Predicted=0.197893, Expected=0.175027
# Month=99, Predicted=0.205318, Expected=0.179303
# Month=100, Predicted=0.157090, Expected=0.152461
# Month=101, Predicted=0.128401, Expected=0.129530
# Month=102, Predicted=0.098037, Expected=0.073917
# Month=103, Predicted=0.128697, Expected=0.069641
# Month=104, Predicted=0.091593, Expected=0.104279
# Month=105, Predicted=0.103065, Expected=0.024326
# Month=106, Predicted=0.098658, Expected=0.082156
# Month=107, Predicted=0.127218, Expected=0.074529
# Month=108, Predicted=0.161289, Expected=0.115347
# Month=109, Predicted=0.218935, Expected=0.119270
# Month=110, Predicted=0.208665, Expected=0.212338
# Month=111, Predicted=0.228938, Expected=0.189289
# Month=112, Predicted=0.182229, Expected=0.193005
# Month=113, Predicted=0.151704, Expected=0.133037
# Month=114, Predicted=0.120044, Expected=0.066030
# Month=115, Predicted=0.135697, Expected=0.081673
# Month=116, Predicted=0.101896, Expected=0.125111
# Month=117, Predicted=0.147819, Expected=0.070710
# Month=118, Predicted=0.116381, Expected=0.109506
# Month=119, Predicted=0.151073, Expected=0.106104
# Month=120, Predicted=0.178423, Expected=0.147090
# Month=121, Predicted=0.232689, Expected=0.164598
# Month=122, Predicted=0.248776, Expected=0.248214
# Month=123, Predicted=0.253738, Expected=0.215597
# Month=124, Predicted=0.205171, Expected=0.222545
# Month=125, Predicted=0.168435, Expected=0.178286
# Month=126, Predicted=0.142672, Expected=0.107107
# Month=127, Predicted=0.170669, Expected=0.128761
# Month=128, Predicted=0.125057, Expected=0.150832
# Month=129, Predicted=0.148476, Expected=0.070762
# Month=130, Predicted=0.115936, Expected=0.137600
# Month=131, Predicted=0.161049, Expected=0.113991
# Month=132, Predicted=0.203177, Expected=0.169930
# Month=133, Predicted=0.237179, Expected=0.202547
# Month=134, Predicted=0.256575, Expected=0.264757
# Month=135, Predicted=0.248483, Expected=0.257353
# Month=136, Predicted=0.212750, Expected=0.256271
# Month=137, Predicted=0.170948, Expected=0.206967

# %%
# Skalierung zurücksetzten
predictions_46=np.reshape(predictions_46,(len(predictions_46),1))
predictions_46=scaler.inverse_transform(predictions_46)

# %%
# Modellperformance bewerten
mse = mean_squared_error(ZR_46[-len(predictions_46):], predictions_46)
print('Test MSE: %.3f' % mse)
# line plot of observed vs predicted
plt.plot(ZR_46[-len(predictions_46):], color='blue')
plt.plot(predictions_46, color='orange')
plt.show()
# Out:
# Test MSE: 6922417.454

# %%
predictions_train_46 = list()
for i in range(len(ZR_N46_TR_I)):
    # make forecast 
    X, y = ZR_N46_TR_I.iloc[i, 0:-1], ZR_N46_TR_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_46, 1, X)
    predictions_train_46.append(yhat)
    expected = ZR_N46[ i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.253916, Expected=0.276451
# Month=2, Predicted=0.193142, Expected=0.258943
# Month=3, Predicted=0.193450, Expected=0.212051
# Month=4, Predicted=0.140234, Expected=0.211151
# Month=5, Predicted=0.184636, Expected=0.271315
# Month=6, Predicted=0.172967, Expected=0.198128
# Month=7, Predicted=0.227940, Expected=0.299982
# Month=8, Predicted=0.191188, Expected=0.264158
# Month=9, Predicted=0.239093, Expected=0.289592
# Month=10, Predicted=0.198514, Expected=0.229481
# Month=11, Predicted=0.267834, Expected=0.318363
# Month=12, Predicted=0.219162, Expected=0.282995
# Month=13, Predicted=0.262372, Expected=0.298717
# Month=14, Predicted=0.220376, Expected=0.266283
# Month=15, Predicted=0.193020, Expected=0.197176
# Month=16, Predicted=0.151218, Expected=0.196433
# Month=17, Predicted=0.216385, Expected=0.291573
# Month=18, Predicted=0.183003, Expected=0.220811
# Month=19, Predicted=0.214685, Expected=0.293151
# Month=20, Predicted=0.218144, Expected=0.306383
# Month=21, Predicted=0.218604, Expected=0.310098
# Month=22, Predicted=0.244612, Expected=0.291273
# Month=23, Predicted=0.270764, Expected=0.338830
# Month=24, Predicted=0.270781, Expected=0.328675
# Month=25, Predicted=0.275379, Expected=0.356782
# Month=26, Predicted=0.233649, Expected=0.306865
# Month=27, Predicted=0.191851, Expected=0.227916
# Month=28, Predicted=0.192290, Expected=0.289096
# Month=29, Predicted=0.201377, Expected=0.309798
# Month=30, Predicted=0.203125, Expected=0.234917
# Month=31, Predicted=0.246819, Expected=0.330265
# Month=32, Predicted=0.232095, Expected=0.295067
# Month=33, Predicted=0.237927, Expected=0.344592
# Month=34, Predicted=0.265662, Expected=0.354904
# Month=35, Predicted=0.273051, Expected=0.395448
# Month=36, Predicted=0.270356, Expected=0.362830
# Month=37, Predicted=0.284150, Expected=0.363886
# Month=38, Predicted=0.238450, Expected=0.299890
# Month=39, Predicted=0.208109, Expected=0.248827
# Month=40, Predicted=0.188078, Expected=0.278328
# Month=41, Predicted=0.239463, Expected=0.354513
# Month=42, Predicted=0.212636, Expected=0.305431
# Month=43, Predicted=0.250318, Expected=0.392919
# Month=44, Predicted=0.202729, Expected=0.295328
# Month=45, Predicted=0.254509, Expected=0.374850
# Month=46, Predicted=0.232492, Expected=0.324868
# Month=47, Predicted=0.274299, Expected=0.383376
# Month=48, Predicted=0.289272, Expected=0.398029
# Month=49, Predicted=0.296451, Expected=0.400688
# Month=50, Predicted=0.231284, Expected=0.322404
# Month=51, Predicted=0.213765, Expected=0.284494
# Month=52, Predicted=0.198036, Expected=0.308077
# Month=53, Predicted=0.230833, Expected=0.324790
# Month=54, Predicted=0.224281, Expected=0.278002
# Month=55, Predicted=0.242968, Expected=0.354891
# Month=56, Predicted=0.222395, Expected=0.304949
# Month=57, Predicted=0.246436, Expected=0.348986
# Month=58, Predicted=0.253394, Expected=0.323134
# Month=59, Predicted=0.280375, Expected=0.402370
# Month=60, Predicted=0.291950, Expected=0.391107
# Month=61, Predicted=0.290972, Expected=0.350459
# Month=62, Predicted=0.263257, Expected=0.312210
# Month=63, Predicted=0.231922, Expected=0.274978
# Month=64, Predicted=0.206008, Expected=0.315704
# Month=65, Predicted=0.226718, Expected=0.363456
# Month=66, Predicted=0.205975, Expected=0.294246
# Month=67, Predicted=0.224300, Expected=0.374276
# Month=68, Predicted=0.188926, Expected=0.321922
# Month=69, Predicted=0.220602, Expected=0.373442
# Month=70, Predicted=0.213391, Expected=0.327893
# Month=71, Predicted=0.274385, Expected=0.432523
# Month=72, Predicted=0.274295, Expected=0.438585
# Month=73, Predicted=0.278134, Expected=0.422759
# Month=74, Predicted=0.241393, Expected=0.375919
# Month=75, Predicted=0.190409, Expected=0.294141
# Month=76, Predicted=0.171002, Expected=0.291143
# Month=77, Predicted=0.203804, Expected=0.340043
# Month=78, Predicted=0.180593, Expected=0.239949
# Month=79, Predicted=0.226047, Expected=0.303749
# Month=80, Predicted=0.179447, Expected=0.265396
# Month=81, Predicted=0.204344, Expected=0.293633
# Month=82, Predicted=0.195557, Expected=0.271732
# Month=83, Predicted=0.254642, Expected=0.340238
# Month=84, Predicted=0.238065, Expected=0.315156
# Month=85, Predicted=0.249664, Expected=0.314309
# Month=86, Predicted=0.184981, Expected=0.234474
# Month=87, Predicted=0.163796, Expected=0.196329
# Month=88, Predicted=0.140341, Expected=0.209013
# Month=89, Predicted=0.195165, Expected=0.280649
# Month=90, Predicted=0.191626, Expected=0.239988
# Month=91, Predicted=0.194117, Expected=0.275512
# Month=92, Predicted=0.171626, Expected=0.224462
# Month=93, Predicted=0.189974, Expected=0.257118
# Month=94, Predicted=0.190523, Expected=0.254185
# Month=95, Predicted=0.246312, Expected=0.320879
# Month=96, Predicted=0.232972, Expected=0.302498
# Month=97, Predicted=0.245728, Expected=0.298574
# Month=98, Predicted=0.176014, Expected=0.217839
# Month=99, Predicted=0.162270, Expected=0.175549
# Month=100, Predicted=0.135521, Expected=0.204242
# Month=101, Predicted=0.186704, Expected=0.282761
# Month=102, Predicted=0.144515, Expected=0.199640
# Month=103, Predicted=0.185161, Expected=0.271966
# Month=104, Predicted=0.150083, Expected=0.221972
# Month=105, Predicted=0.183613, Expected=0.229728
# Month=106, Predicted=0.198857, Expected=0.251564
# Month=107, Predicted=0.233879, Expected=0.313696
# Month=108, Predicted=0.216969, Expected=0.295015
# Month=109, Predicted=0.225656, Expected=0.286737
# Month=110, Predicted=0.169185, Expected=0.220603
# Month=111, Predicted=0.146219, Expected=0.159736
# Month=112, Predicted=0.130159, Expected=0.179017
# Month=113, Predicted=0.170367, Expected=0.216900
# Month=114, Predicted=0.138743, Expected=0.156203
# Month=115, Predicted=0.171073, Expected=0.230119
# Month=116, Predicted=0.152914, Expected=0.207892
# Month=117, Predicted=0.156830, Expected=0.231958
# Month=118, Predicted=0.172175, Expected=0.226847
# Month=119, Predicted=0.212963, Expected=0.259738
# Month=120, Predicted=0.222171, Expected=0.248357
# Month=121, Predicted=0.219048, Expected=0.232075
# Month=122, Predicted=0.172545, Expected=0.184896
# Month=123, Predicted=0.171505, Expected=0.153726
# Month=124, Predicted=0.148546, Expected=0.187699
# Month=125, Predicted=0.163192, Expected=0.206915
# Month=126, Predicted=0.132555, Expected=0.145461
# Month=127, Predicted=0.174531, Expected=0.213081
# Month=128, Predicted=0.125500, Expected=0.133624
# Month=129, Predicted=0.162669, Expected=0.179603
# Month=130, Predicted=0.175992, Expected=0.223510
# Month=131, Predicted=0.223970, Expected=0.280323
# Month=132, Predicted=0.239578, Expected=0.269972
# Month=133, Predicted=0.237943, Expected=0.253233
# Month=134, Predicted=0.211700, Expected=0.232648
# Month=135, Predicted=0.170586, Expected=0.170517
# Month=136, Predicted=0.156526, Expected=0.170399
# Month=137, Predicted=0.190635, Expected=0.208309
# Month=138, Predicted=0.181619, Expected=0.183214
# Month=139, Predicted=0.179695, Expected=0.224774
# Month=140, Predicted=0.139044, Expected=0.178704
# Month=141, Predicted=0.183955, Expected=0.210825
# Month=142, Predicted=0.201904, Expected=0.232896
# Month=143, Predicted=0.250395, Expected=0.311024
# Month=144, Predicted=0.238121, Expected=0.304401
# Month=145, Predicted=0.236115, Expected=0.303071
# Month=146, Predicted=0.203319, Expected=0.260064
# Month=147, Predicted=0.174704, Expected=0.215792
# Month=148, Predicted=0.152976, Expected=0.247627
# Month=149, Predicted=0.185707, Expected=0.292355
# Month=150, Predicted=0.162660, Expected=0.218530
# Month=151, Predicted=0.167178, Expected=0.234773
# Month=152, Predicted=0.173902, Expected=0.254054
# Month=153, Predicted=0.186148, Expected=0.275108
# Month=154, Predicted=0.205227, Expected=0.281731
# Month=155, Predicted=0.222818, Expected=0.335089
# Month=156, Predicted=0.239485, Expected=0.299082
# Month=157, Predicted=0.237564, Expected=0.293776
# Month=158, Predicted=0.207675, Expected=0.238645
# Month=159, Predicted=0.147207, Expected=0.159944
# Month=160, Predicted=0.152079, Expected=0.208283
# Month=161, Predicted=0.169447, Expected=0.247275
# Month=162, Predicted=0.154468, Expected=0.174102
# Month=163, Predicted=0.167928, Expected=0.227734
# Month=164, Predicted=0.145670, Expected=0.213798
# Month=165, Predicted=0.159900, Expected=0.218621
# Month=166, Predicted=0.177954, Expected=0.202495
# Month=167, Predicted=0.243022, Expected=0.310567
# Month=168, Predicted=0.223042, Expected=0.283178
# Month=169, Predicted=0.241600, Expected=0.293346
# Month=170, Predicted=0.178938, Expected=0.217435
# Month=171, Predicted=0.152814, Expected=0.167153
# Month=172, Predicted=0.118220, Expected=0.181872
# Month=173, Predicted=0.173652, Expected=0.232283
# Month=174, Predicted=0.143501, Expected=0.158367
# Month=175, Predicted=0.184937, Expected=0.209000
# Month=176, Predicted=0.136517, Expected=0.180581
# Month=177, Predicted=0.172600, Expected=0.226143
# Month=178, Predicted=0.182869, Expected=0.226078
# Month=179, Predicted=0.226786, Expected=0.293085
# Month=180, Predicted=0.208643, Expected=0.268290
# Month=181, Predicted=0.224733, Expected=0.268225
# Month=182, Predicted=0.156659, Expected=0.184088
# Month=183, Predicted=0.146929, Expected=0.128422
# Month=184, Predicted=0.127050, Expected=0.176722
# Month=185, Predicted=0.171869, Expected=0.231984
# Month=186, Predicted=0.152212, Expected=0.190189
# Month=187, Predicted=0.138576, Expected=0.215688
# Month=188, Predicted=0.125408, Expected=0.173320
# Month=189, Predicted=0.155342, Expected=0.222715
# Month=190, Predicted=0.175503, Expected=0.202678
# Month=191, Predicted=0.201238, Expected=0.256088
# Month=192, Predicted=0.209389, Expected=0.265109
# Month=193, Predicted=0.204484, Expected=0.241761
# Month=194, Predicted=0.164657, Expected=0.196303
# Month=195, Predicted=0.145933, Expected=0.140220
# Month=196, Predicted=0.122128, Expected=0.166410
# Month=197, Predicted=0.149659, Expected=0.208401
# Month=198, Predicted=0.100454, Expected=0.099051
# Month=199, Predicted=0.143278, Expected=0.169109
# Month=200, Predicted=0.118847, Expected=0.142123
# Month=201, Predicted=0.158351, Expected=0.199640
# Month=202, Predicted=0.138124, Expected=0.175275
# Month=203, Predicted=0.192421, Expected=0.240562
# Month=204, Predicted=0.191769, Expected=0.230185
# Month=205, Predicted=0.193422, Expected=0.198623
# Month=206, Predicted=0.163383, Expected=0.172577
# Month=207, Predicted=0.137612, Expected=0.120639
# Month=208, Predicted=0.101821, Expected=0.122282
# Month=209, Predicted=0.144925, Expected=0.167949
# Month=210, Predicted=0.101738, Expected=0.101971
# Month=211, Predicted=0.133489, Expected=0.168913
# Month=212, Predicted=0.094659, Expected=0.130182
# Month=213, Predicted=0.131467, Expected=0.142958
# Month=214, Predicted=0.142200, Expected=0.144900
# Month=215, Predicted=0.189837, Expected=0.223797
# Month=216, Predicted=0.193897, Expected=0.204372
# Month=217, Predicted=0.193444, Expected=0.202521
# Month=218, Predicted=0.170591, Expected=0.173424
# Month=219, Predicted=0.117471, Expected=0.096730
# Month=220, Predicted=0.103581, Expected=0.122269
# Month=221, Predicted=0.120086, Expected=0.145474
# Month=222, Predicted=0.101078, Expected=0.072991
# Month=223, Predicted=0.123770, Expected=0.123234
# Month=224, Predicted=0.095057, Expected=0.118058
# Month=225, Predicted=0.124923, Expected=0.147781
# Month=226, Predicted=0.127650, Expected=0.146569
# Month=227, Predicted=0.208195, Expected=0.235256
# Month=228, Predicted=0.183882, Expected=0.194804
# Month=229, Predicted=0.210000, Expected=0.205116
# Month=230, Predicted=0.142055, Expected=0.145422
# Month=231, Predicted=0.116105, Expected=0.077567
# Month=232, Predicted=0.101387, Expected=0.104383
# Month=233, Predicted=0.138403, Expected=0.152696
# Month=234, Predicted=0.094362, Expected=0.091229
# Month=235, Predicted=0.103158, Expected=0.114682
# Month=236, Predicted=0.092134, Expected=0.101046
# Month=237, Predicted=0.114014, Expected=0.112909

# %%
# Skalierung zurücksetzten
predictions_train_46=np.reshape(predictions_train_46,(len(predictions_train_46),1))
predictions_train_46=scaler.inverse_transform(predictions_train_46)

# %%
# Verschiebung der Trainingsvorhersage zum Plotten
trainPredictPlot = np.empty_like(ZR_46)
trainPredictPlot=trainPredictPlot.reshape(len(ZR_46))
trainPredictPlot[:]=[0]*len(ZR_46)
predictions_train_46=predictions_train_46.reshape(len(predictions_train_46))
trainPredictPlot[(look_back+look_forward-1):len(predictions_train_46)+(look_back+look_forward-1)] = predictions_train_46

# Verschiebung der Testvorhersage zum Plotten
testPredictPlot = np.empty_like(ZR_46)
testPredictPlot=testPredictPlot.reshape(len(ZR_46))
testPredictPlot[:]=[0]*len(ZR_46)
predictions_46=predictions_46.reshape(len(predictions_46))
testPredictPlot[-len(predictions_46):] = predictions_46

# Plotten der baseline und  der Vorhersagen
plt.plot(ZR_46, color='blue')
plt.plot(trainPredictPlot, color='orange')
plt.plot(testPredictPlot, color='green')
plt.show()

# %%
# Replizierbarkeit gewährleisten
np.random.seed(0)

# %%
# Modell anpassen: 12% der originalen Datensatzstärke
lstm_model_12 = fit_lstm(ZR_N12_TR_I, 1, 30, 4)

# %%
# Validierung des Modells anhand der Testdaten
predictions_12 = list()
for i in range(len(ZR_N12_TE_I)):
    # make forecast 
    X, y = ZR_N12_TE_I.iloc[i, 0:-1], ZR_N12_TE_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_12, 1, X)
    predictions_12.append(yhat)
    expected = ZR_N12[len(ZR_N12_TR_I) + i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.038798, Expected=0.129530
# Month=2, Predicted=0.052054, Expected=0.073917
# Month=3, Predicted=0.064053, Expected=0.069641
# Month=4, Predicted=0.064824, Expected=0.104279
# Month=5, Predicted=0.077033, Expected=0.024326
# Month=6, Predicted=0.090106, Expected=0.082156
# Month=7, Predicted=0.115347, Expected=0.074529
# Month=8, Predicted=0.148711, Expected=0.115347
# Month=9, Predicted=0.186892, Expected=0.119270
# Month=10, Predicted=0.203135, Expected=0.212338
# Month=11, Predicted=0.218881, Expected=0.189289
# Month=12, Predicted=0.204412, Expected=0.193005
# Month=13, Predicted=0.176811, Expected=0.133037
# Month=14, Predicted=0.146080, Expected=0.066030
# Month=15, Predicted=0.121552, Expected=0.081673
# Month=16, Predicted=0.102719, Expected=0.125111
# Month=17, Predicted=0.109321, Expected=0.070710
# Month=18, Predicted=0.120497, Expected=0.109506
# Month=19, Predicted=0.145545, Expected=0.106104
# Month=20, Predicted=0.178185, Expected=0.147090
# Month=21, Predicted=0.212595, Expected=0.164598
# Month=22, Predicted=0.232035, Expected=0.248214
# Month=23, Predicted=0.245332, Expected=0.215597
# Month=24, Predicted=0.231497, Expected=0.222545
# Month=25, Predicted=0.206452, Expected=0.178286
# Month=26, Predicted=0.177106, Expected=0.107107
# Month=27, Predicted=0.158031, Expected=0.128761
# Month=28, Predicted=0.141668, Expected=0.150832
# Month=29, Predicted=0.138549, Expected=0.070762
# Month=30, Predicted=0.145598, Expected=0.137600
# Month=31, Predicted=0.171368, Expected=0.113991
# Month=32, Predicted=0.212544, Expected=0.169930
# Month=33, Predicted=0.251622, Expected=0.202547
# Month=34, Predicted=0.277024, Expected=0.264757
# Month=35, Predicted=0.288204, Expected=0.257353
# Month=36, Predicted=0.273058, Expected=0.256271
# Month=37, Predicted=0.243572, Expected=0.206967

# %%
# Skalierung zurücksetzten
predictions_12=np.reshape(predictions_12,(len(predictions_12),1))
predictions_12=scaler.inverse_transform(predictions_12)

# %%
# Modellperformance bewerten
mse = mean_squared_error(ZR_12[-len(predictions_12):], predictions_12)
print('Test MSE: %.3f' % mse)
# line plot of observed vs predicted
plt.plot(ZR_12[-len(predictions_12):], color='blue')
plt.plot(predictions_12, color='orange')
plt.show()
# Out:
# Test MSE: 20419580.308

# %%
predictions_train_12 = list()
for i in range(len(ZR_N12_TR_I)):
    # make forecast 
    X, y = ZR_N12_TR_I.iloc[i, 0:-1], ZR_N12_TR_I.iloc[i, -1]
    yhat = forecast_lstm(lstm_model_12, 1, X)
    predictions_train_12.append(yhat)
    expected = ZR_N12[i + 1]
    print('Month=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))
# Out:
# Month=1, Predicted=0.231218, Expected=0.152422
# Month=2, Predicted=0.184839, Expected=0.089169
# Month=3, Predicted=0.147708, Expected=0.044311
# Month=4, Predicted=0.116503, Expected=0.077554
# Month=5, Predicted=0.093566, Expected=0.095857
# Month=6, Predicted=0.072113, Expected=0.031209
# Month=7, Predicted=0.071695, Expected=0.098634
# Month=8, Predicted=0.069713, Expected=0.053449
# Month=9, Predicted=0.081999, Expected=0.106038
# Month=10, Predicted=0.102575, Expected=0.125293
# Month=11, Predicted=0.132513, Expected=0.182484
# Month=12, Predicted=0.147964, Expected=0.155460
# Month=13, Predicted=0.166551, Expected=0.172146
# Month=14, Predicted=0.157596, Expected=0.142045
# Month=15, Predicted=0.137921, Expected=0.086771
# Month=16, Predicted=0.108250, Expected=0.092155
# Month=17, Predicted=0.082542, Expected=0.089717
# Month=18, Predicted=0.063540, Expected=0.033895
# Month=19, Predicted=0.062812, Expected=0.071870
# Month=20, Predicted=0.063050, Expected=0.024391
# Month=21, Predicted=0.083768, Expected=0.093067
# Month=22, Predicted=0.108669, Expected=0.117680
# Month=23, Predicted=0.134656, Expected=0.172720
# Month=24, Predicted=0.142675, Expected=0.167988
# Month=25, Predicted=0.152770, Expected=0.161496
# Month=26, Predicted=0.136093, Expected=0.104513
# Month=27, Predicted=0.114262, Expected=0.049160
# Month=28, Predicted=0.091088, Expected=0.056083
# Month=29, Predicted=0.078492, Expected=0.086145
# Month=30, Predicted=0.067513, Expected=0.043802
# Month=31, Predicted=0.068014, Expected=0.092637
# Month=32, Predicted=0.071656, Expected=0.068298
# Month=33, Predicted=0.089428, Expected=0.114238
# Month=34, Predicted=0.108346, Expected=0.099142
# Month=35, Predicted=0.138744, Expected=0.175027
# Month=36, Predicted=0.152232, Expected=0.179303
# Month=37, Predicted=0.165959, Expected=0.152461

# %%
# Skalierung zurücksetzten
predictions_train_12=np.reshape(predictions_train_12,(len(predictions_train_12),1))
predictions_train_12=scaler.inverse_transform(predictions_train_12)

# %%
# Verschiebung der Trainingsvorhersage zum Plotten
trainPredictPlot = np.empty_like(ZR_12)
trainPredictPlot=trainPredictPlot.reshape(len(ZR_12))
trainPredictPlot[:]=[0]*len(ZR_12)
predictions_train_12=predictions_train_12.reshape(len(predictions_train_12))
trainPredictPlot[(look_back+look_forward-1):len(predictions_train_12)+(look_back+look_forward-1)] = predictions_train_12

# Verschiebung der Testvorhersage zum Plotten
testPredictPlot = np.empty_like(ZR_12)
testPredictPlot=testPredictPlot.reshape(len(ZR_12))
testPredictPlot[:]=[0]*len(ZR_12)
predictions_12=predictions_12.reshape(len(predictions_12))
testPredictPlot[-len(predictions_12):] = predictions_12

# Plotten der baseline und  der Vorhersagen
plt.plot(ZR_12, color='blue')
plt.plot(trainPredictPlot, color='orange') 
plt.plot(testPredictPlot, color='green')
plt.show()
